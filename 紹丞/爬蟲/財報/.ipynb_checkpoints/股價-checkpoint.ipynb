# %%
import numpy as np
import pandas as pd

# get data
import pandas_datareader as pdr

# visual
import matplotlib.pyplot as plt
import mpl_finance as mpf
# %matplotlib inline
import seaborn as sns

#time
import datetime as datetime

#talib
import talib

# %%
start = datetime.datetime(2022,5,30) #from datatime
df_2330 = pdr.DataReader('1529.TW', 'yahoo', start=start)
# df_2330
# Out:
#                  High        Low       Open      Close    Volume  Adj Close
# Date
# 2022-05-30  21.950001  21.150000  21.250000  21.150000   1123650  21.150000
# 2022-05-31  21.299999  20.799999  20.950001  20.850000    768000  20.850000
# 2022-06-01  21.400000  20.950001  20.950001  20.950001    617000  20.950001
# 2022-06-02  21.299999  20.500000  21.150000  20.549999    698000  20.549999
# 2022-06-06  20.799999  20.200001  20.700001  20.650000    596000  20.650000
# 2022-06-07  20.900000  20.350000  20.900000  20.350000    383001  20.350000
# 2022-06-08  20.600000  20.350000  20.500000  20.350000    316000  20.350000
# 2022-06-09  20.850000  20.200001  20.200001  20.799999    492020  20.799999
# 2022-06-10  20.799999  20.350000  20.400000  20.700001    320000  20.700001
# 2022-06-13  20.299999  19.900000  20.000000  19.900000    847999  19.900000
# 2022-06-14  19.900000  19.200001  19.900000  19.549999    691000  19.549999
# 2022-06-15  20.299999  19.600000  19.750000  19.900000    619312  19.900000
# 2022-06-16  20.549999  19.400000  20.200001  19.400000    678101  19.400000
# 2022-06-17  19.650000  19.100000  19.500000  19.400000    328000  19.400000
# 2022-06-20  19.799999  18.500000  19.500000  18.500000    784633  18.500000
# 2022-06-21  19.600000  18.500000  19.000000  19.600000    671034  19.600000
# 2022-06-22  19.799999  18.750000  19.799999  18.950001    512001  18.950001
# 2022-06-23  20.000000  18.900000  19.200001  19.250000  24252200  19.250000
# 2022-06-24  19.450001  19.000000  19.200001  19.400000   1417000  19.400000
# 2022-06-27  19.799999  19.350000  19.799999  19.500000    715000  19.500000
# 2022-06-28  19.750000  19.000000  19.500000  19.500000    732075  19.500000
# 2022-06-29  19.650000  19.250000  19.400000  19.299999    458054  19.299999
# 2022-06-30  19.299999  18.600000  19.299999  18.700001    748000  18.700001
# 2022-07-01  18.799999  17.100000  18.700001  17.150000   1004000  17.150000
# 2022-07-04  18.850000  17.350000  17.500000  18.850000   1208200  18.850000
# 2022-07-05  19.750000  18.900000  19.100000  19.350000   3729058  19.350000
# 2022-07-06  19.700001  18.200001  19.700001  18.350000   1316142  18.350000
# 2022-07-07  18.700001  17.799999  18.700001  18.299999    850000  18.299999
# 2022-07-08  18.850000  17.900000  18.400000  17.900000    828010  17.900000
# 2022-07-11  18.100000  17.650000  18.100000  17.650000    309256  17.650000

# %%
sma_10 = talib.SMA(np.array(df_2330['Close']), 10)
sma_30 = talib.SMA(np.array(df_2330['Close']), 30)

fig = plt.figure(figsize=(24, 15))
ax = fig.add_axes([0,0.2,1,0.5])
ax2 = fig.add_axes([0,0,1,0.2])
ax.plot(grid='True')
#使用 set_xticklabels來畫股票棒子 from talib
ax.set_xticks(range(0, len(df_2330.index), 10))
ax.set_xticklabels(df_2330.index[::10])
mpf.candlestick2_ochl(ax, df_2330['Open'], df_2330['Close'], df_2330['High'],
                      df_2330['Low'], width=0.6, colorup='r', colordown='g', alpha=0.75)
plt.rcParams['font.sans-serif']=['Microsoft JhengHei'] 
ax.plot(sma_10, label='10日均線') #藍色
ax.plot(sma_30, label='30日均線') #橘色

#成交量
mpf.volume_overlay(ax2, df_2330['Open'], df_2330['Close'], df_2330['Volume'], colorup='r', colordown='g', width=0.5, alpha=0.8)
ax2.set_xticks(range(0, len(df_2330.index), 10))
ax2.set_xticklabels(df_2330.index[::10])

ax.legend();
