# %% [markdown]
# # 2457

# %%
import pandas_datareader as pdr
import datetime
start = datetime.datetime(2015,3,1) #from datatime
end =datetime.datetime(2022,4,30)
df_2457 = pdr.DataReader('2457.TW', 'yahoo', start=start,end=end)
df_2457
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2015-03-02  16.589998  16.344585  16.491833  16.344585   1106292.0  15.580491
# 2015-03-03  17.031744  16.344585  16.393667  17.031744   2063857.0  16.235525
# 2015-03-04  17.571655  16.835413  16.982660  17.326241   3421766.0  16.516254
# 2015-03-05  17.522573  17.178993  17.473490  17.178993   1769457.0  16.375891
# 2015-03-06  17.375324  17.178993  17.178993  17.375324    751790.0  16.563044
# ...               ...        ...        ...        ...         ...        ...
# 2022-04-25  42.200001  40.599998  42.099998  40.950001   8863000.0  40.950001
# 2022-04-26  41.700001  40.700001  41.400002  40.700001   4182232.0  40.700001
# 2022-04-27  39.349998  37.000000  39.000000  38.650002  12176416.0  38.650002
# 2022-04-28  39.400002  38.049999  39.099998  38.700001   5103068.0  38.700001
# 2022-04-29  39.849998  38.799999  39.549999  39.000000   3540001.0  39.000000
#
# [1749 rows x 6 columns]

# %%
counter=0
maxValue=0
maxList=[]
timeList=[]
for i in range(len(df_2457)):
    if(i%30==0 and i!=0):
        maxList.append(maxValue)
        timeList.append(timeVaue)
        maxValue=0
    if(t['Close'][i]>maxValue):
        maxValue=t['Close'][i]
        timeVaue=t['Date'][i]

# %%
dict(zip(timeList, maxList))
# Out:
# {Timestamp('2015-03-06 00:00:00'): 17.375324249267578,
#  Timestamp('2015-04-15 00:00:00'): 16.24641990661621,
#  Timestamp('2015-05-29 00:00:00'): 12.957868576049805,
#  Timestamp('2015-07-20 00:00:00'): 11.28905200958252,
#  Timestamp('2015-09-11 00:00:00'): 8.481513977050781,
#  Timestamp('2015-10-20 00:00:00'): 10.209230422973633,
#  Timestamp('2015-12-17 00:00:00'): 14.086773872375488,
#  Timestamp('2015-12-31 00:00:00'): 13.203283309936523,
#  Timestamp('2016-02-23 00:00:00'): 13.203283309936523,
#  Timestamp('2016-04-13 00:00:00'): 11.77988052368164,
#  Timestamp('2016-05-26 00:00:00'): 9.816567420959473,
#  Timestamp('2016-07-26 00:00:00'): 11.141803741455078,
#  Timestamp('2016-09-09 00:00:00'): 10.503726959228516,
#  Timestamp('2016-09-28 00:00:00'): 10.160146713256836,
#  Timestamp('2016-12-21 00:00:00'): 11.534465789794922,
#  Timestamp('2016-12-30 00:00:00'): 12.859703063964844,
#  Timestamp('2017-03-27 00:00:00'): 12.75,
# ...

# %%
t=df_2457.reset_index() 
t['Date'][0]
# Out:
# Timestamp('2015-03-02 00:00:00')

# %% [markdown]
# # 5258

# %%
start = datetime.datetime(2013,3,28) #from datatime
end =datetime.datetime(2022,7,19)
df_5258 = pdr.DataReader('5258.TW', 'yahoo', start=start,end=end)
df_5258
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2013-03-28  14.407788  14.287053  14.407788  14.407788     19878.0  12.392808
# 2013-03-29  14.488279  14.327298  14.448034  14.448034     37271.0  12.427426
# 2013-04-01  14.649260  14.488279  14.568769  14.568769    122064.0  12.531277
# 2013-04-02  14.971221  14.649260  14.729750  14.729750    148216.0  12.669744
# 2013-04-03  14.729750  14.729750  14.729750  14.729750         0.0  12.669744
# ...               ...        ...        ...        ...         ...        ...
# 2022-07-13  62.099998  58.000000  58.500000  62.099998  16581590.0  62.099998
# 2022-07-14  64.400002  59.200001  61.400002  64.000000  52304233.0  64.000000
# 2022-07-15  65.400002  60.599998  63.200001  61.700001  22756150.0  61.700001
# 2022-07-18  66.800003  61.700001  62.000000  64.599998  35055363.0  64.599998
# 2022-07-19  66.300003  63.200001  64.599998  66.099998  25658328.0  66.099998
#
# [2276 rows x 6 columns]

# %%
counter=0
maxValue=0
maxList=[]
timeList=[]
t=df_5258.reset_index() 
for i in range(len(df_5258)):
    if(i%30==0 and i!=0):
        maxList.append(maxValue)
        timeList.append(timeVaue)
        maxValue=0
    if(t['Close'][i]>maxValue):
        maxValue=t['Close'][i]
        timeVaue=t['Date'][i]
dict(zip(timeList, maxList))
# Out:
# {Timestamp('2013-04-02 00:00:00'): 14.72974967956543,
#  Timestamp('2013-05-17 00:00:00'): 13.522393226623535,
#  Timestamp('2013-08-05 00:00:00'): 13.522393226623535,
#  Timestamp('2013-08-13 00:00:00'): 14.407788276672363,
#  Timestamp('2013-10-15 00:00:00'): 15.128177642822266,
#  Timestamp('2013-12-12 00:00:00'): 20.368104934692383,
#  Timestamp('2013-12-27 00:00:00'): 23.326129913330078,
#  Timestamp('2014-03-03 00:00:00'): 26.368667602539062,
#  Timestamp('2014-04-10 00:00:00'): 22.565494537353516,
#  Timestamp('2014-06-11 00:00:00'): 22.396465301513672,
#  Timestamp('2014-06-18 00:00:00'): 21.97389030456543,
#  Timestamp('2014-08-12 00:00:00'): 20.537134170532227,
#  Timestamp('2014-10-09 00:00:00'): 21.522579193115234,
#  Timestamp('2014-10-24 00:00:00'): 19.759174346923828,
#  Timestamp('2014-12-31 00:00:00'): 19.632572174072266,
#  Timestamp('2015-01-26 00:00:00'): 18.99051284790039,
#  Timestamp('2015-03-24 00:00:00'): 18.393667221069336,
# ...

# %% [markdown]
# # 3062

# %%
start = datetime.datetime(2013,3,27) #from datatime
end =datetime.datetime(2022,7,19)
df_3062 = pdr.DataReader('3062.TW', 'yahoo', start=start,end=end)
counter=0
maxValue=0
maxList=[]
timeList=[]
t=df_3062.reset_index() 
for i in range(len(df_3062)):
    if(i%30==0 and i!=0):
        maxList.append(maxValue)
        timeList.append(timeVaue)
        maxValue=0
    if(t['Close'][i]>maxValue):
        maxValue=t['Close'][i]
        timeVaue=t['Date'][i]
dict(zip(timeList, maxList))
# Out:
# {Timestamp('2013-03-27 00:00:00'): 25.399999618530273,
#  Timestamp('2013-06-07 00:00:00'): 25.649999618530273,
#  Timestamp('2013-07-24 00:00:00'): 34.5,
#  Timestamp('2013-08-14 00:00:00'): 36.349998474121094,
#  Timestamp('2013-09-18 00:00:00'): 35.650001525878906,
#  Timestamp('2013-11-11 00:00:00'): 33.0,
#  Timestamp('2014-01-10 00:00:00'): 34.04999923706055,
#  Timestamp('2014-03-06 00:00:00'): 35.650001525878906,
#  Timestamp('2014-04-17 00:00:00'): 33.349998474121094,
#  Timestamp('2014-06-11 00:00:00'): 32.349998474121094,
#  Timestamp('2014-07-04 00:00:00'): 32.20000076293945,
#  Timestamp('2014-07-30 00:00:00'): 30.200000762939453,
#  Timestamp('2014-10-03 00:00:00'): 27.850000381469727,
#  Timestamp('2014-11-04 00:00:00'): 24.600000381469727,
#  Timestamp('2015-01-05 00:00:00'): 26.5,
#  Timestamp('2015-01-20 00:00:00'): 24.799999237060547,
#  Timestamp('2015-04-14 00:00:00'): 25.350000381469727,
#  Timestamp('2015-04-27 00:00:00'): 24.700000762939453,
# ...
