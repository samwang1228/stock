# %%
# https://finmind.github.io/quickstart/

# %%
import requests
import pandas as pd
url = "https://api.finmindtrade.com/api/v4/data"
parameter = {
    "dataset": "TaiwanStockNews",
    "data_id":"2498", #宏達電
    "start_date": "2022-04-15",
    "end_date": "2022-07-05",
    "token": "", # 參考登入，獲取金鑰
}
data = requests.get(url, params=parameter)
data = data.json()
data = pd.DataFrame(data['data'])
#print(data.head())
print(data)
# Out:
#                     date stock_id  \
# 0    2022-04-15 06:48:57     2498
# 1    2022-04-15 07:00:00     2498
# 2    2022-04-19 09:15:00     2498
# 3    2022-04-19 09:15:00     2498
# 4    2022-04-19 09:15:00     2498
# ..                   ...      ...
# 364  2022-07-04 05:09:00     2498
# 365  2022-07-04 05:12:36     2498
# 366  2022-07-04 06:48:11     2498
# 367  2022-07-04 16:14:02     2498
# 368  2022-07-04 16:15:53     2498
#
#                                                   link                source  \
# 0    https://www.chinatimes.com/realtimenews/202204...  中時新聞網 Chinatimes.com
# 1    https://www.chinatimes.com/realtimenews/202204...  中時新聞網 Chinatimes.com
# 2             https://finance.ettoday.net/news/2233305            ETtoday財經雲
# 3             https://finance.ettoday.net/news/2233305            ETtoday財經雲
# 4             https://finance.ettoday.net/news/2233305            ETtoday財經雲
# ..                                                 ...                   ...
# 364  https://money.udn.com/money/story/5739/6436125...                  經濟日報
# 365  https://tw.news.yahoo.com/%E7%9C%8B%E5%A5%BDvr...             Yahoo奇摩新聞
# 366  https://udn.com/news/story/7240/6435391?from=u...               udn.com
# 367   https://money.udn.com/money/story/122231/6436125                  經濟日報
# 368  https://money.udn.com/money/story/5739/6436125...                  經濟日報
#
#                                                  title
# 0    《通信網路》宏達電VIVE Arts再當藝術咖 前進倫敦蛇形藝廊 - 中時新聞網 China...
# 1    《通信網路》宏達電VIVE Arts再當藝術咖 前進倫敦蛇形藝廊 - 中時新聞網 China...
# 2          十大超夯股東會紀念品！聯電續推角落小夥伴 敲碗等王品、宏達電 - ETtoday財經雲
# 3           十大超夯股東會紀念品！聯電續推角落小夥伴敲碗等王品、宏達電 - ETtoday財經雲
# 4    十大超夯股東會紀念品！聯電續推角落小夥伴敲碗等王品、宏達電| ETtoday財經雲| ETt...
# ..                                                 ...
# 364                            最牛一輪/宏達電閃亮 中信1B靚 - 經濟日報
# 365              看好VR產業發展 美系外資首評宏達電 目標價76元 - Yahoo奇摩新聞
# 366             宏達電再讓元宇宙成焦點 MicroLED將是AR設備首選 - udn.com
# 367                            最牛一輪/宏達電閃亮 中信1B靚 - 經濟日報
# 368                            最牛一輪/宏達電閃亮 中信1B靚 - 經濟日報
#
# [369 rows x 5 columns]

# %%
print(data["title"])

# %%
import requests

# %%
# 中時新聞網 Chinatimes.com

# %%
my_headers ={'cookie':'over18=1;'}
url=data['link'][0]
response = requests.get(url, headers=my_headers)
content=response.text
print(data['source'][0])
print(content)
# Out:
# 中時新聞網 Chinatimes.com
#
# <!DOCTYPE html>
# <html lang="zh-Hant-TW">
# <head id="Head1" prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#">
# <meta charset="utf-8">
# <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
# <title>《通信網路》宏達電VIVE Arts再當藝術咖 前進倫敦蛇形藝廊 - 財經 - 時報資訊</title>
# <meta name="viewport" content="width=device-width, initial-scale=1.0">
#
# <meta property="og:url" itemprop="url" content="https://www.chinatimes.com/realtimenews/20220415003322-260410">
# <meta property="og:title" itemprop="name" content="《通信網路》宏達電VIVE Arts再當藝術咖 前進倫敦蛇形藝廊 - 財經">
# <meta property="og:image" itemprop="image" content="https://static.chinatimes.com/images/2020/logo-chinatimes-250x250.png">
# <meta property="og:image:width" content="250">
# <meta property="og:image:height" content="250">
# <meta name="twitter:card" content="summary_large_image">
# <meta property="og:type" content="article">
# <meta property="og:description" itemprop="description" content="宏達電(2498)宣布，旗下藝術創新團隊VIVE Arts將再度與知名法國藝術家多米妮克.岡薩雷斯-福斯特(Dominique Gonzalez-Foerster)聯手合作，擔任其將於倫敦蛇形藝廊(Serpentine)隆重登場的全新個展「Alienarium 5」的官">
# <meta property="fb:admins" content="100009177684541">
# <meta property="fb:app_id" content="1379575469016080">
# <meta property="fb:pages" content="188311137478,102052648187244,300714994690744,1122937374406998,133290163978246,722239474456253,329118253934643,556244387799738,558877360920831" />
# <meta property="article:author" content="https://www.facebook.com/CTfans">
# <meta property="article:publisher" content="https://www.facebook.com/CTfans">
# <meta property="og:locale" content="zh_TW">
# <meta property="og:site_name" content="中時新聞網">
#
# <meta property="dable:item_id" content="20220415003322-260410">
# <meta property="dable:author" content="中時新聞網">
# <meta property="article:section2" content="non-adult">
#
#
#
# <meta name="title" itemprop="headline" data-ephemeral="true" content="Infotimes.WwwWeb.ViewModels.ArticleViewModel">
# <meta name="description" content="宏達電(2498)宣布，旗下藝術創新團隊VIVE Arts將再度與知名法國藝術家多米妮克.岡薩雷斯-福斯特(Dominique Gonzalez-Foerster)聯手合作，擔任其將於倫敦蛇形藝廊(Serpentine)隆重登場的全新個展「Alienarium 5」的官">
# <meta name="keywords" itemprop="keywords" content="VIVEArts,VR,體驗,藝廊,妮克">
# <meta name="lastmod" property="article:modified_time" itemprop="dateModified" content="1970-01-01T08:00:00+08:00">
# <meta name="pubdate" property="article:published_time" itemprop="datePublished" content="2022-04-15T14:48:57+08:00">
# <meta name="section" property="article:section" itemprop="articleSection" content="財經">
# <meta name="section" content="財經" data-ephemeral="true">
# <meta name="subsection" itemprop="articleSection" content="新聞">
# <meta name="source" content="中時新聞網">
# <meta name="copyright" content="中時新聞網">
# <meta name="author" itemprop="author" content="中時新聞網">
# <meta name="publisher" itemprop="publisher" content="中時新聞網">
# <meta name="medium" content="news">
# <meta name="popIn_certification" content="non_adult">
# <meta property="taboola_recommend" content="true">
# <meta name="image" content="https://static.chinatimes.com/images/2020/logo-chinatimes-250x250.png">
# <link rel="image_src" type="image/jpeg" href="https://static.chinatimes.com/images/2020/logo-chinatimes-250x250.png">
# <link rel="amphtml" href="https://www.chinatimes.com/amp/realtimenews/20220415003322-260410">
# <link rel="canonical" href="https://wantrich.chinatimes.com/news/20220415900586-420101">
# <link rel="alternate" hreflang="zh-Hant" media="only screen and (max-width: 640px)" href="https://www.chinatimes.com/realtimenews/20220415003322-260410">
# <link rel="alternate" hreflang="zh-Hant" media="only screen and (min-width: 640px)" href="https://www.chinatimes.com/realtimenews/20220415003322-260410?chdtv">
# <link rel="alternate" hreflang="zh-Hans" media="only screen and (max-width: 640px)" href="https://www.chinatimes.com/cn/realtimenews/20220415003322-260410">
# <link rel="alternate" hreflang="zh-Hans" media="only screen and (min-width: 640px)" href="https://www.chinatimes.com/cn/realtimenews/20220415003322-260410?chdtv">
# <link rel="shortcut icon" href="//www.chinatimes.com/images/2020/favicon.ico">
# <link rel="apple-touch-icon" sizes="180x180" href="//www.chinatimes.com/images/2020/apple-touch-icon.png">
# <link rel="mask-icon" href="//www.chinatimes.com/images/2020/safari-pinned-tab.svg" color="#d8262c">
# <link rel="manifest" href="//www.chinatimes.com/site.webmanifest">
# <meta name="apple-mobile-web-app-title" content="中時新聞網">
# <meta name="application-name" content="中時新聞網">
# <meta name="msapplication-TileColor" content="#dddddd">
# <meta name="theme-color" content="#ffffff">
# <script type="application/ld+json">
#         {
#         "@context": "https://schema.org",
#         "@type": "NewsArticle",
#         "articleSection": "財經",
#         "mainEntityOfPage": {
#         "@type": "WebPage",
#         "@id": "https://www.chinatimes.com/realtimenews/20220415003322-260410"
#         },
#         "headline": "《通信網路》宏達電VIVE Arts再當藝術咖 前進倫敦蛇形藝廊",
# "image": {"@type": "ImageObject","url":"https://static.chinatimes.com/images/2020/logo-chinatimes-250x250.png","height":250,"width":250},"author": {"@type": "Person","name": "王逸芯" },        "url":"https://www.chinatimes.com/realtimenews/20220415003322-260410",
#         "description":"宏達電(2498)宣布，旗下藝術創新團隊VIVE Arts將再度與知名法國藝術家多米妮克.岡薩雷斯-福斯特(Dominique Gonzalez-Foerster)聯手合作，擔任其將於倫敦蛇形藝廊(Serpentine)隆重登場的全新個展「Alienarium 5」的官",
#         "keywords": "VIVEArts,VR,體驗,藝廊,妮克",
#         "datePublished": "2022-04-15T14:48:57+08:00",
# "dateModified": "2022-04-15T14:48:57+08:00",        "publisher": {
#         "@type": "Organization",
#         "name": "財經 - 時報資訊",
#         "logo": {
#         "@type": "ImageObject",
#         "url": "https://static.chinatimes.com/images/2020/category-logo/logo-ct-money.png",
#         "width": 260,
#         "height": 60
#         }
#         }
#         }
#     </script>
#
#
# <link rel="stylesheet" href="https://static.chinatimes.com/css-main/2020/index-m2020.css?20220707">
#
#
# <script data-cfasync="false" src="https://static.chinatimes.com/scripts/identify-browser-mode.min.js?20190418"></script>
# <script data-cfasync="false" src="https://static.chinatimes.com/libs/jquery/3.6.0/jquery.min.js"></script>
# <script data-cfasync="false" src="https://static.chinatimes.com/libs/bootstrap/4.5.2/js/bootstrap.min.js"></script>
# <script src="https://static.chinatimes.com/libs/jquery-cookie/1.4.1/jquery.cookie.min.js"></script>
# <script data-cfasync="false" src="https://static.chinatimes.com/scripts/user.min.js?20190329"></script>
#
#
# <script>
#         var _comscore = _comscore || [];
#         _comscore.push({
#             c1: "2",
#             c2: "9457284",
#             options: {
#                 url_append: "comscorekw=news"
#             }
#         });
#         (function () {
#             var s = document.createElement("script"),
#                 el = document.getElementsByTagName("script")[0];
#             s.async = true;
#             s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#             el.parentNode.insertBefore(s, el);
#         })();
#     </script>
# <noscript>
#         <img src="http://b.scorecardresearch.com/p?c1=2&c2=9457284&cv=2.0&cj=1">
#     </noscript>
#
#
# <script>
#         var _uuid = "" + getCookie("ID");
#         dataLayer = [{
#             'ArticleID': '20220415003322',
#             'ArticleDate': '2022-04-15',
#             'Title': '《通信網路》宏達電VIVE Arts再當藝術咖 前進倫敦蛇形藝廊',
#             'SrcID': '8',
#             'AuthorName': '王逸芯',
#             'SiteID': '26',
#             'ChannelID': '2604',
#             'CategoryID': '260410',
#             'UUID': _uuid,
#             'Tag': 'VIVEArts、VR、體驗、藝廊、妮克',
#             'utm_source': '',
#             'PageType': '3',
#             'GroupID': 'A',
#             'adult': '0'
#         }];
#     </script>
# <script>
#         (function (w, d, s, l, i) {
#             w[l] = w[l] || [];
#             w[l].push({
#                 'gtm.start': new Date().getTime(),
#                 event: 'gtm.js'
#             });
#             var f = d.getElementsByTagName(s)[0],
#                 j = d.createElement(s),
#                 dl = l != 'dataLayer' ? '&l=' + l : '';
#             j.async = true;
#             j.src =
#                 'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
#             f.parentNode.insertBefore(j, f);
#         })(window, document, 'script', 'dataLayer', 'GTM-5SNQFFP');
#     </script>
#
#
# <script>
#         (function (w, d, s, l, i) {
#             w[l] = w[l] || [];
#             w[l].push({
#                 'gtm.start': new Date().getTime(),
#                 event: 'gtm.js'
#             });
#             var f = d.getElementsByTagName(s)[0],
#                 j = d.createElement(s),
#                 dl = l != 'dataLayer' ? '&l=' + l : '';
#             j.async = true;
#             j.src =
#                 'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
#             f.parentNode.insertBefore(j, f);
#         })(window, document, 'script', 'dataLayer', 'GTM-MWBSFZ');
#     </script>
#
# </head>
# <body class="is-mobile content-article ">
#
# <div id="fb-root"></div>
# <script>
#         window.fbAsyncInit = function () {
#             FB.init({
#                 appId: '1379575469016080',
#                 xfbml: true,
#                 version: 'v3.2'
#             });
#             FB.AppEvents.logPageView();
#         };
#         (function (d, s, id) {
#             var js, fjs = d.getElementsByTagName(s)[0];
#             if (d.getElementById(id)) {
#                 return;
#             }
#             js = d.createElement(s);
#             js.id = id;
#             js.src = "//connect.facebook.net/zh_TW/sdk.js";
#             fjs.parentNode.insertBefore(js, fjs);
#         }(document, 'script', 'facebook-jssdk'));
#     </script>
#
#
# <noscript>
#         <iframe src="https://www.googletagmanager.com/ns.html?id=GTM-5SNQFFP" height="0" width="0" style="display: none; visibility: hidden"></iframe>
#     </noscript>
#
#
# <noscript>
#         <iframe src="https://www.googletagmanager.com/ns.html?id=GTM-MWBSFZ" height="0" width="0" style="display:none;visibility:hidden"></iframe>
#     </noscript>
#
#
# <script async data-cfasync="false" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script>
# <script data-cfasync="false">
#             window.googletag = window.googletag || { cmd: [] };
#         </script>
#
#
# <div class="ad rwd">
# <div class="lightbox-auto-scale">
#
# <div id="div-gpt-ad-1551201747632-0"></div>
#
# </div>
# </div>
#
# <div id="page-top" class="wrapper">
# <div class="container">
# <div class="row d-block">
#
# <script>
#                         //全域主選單高亮項目id，例：realtimenews
#                         var ctMainNavId = "money";
#                         //全域次選單高亮項目id，例：subnav01
#                         var ctSubNavId = "article";
#                         //捲動頁面時，手機版刊頭是否轉換為置頂固定式
#                         var toFixCtMainHeaderOnScroll = true;
#                 </script>
#
# <header class="main-header">
# <div class="main-header-container">
# <div class="main-header-logo"><a href="https://www.chinatimes.com/" title="中時新聞網">中時新聞網</a></div>
# </div>
# </header>
#
#
# <div class="main-nav-wrapper">
# <nav class="main-nav desktop">
# <div class="mobile-btn-close"><a href="javascript:;">關閉</a></div>
# <ul class="main-nav-item-group">
# <li data-id="covid-19" class="main-nav-item"><a href="https://covid-19.chinatimes.com/%E6%96%B0%E5%86%A0%E8%82%BA%E7%82%8E,%E5%8F%B0%E7%81%A3" target="_blank">新冠肺炎</a></li>
# <li data-id="realtimenews" class="main-nav-item">
# <a href="//www.chinatimes.com/realtimenews/" target="">即時</a>
# <div class="btn-toggle-sub-nav"><a href="javascript:;">展開子選單</a></div>
# <div class="sub-nav hide" id="menu_realtimenews">
# <ul class="sub-nav-item-group">
# <li class="sub-nav-item" data-id="2604"><a href="//www.chinatimes.com/realtimenews/" target="_self">即時首頁</a></li>
# <li class="sub-nav-item" data-id="hotnews"><a href="//www.chinatimes.com/hotnews/?chdtv" target="_self">熱門</a></li>
# <li class="sub-nav-item" data-id="260407"><a href="//www.chinatimes.com/realtimenews/260407/" target="_self">政治</a></li>
# <li class="sub-nav-item" data-id="260405"><a href="//www.chinatimes.com/realtimenews/260405/" target="_self">生活</a></li>
# <li class="sub-nav-item" data-id="260402"><a href="//www.chinatimes.com/realtimenews/260402/" target="_self">社會</a></li>
# <li class="sub-nav-item" data-id="260404"><a href="//www.chinatimes.com/realtimenews/260404/" target="_self">娛樂</a></li>
# <li class="sub-nav-item" data-id="260403"><a href="//www.chinatimes.com/realtimenews/260403/" target="_self">體育</a></li>
# <li class="sub-nav-item" data-id="260410"><a href="//www.chinatimes.com/realtimenews/260410/" target="_self">財經</a></li>
# <li class="sub-nav-item" data-id="260408"><a href="//www.chinatimes.com/realtimenews/260408/" target="_self">國際</a></li>
# <li class="sub-nav-item" data-id="260409"><a href="//www.chinatimes.com/realtimenews/260409/" target="_self">兩岸</a></li>
# <li class="sub-nav-item" data-id="260412"><a href="//www.chinatimes.com/realtimenews/260412/" target="_self">科技</a></li>
# <li class="sub-nav-item" data-id="260417"><a href="//www.chinatimes.com/realtimenews/260417/" target="_self">軍事</a></li>
# <li class="sub-nav-item" data-id="260418"><a href="//www.chinatimes.com/realtimenews/260418/" target="_self">健康</a></li>
# <li class="sub-nav-item" data-id="2622"><a href="//www.chinatimes.com/album/" target="_self">專輯</a></li>
# </ul>
# </div>
# </li>
# <li data-id="politic" class="main-nav-item">
# <a href="//www.chinatimes.com/politic/" target="">政治</a>
# <div class="btn-toggle-sub-nav"><a href="javascript:;">展開子選單</a></div>
# <div class="sub-nav hide" id="menu_politic">
# <ul class="sub-nav-item-group">
# <li class="sub-nav-item" data-id="index"><a href="//www.chinatimes.com/politic/" target="_self">政治首頁</a></li>
# <li class="sub-nav-item" data-id="total"><a href="//www.chinatimes.com/politic/total/" target="_self">總覽</a></li>
# </ul>
# </div>
# </li>
# <li data-id="opinion" class="main-nav-item">
# <a href="//www.chinatimes.com/opinion/" target="">言論</a>
# <div class="btn-toggle-sub-nav"><a href="javascript:;">展開子選單</a></div>
# <div class="sub-nav hide" id="menu_opinion">
# <ul class="sub-nav-item-group">
# <li class="sub-nav-item" data-id="index"><a href="//www.chinatimes.com/opinion/" target="_self">首頁</a></li>
# <li class="sub-nav-item" data-id="total"><a href="//www.chinatimes.com/opinion/total/" target="_self">總覽</a></li>
# <li class="sub-nav-item" data-id="262101"><a href="//www.chinatimes.com/opinion/cteditorials/" target="_self">中時社論</a></li>
# <li class="sub-nav-item" data-id="262102"><a href="//www.chinatimes.com/opinion/wanteditorials/" target="_self">旺報社評</a></li>
# <li class="sub-nav-item" data-id="262113"><a href="//www.chinatimes.com/opinion/commercial/" target="_self">工商社論</a></li>
# <li class="sub-nav-item" data-id="262103"><a href="//www.chinatimes.com/opinion/review/" target="_self">快評</a></li>
# <li class="sub-nav-item" data-id="262104"><a href="//www.chinatimes.com/opinion/columnists/" target="_self">時論廣場</a></li>
# <li class="sub-nav-item" data-id="262114"><a href="//www.chinatimes.com/opinion/op-ed-weekly/" target="_self">尚青論壇</a></li>
# <li class="sub-nav-item" data-id="262106"><a href="//www.chinatimes.com/opinion/letters/" target="_self">兩岸徵文</a></li>
# <li class="sub-nav-item" data-id="262107"><a href="//www.chinatimes.com/opinion/record/" target="_self">史話</a></li>
# <li class="sub-nav-item" data-id="262110"><a href="//www.chinatimes.com/opinion/partner/" target="_self">海納百川</a></li>
# <li class="sub-nav-item" data-id="262115"><a href="//www.chinatimes.com/opinion/awakening/" target="_self">無色覺醒</a></li>
# </ul>
# </div>
# </li>
# <li data-id="life" class="main-nav-item">
# <a href="//www.chinatimes.com/life/" target="">生活</a>
# <div class="btn-toggle-sub-nav"><a href="javascript:;">展開子選單</a></div>
# <div class="sub-nav hide" id="menu_life">
# <ul class="sub-nav-item-group">
# <li class="sub-nav-item" data-id="index"><a href="//www.chinatimes.com/life/" target="_self">生活首頁</a></li>
# <li class="sub-nav-item" data-id="total"><a href="//www.chinatimes.com/life/total/" target="_self">總覽</a></li>
# <li class="sub-nav-item" data-id="263304"><a href="//www.chinatimes.com/life/life-travel/" target="_self">美食旅遊</a></li>
# <li class="sub-nav-item" data-id="263302"><a href="//www.chinatimes.com/life/shopping/" target="_self">消費</a></li>
# <li class="sub-nav-item" data-id="263306"><a href="//www.chinatimes.com/life/life-fashion/" target="_self">時尚</a></li>
# <li class="sub-nav-item" data-id="262211"><a href="//www.chinatimes.com/album/album-life/" target="_self">專輯</a></li>
# <li class="sub-nav-item" data-id="covid-19"><a href="//covid-19.chinatimes.com/%E6%96%B0%E5%86%A0%E8%82%BA%E7%82%8E,%E5%8F%B0%E7%81%A3" target="_blank" rel="noopener">新冠肺炎</a></li>
# <li class="sub-nav-item" data-id="campus"><a href="//www.chinatimes.com/campus/" target="_self">校園Campus</a></li>
# <li class="sub-nav-item" data-id="Happy-City"><a href="//www.chinatimes.com/album/Happy-City/20220209002461-262211" target="_self">城市幸福力</a></li>
# <li class="sub-nav-item" data-id="Planet"><a href="//www.chinatimes.com/album/Planet/20220209002816-262211" target="_self">和地球呼吸</a></li>
# <li class="sub-nav-item" data-id="LVMH"><a href="//www.chinatimes.com/album/LVMH/20220317002892-262211" target="_self">2022鐘錶展</a></li>
# </ul>
# </div>
# </li>
# <li data-id="star" class="main-nav-item">
# <a href="//www.chinatimes.com/star/" target="">娛樂</a>
# <div class="btn-toggle-sub-nav"><a href="javascript:;">展開子選單</a></div>
# <div class="sub-nav hide" id="menu_star">
# <ul class="sub-nav-item-group">
# <li class="sub-nav-item" data-id="index"><a href="//www.chinatimes.com/star/" target="_self">娛樂首頁</a></li>
# <li class="sub-nav-item" data-id="total"><a href="//www.chinatimes.com/star/total/" target="_self">總覽</a></li>
# <li class="sub-nav-item" data-id="261101"><a href="//www.chinatimes.com/star/news/" target="_self">華人星光</a></li>
# <li class="sub-nav-item" data-id="261105"><a href="//www.chinatimes.com/star/jkstars/" target="_self">哈燒日韓</a></li>
# <li class="sub-nav-item" data-id="261108"><a href="//www.chinatimes.com/star/western/" target="_self">西洋熱門</a></li>
# <li class="sub-nav-item" data-id="261109"><a href="//www.chinatimes.com/star/general/" target="_self">綜合星聞</a></li>
# <li class="sub-nav-item" data-id="262207"><a href="//www.chinatimes.com/album/album-star/" target="_self">專輯</a></li>
# </ul>
# </div>
# </li>
# <li data-id="money" class="main-nav-item">
# <a href="//www.chinatimes.com/money/" target="">財經</a>
# <div class="btn-toggle-sub-nav"><a href="javascript:;">展開子選單</a></div>
# <div class="sub-nav hide" id="menu_money">
# <ul class="sub-nav-item-group">
# <li class="sub-nav-item" data-id="index"><a href="//www.chinatimes.com/money/" target="_self">財經首頁</a></li>
# <li class="sub-nav-item" data-id="total"><a href="//www.chinatimes.com/money/total/" target="_self">總覽</a></li>
# <li class="sub-nav-item" data-id="261502"><a href="//www.chinatimes.com/money/focus/" target="_self">要聞</a></li>
# <li class="sub-nav-item" data-id="261507"><a href="//www.chinatimes.com/money/securities/" target="_self">證券</a></li>
# <li class="sub-nav-item" data-id="261505"><a href="//www.chinatimes.com/money/banking/" target="_self">金融</a></li>
# <li class="sub-nav-item" data-id="261511"><a href="//www.chinatimes.com/money/industry/" target="_self">產業</a></li>
# <li class="sub-nav-item" data-id="fight_economy"><a href="//www.chinatimes.com/album/fight_economy/20220120000002-262201" target="_self">疫起拚經濟</a></li>
# </ul>
# </div>
# </li>
# <li data-id="wantrich" class="main-nav-item">
# <a href="//wantrich.chinatimes.com/" target="_blank">股市</a>
# </li>
# <li data-id="world" class="main-nav-item">
# <a href="//www.chinatimes.com/world/" target="">國際</a>
# <div class="btn-toggle-sub-nav"><a href="javascript:;">展開子選單</a></div>
# <div class="sub-nav hide" id="menu_world">
# <ul class="sub-nav-item-group">
# <li class="sub-nav-item" data-id="index"><a href="//www.chinatimes.com/world/" target="_self">國際首頁</a></li>
# <li class="sub-nav-item" data-id="total"><a href="//www.chinatimes.com/world/total/" target="_self">總覽</a></li>
# <li class="sub-nav-item" data-id="261601"><a href="//www.chinatimes.com/world/report/" target="_self">政治圈</a></li>
# <li class="sub-nav-item" data-id="261604"><a href="//www.chinatimes.com/world/knowledge/" target="_self">開眼界</a></li>
# <li class="sub-nav-item" data-id="261609"><a href="//www.chinatimes.com/world/uselection/" target="_self">美大選</a></li>
# <li class="sub-nav-item" data-id="262203"><a href="//www.chinatimes.com/album/global/" target="_self">專輯</a></li>
# </ul>
# </div>
# </li>
# <li data-id="chinese" class="main-nav-item">
# <a href="//www.chinatimes.com/chinese/" target="">兩岸</a>
# <div class="btn-toggle-sub-nav"><a href="javascript:;">展開子選單</a></div>
# <div class="sub-nav hide" id="menu_chinese">
# <ul class="sub-nav-item-group">
# <li class="sub-nav-item" data-id="index"><a href="//www.chinatimes.com/chinese/" target="_self">兩岸首頁</a></li>
# <li class="sub-nav-item" data-id="total"><a href="//www.chinatimes.com/chinese/total/" target="_self">總覽</a></li>
# <li class="sub-nav-item" data-id="261701"><a href="//www.chinatimes.com/chinese/tidings/" target="_self">政經</a></li>
# <li class="sub-nav-item" data-id="261710"><a href="//www.chinatimes.com/chinese/cn-society/" target="_self">社會萬象</a></li>
# </ul>
# </div>
# </li>
# <li data-id="society" class="main-nav-item">
# <a href="//www.chinatimes.com/society/" target="">社會</a>
# <div class="btn-toggle-sub-nav"><a href="javascript:;">展開子選單</a></div>
# <div class="sub-nav hide" id="menu_society">
# <ul class="sub-nav-item-group">
# <li class="sub-nav-item" data-id="index"><a href="//www.chinatimes.com/society/" target="_self">社會首頁</a></li>
# <li class="sub-nav-item" data-id="total"><a href="//www.chinatimes.com/society/total/" target="_self">總覽</a></li>
# <li class="sub-nav-item" data-id="263202"><a href="//www.chinatimes.com/society/criminal/" target="_self">刑案</a></li>
# <li class="sub-nav-item" data-id="263206"><a href="//www.chinatimes.com/society/all/" target="_self">地方萬象</a></li>
# <li class="sub-nav-item" data-id="263208"><a href="//www.chinatimes.com/society/law/" target="_self">法庭中心</a></li>
# </ul>
# </div>
# </li>
# <li data-id="armament" class="main-nav-item">
# <a href="//www.chinatimes.com/armament/" target="">軍事</a>
# <div class="btn-toggle-sub-nav"><a href="javascript:;">展開子選單</a></div>
# <div class="sub-nav hide" id="menu_armament">
# <ul class="sub-nav-item-group">
# <li class="sub-nav-item" data-id="index"><a href="//www.chinatimes.com/armament/" target="_self">軍事首頁</a></li>
# <li class="sub-nav-item" data-id="total"><a href="//www.chinatimes.com/armament/total/" target="_self">總覽</a></li>
# <li class="sub-nav-item" data-id="262212"><a href="//www.chinatimes.com/album/album-military/" target="_self">專輯</a></li>
# </ul>
# </div>
# </li>
# <li data-id="technologynews" class="main-nav-item">
# <a href="//www.chinatimes.com/technologynews/" target="">科技</a>
# <div class="btn-toggle-sub-nav"><a href="javascript:;">展開子選單</a></div>
# <div class="sub-nav hide" id="menu_technologynews">
# <ul class="sub-nav-item-group">
# <li class="sub-nav-item" data-id="index"><a href="//www.chinatimes.com/technologynews/" target="_self">科技首頁</a></li>
# <li class="sub-nav-item" data-id="total"><a href="//www.chinatimes.com/technologynews/total/" target="_self">總覽</a></li>
# <li class="sub-nav-item" data-id="263402"><a href="//www.chinatimes.com/technologynews/tech-mobile/" target="_self">行動裝置</a></li>
# <li class="sub-nav-item" data-id="263404"><a href="//www.chinatimes.com/technologynews/tech-computer/" target="_self">電腦硬體</a></li>
# <li class="sub-nav-item" data-id="263405"><a href="//www.chinatimes.com/technologynews/tech-internet/" target="_self">網際網路</a></li>
# <li class="sub-nav-item" data-id="263408"><a href="//www.chinatimes.com/technologynews/tech-games/" target="_self">電玩娛樂</a></li>
# <li class="sub-nav-item" data-id="262210"><a href="//www.chinatimes.com/album/album-technology/" target="_self">專輯</a></li>
# </ul>
# </div>
# </li>
# <li data-id="sports" class="main-nav-item">
# <a href="//www.chinatimes.com/sports/" target="">體育</a>
# <div class="btn-toggle-sub-nav"><a href="javascript:;">展開子選單</a></div>
# <div class="sub-nav hide" id="menu_sports">
# <ul class="sub-nav-item-group">
# <li class="sub-nav-item" data-id="index"><a href="//www.chinatimes.com/sports/" target="_self">體育首頁</a></li>
# <li class="sub-nav-item" data-id="total"><a href="//www.chinatimes.com/sports/total/" target="_self">總覽</a></li>
# <li class="sub-nav-item" data-id="261310"><a href="//www.chinatimes.com/sports/golf/" target="_self">高爾夫</a></li>
# <li class="sub-nav-item" data-id="261306"><a href="//www.chinatimes.com/sports/baseball/" target="_self">棒球</a></li>
# <li class="sub-nav-item" data-id="261307"><a href="//www.chinatimes.com/sports/basketball/" target="_self">籃球</a></li>
# <li class="sub-nav-item" data-id="261308"><a href="//www.chinatimes.com/sports/soccer/" target="_self">足球</a></li>
# <li class="sub-nav-item" data-id="261312"><a href="//www.chinatimes.com/sports/others/" target="_self">其他</a></li>
# <li class="sub-nav-item" data-id="262204"><a href="//www.chinatimes.com/album/album-sports/" target="_self">專輯</a></li>
# <li class="sub-nav-item" data-id="261314"><a href="//www.chinatimes.com/sports/sporky/" target="_self">時來運轉</a></li>
# </ul>
# </div>
# </li>
# <li data-id="hottopic" class="main-nav-item">
# <a href="//www.chinatimes.com/hottopic/" target="">網推</a>
# <div class="btn-toggle-sub-nav"><a href="javascript:;">展開子選單</a></div>
# <div class="sub-nav hide" id="menu_hottopic">
# <ul class="sub-nav-item-group">
# <li class="sub-nav-item" data-id="index"><a href="//www.chinatimes.com/hottopic/" target="_self">網推首頁</a></li>
# <li class="sub-nav-item" data-id="total"><a href="//www.chinatimes.com/hottopic/total/" target="_self">總覽</a></li>
# <li class="sub-nav-item" data-id="260819"><a href="//www.chinatimes.com/hottopic/cutepet/" target="_self">萌寵</a></li>
# <li class="sub-nav-item" data-id="260809"><a href="//www.chinatimes.com/hottopic/funny-photo/" target="_self">搜奇</a></li>
# <li class="sub-nav-item" data-id="260812"><a href="//www.chinatimes.com/hottopic/history-photo/" target="_self">歷史</a></li>
# </ul>
# </div>
# </li>
# <li data-id="tube" class="main-nav-item">
# <a href="//www.chinatimes.com/tube/" target="">有影</a>
# <div class="btn-toggle-sub-nav"><a href="javascript:;">展開子選單</a></div>
# <div class="sub-nav hide" id="menu_tube">
# <ul class="sub-nav-item-group">
# <li class="sub-nav-item" data-id="index"><a href="//www.chinatimes.com/tube/" target="_self">有影首頁</a></li>
# <li class="sub-nav-item" data-id="total"><a href="//www.chinatimes.com/tube/tubetotal/" target="_self">總覽</a></li>
# <li class="sub-nav-item" data-id="tube-ctinews"><a href="//www.chinatimes.com/tube-ctinews/" target="_self">中天新聞</a></li>
# <li class="sub-nav-item" data-id="tube-ctvnews"><a href="//www.chinatimes.com/tube-ctvnews/" target="_self">中視新聞</a></li>
# <li class="sub-nav-item" data-id="tube-politic"><a href="//www.chinatimes.com/tube-politic/" target="_self">政新鮮</a></li>
# <li class="sub-nav-item" data-id="tube-streetspeaker"><a href="//www.chinatimes.com/tube-streetspeaker/" target="_self">街頭大聲公</a></li>
# <li class="sub-nav-item" data-id="tube-funfan"><a href="//www.chinatimes.com/tube-funfan/" target="_self">玩FUN飯</a></li>
# <li class="sub-nav-item" data-id="tube-victory"><a href="//www.chinatimes.com/tube-victory/" target="_self">旗開得勝</a></li>
# <li class="sub-nav-item" data-id="tube-awakening"><a href="//www.chinatimes.com/opinion/awakening/" target="_self">無色覺醒</a></li>
# <li class="sub-nav-item" data-id=""><a href="http://hyperurl.co/cttube" target="_blank" rel="noopener">追劇</a></li>
# </ul>
# </div>
# </li>
# <li data-id="health" class="main-nav-item">
# <a href="//www.chinatimes.com/health/" target="">健康</a>
# <div class="btn-toggle-sub-nav"><a href="javascript:;">展開子選單</a></div>
# <div class="sub-nav hide" id="menu_health">
# <ul class="sub-nav-item-group">
# <li class="sub-nav-item" data-id="index"><a href="//www.chinatimes.com/health/" target="_self">健康首頁</a></li>
# <li class="sub-nav-item" data-id="total"><a href="//www.chinatimes.com/health/total/" target="_self">總覽</a></li>
# <li class="sub-nav-item" data-id="263504"><a href="//www.chinatimes.com/health/health-news/" target="_self">新聞快遞</a></li>
# <li class="sub-nav-item" data-id="263506"><a href="//www.chinatimes.com/health/health-doctor/" target="_self">名醫名家</a></li>
# <li class="sub-nav-item" data-id="263507"><a href="//www.chinatimes.com/health/health-regimen/" target="_self">養生健體</a></li>
# <li class="sub-nav-item" data-id="263508"><a href="//www.chinatimes.com/health/health-book/" target="_self">醫病百科</a></li>
# <li class="sub-nav-item" data-id="263511"><a href="//www.chinatimes.com/health/health-traditional/" target="_self">中醫健康</a></li>
# <li class="sub-nav-item" data-id="263509"><a href="//www.chinatimes.com/health/health-soul/" target="_self">心靈關係</a></li>
# <li class="sub-nav-item" data-id="262214"><a href="//www.chinatimes.com/album/album-health/" target="_self">健康專輯</a></li>
# <li class="sub-nav-item" data-id="262211"><a href="//www.chinatimes.com/album/health_plan/20210511004690-262211" target="_self">健康規劃局</a></li>
# </ul>
# </div>
# </li>
# <li data-id="fortune" class="main-nav-item">
# <a href="//www.chinatimes.com/fortune/" target="">運勢</a>
# <div class="btn-toggle-sub-nav"><a href="javascript:;">展開子選單</a></div>
# <div class="sub-nav hide" id="menu_fortune">
# <ul class="sub-nav-item-group">
# <li class="sub-nav-item" data-id="index"><a href="//www.chinatimes.com/fortune/" target="_self">運勢首頁</a></li>
# <li class="sub-nav-item" data-id="total"><a href="//www.chinatimes.com/fortune/total/" target="_self">總覽</a></li>
# <li class="sub-nav-item" data-id="264601"><a href="//www.chinatimes.com/fortune/fortune-astrology/" target="_self">星座</a></li>
# <li class="sub-nav-item" data-id="264602"><a href="//www.chinatimes.com/fortune/shengxiao/" target="_self">生肖</a></li>
# <li class="sub-nav-item" data-id="264603"><a href="//www.chinatimes.com/fortune/fengshui/" target="_self">風水</a></li>
# </ul>
# </div>
# </li>
# <li data-id="taiwan" class="main-nav-item">
# <a href="//www.chinatimes.com/taiwan/" target="">寶島</a>
# <div class="btn-toggle-sub-nav"><a href="javascript:;">展開子選單</a></div>
# <div class="sub-nav hide" id="menu_taiwan">
# <ul class="sub-nav-item-group">
# <li class="sub-nav-item" data-id="index"><a href="//www.chinatimes.com/taiwan/" target="_self">寶島首頁</a></li>
# <li class="sub-nav-item" data-id="total"><a href="//www.chinatimes.com/taiwan/total/" target="_self">總覽</a></li>
# <li class="sub-nav-item" data-id="264201"><a href="//www.chinatimes.com/taiwan/taipei/" target="_self">台北基宜花</a></li>
# <li class="sub-nav-item" data-id="264202"><a href="//www.chinatimes.com/taiwan/newtaipei/" target="_self">新北金馬</a></li>
# <li class="sub-nav-item" data-id="264203"><a href="//www.chinatimes.com/taiwan/taoyuan/" target="_self">桃園竹苗</a></li>
# <li class="sub-nav-item" data-id="264204"><a href="//www.chinatimes.com/taiwan/taichung/" target="_self">台中彰投</a></li>
# <li class="sub-nav-item" data-id="264205"><a href="//www.chinatimes.com/taiwan/tainan/" target="_self">台南雲嘉</a></li>
# <li class="sub-nav-item" data-id="264206"><a href="//www.chinatimes.com/taiwan/kaohsiung/" target="_self">高雄屏東澎</a></li>
# <li class="sub-nav-item" data-id="264230"><a href="//www.chinatimes.com/taiwan/taiwan-loveparents/" target="_self">孝親報報</a></li>
# </ul>
# </div>
# </li>
# <li data-id="autos" class="main-nav-item">
# <a href="https://autos.chinatimes.com/" target="_blank" rel="noopener">汽車</a>
# </li>
# <li data-id="housenews" class="main-nav-item">
# <a href="https://house.chinatimes.com/" target="_blank" rel="noopener">房產</a>
# </li>
# </ul>
# </nav>
# <div class="gradient-mask"></div>
# </div>
#
# <script src="https://static.chinatimes.com/scripts/nav2019.min.js?20220707"></script>
#
#
# <nav aria-label="breadcrumb" class="breadcrumb-wrapper">
# <ol itemscope itemtype="https://schema.org/BreadcrumbList" class="breadcrumb">
# <li itemprop="itemListElement" itemscope itemtype="https://schema.org/ListItem" class="breadcrumb-item">
# <a itemtype="https://schema.org/Thing" itemprop="item" class="text-dark" href="/"><span itemprop="name">首頁</span></a><meta itemprop="position" content="1" />
# </li>
# <li itemprop="itemListElement" itemscope itemtype="https://schema.org/ListItem" class="breadcrumb-item">
# <a itemtype="https://schema.org/Thing" itemprop="item" class="text-dark" href="/money"><span itemprop="name">財經</span></a><meta itemprop="position" content="2" />
# </li>
# </ol>
# </nav>
#
# </div>
#
# <div class="row">
# <div class="col">
# <div class="article-wrapper">
# <article class="article-box">
#
# <header class="article-header">
#
# <h1 class="article-title">《通信網路》宏達電VIVE Arts再當藝術咖 前進倫敦蛇形藝廊</h1>
#
# <div class="row align-items-center">
# <div class="col-md">
#
# <div class="meta-info-wrapper">
# <div class="meta-info">
# <time datetime="2022-04-15 14:48"><span class="hour">14:48</span><span class="date">2022/04/15</span></time>
# <div class="source">時報資訊</div>
# <div class="author">
# <a href="/reporter/1111">王逸芯</a>
# </div>
# </div>
# </div>
#
# </div>
# <div class="col-md-auto">
#
# <div class="social-share">
# <ul>
# <li class="facebook"><a href="javascript:;" class="facebook" title="分享至臉書">Facebook</a></li>
# <li class="messenger"><a href="javascript:;" class="messenger" title="分享至Messenger">Messenger</a></li>
# <li class="line"><a href="javascript:;" class="line" title="分享至Line">Line</a></li>
# <li class="weibo"><a href="javascript:;" class="weibo" title="分享至微博">Weibo</a></li>
# <li class="twitter"><a href="javascript:;" class="twitter" title="分享至Twitter">Twitter</a></li>
# <li class="telegram"><a href="javascript:;" class="telegram" title="分享至Telegram">Telegram</a></li>
# <li class="copy-url"><a href="javascript:;" class="copy-url" title="複製連結">複製連結</a></li>
# </ul>
# </div>
#
# </div>
# </div>
# </header>
#
#
# <div class="main-figure">
# <p></p>
# </div>
#
# <div class="row">
# <div class="d-none d-xl-block col-xl-1">
#
# <div class="social-share-wrapper">
# <div class="social-share fixed">
# <ul>
# <li class="facebook"><a href="javascript:;" class="facebook" title="分享至臉書">Facebook</a></li>
# <li class="messenger"><a href="javascript:;" class="messenger" title="分享至Messenger">Messenger</a></li>
# <li class="line"><a href="javascript:;" class="line" title="分享至Line">Line</a></li>
#  <li class="weibo"><a href="javascript:;" class="weibo" title="分享至微博">Weibo</a></li>
# <li class="twitter"><a href="javascript:;" class="twitter" title="分享至Twitter">Twitter</a></li>
# <li class="telegram"><a href="javascript:;" class="telegram" title="分享至Telegram">Telegram</a></li>
# <li class="copy-url"><a href="javascript:;" class="copy-url" title="複製連結">複製連結</a></li>
# </ul>
# </div>
# </div>
#
# </div>
# <div class="col-xl-11">
#
# <div class="article-function">
# <div class="font-size-setting">
# <span class="title">字級設定：</span><a href="javascript:;" data-font-size="18px" class="active">小</a><a href="javascript:;" data-font-size="20px">中</a><a href="javascript:;" data-font-size="22px">大</a><a href="javascript:;" data-font-size="24px">特</a>
# </div>
# </div>
#
#
# <div class="article-body" itemprop="articleBody">
# <p>宏達電(2498)宣布，旗下藝術創新團隊VIVE Arts將再度與知名法國藝術家多米妮克.岡薩雷斯-福斯特(Dominique Gonzalez-Foerster)聯手合作，擔任其將於倫敦蛇形藝廊(Serpentine)隆重登場的全新個展「Alienarium 5」的官方虛擬實境夥伴。</p>
# <p></p>
# <p></p>
# <p></p>
# <p>VIVE Arts是一家全球性的藝術與科技企業，主要是在為數位藝術孕育豐富的生態系，讓藝術家得以透過VR、XR和元宇宙技術來展示創意理念。《Alienarium》是岡薩雷斯-福斯特第二件由VIVE Arts委託製作、以及Lucid Realities開發的VR作品；第一件為2019年於威尼斯雙年展亮相的《Endodrome》。《Alienarium》將嘗試以VR為媒介，連結虛擬與真實世界，在僅能存在於虛擬世界般的想像空間、空幻情境中，感受靈魂出竅的體驗。訪客戴上VIVE Pro後，將置身斑斕繽紛的深度空間環境，在此與外星生命相遇，並與外星生命發光的抽象形體合而為一。岡薩雷斯-福斯特所設計的環境每次可供五人同時體驗，營造兼具私密與社交的體驗，訪客能夠以嶄新形式與外星人互動、與他人交流。</p>
#
# <div class="ad rwd with-placeholder" data-id="mobile-top-banner">
# <div class="banner-300x250 top-banner placeholder">
# <div id="div-gpt-ad-1590732299155-0"></div>
# </div>
# </div>
#
# <p></p>
# <p>VIVE Arts總監葉心宇表示，VIVE Arts的宗旨是鼓勵視覺藝術家探索數位技術的無限可能，重新定義藝術與文化的體驗方式。我們很榮幸能與蛇形藝廊合作舉辦此次精采的沉浸式展覽，也很榮幸能與多米妮克.岡薩雷斯-福斯特再續合作前緣，將她大膽、奇想的與外星生命相遇連結的抽象概念轉化為虛擬實境。多米妮克著名的特色是以對不同型態的意識、主觀性、以及人體與空間的感官關聯性上進行探索，並不斷創新突破界限。多米妮克運用VR的手法充滿巧思和實驗性質，她活用VR包羅萬象的潛力，開創新境界並建立連結，為每位觀眾帶來獨一無二的強大體驗。」</p>
# <p></p>
# <p>宏達電表示，本次個展「Alienarium 5」展期為4月14日至9月4日，是其自2008年於泰德當代美術館(Tate Modern)渦輪大廳(Turbine Hall)之「TH.2058」展覽以來，首度在英國重要藝術機構蛇形藝廊(Serpentine)舉辦的大型個展。</p>
#
# <div class="ad rwd with-placeholder" data-id="mobile-middle-banner">
# <div class="underlay-auto-scale" data-size="320x480" data-media-type="adsense">
# <div class="clip-container">
# <div class="position-container">
# <div class="size-container placeholder">
#
# <div id="div-gpt-ad-1590732428465-0"></div>
#
# </div>
# </div>
# </div>
# </div>
# </div>
#
# <p></p>
# <p></p>
#
# <div class="promote-word"><a href="https://www.chinatimes.com/newspapers/20220418000340-260107">新故鄉願景》紅土的故鄉 海風里農村再生一次玩個夠</a></div>
#
#
# <div class="promote-word"><a href="https://www.chinatimes.com/realtimenews/20220416001253-260410">《通信網路》月租加價百元有找 台灣大邀用戶體驗5G</a></div>
#
#
# <div class="promote-word"><a href="https://www.chinatimes.com/realtimenews/20220419000006-260421">雜誌精選》前進元宇宙 高雄虛擬平行世界全面啟動</a></div>
#
#
# <div class="ad rwd">
# <div class="banner-text">
# <div id="div-gpt-ad-1603262317858-0"></div>
# </div>
# </div>
#
#
# <div class="article-hash-tag">
# <span class="hash-tag"><span class="hash-tag-label">#</span><a href="/Search/VIVEArts">VIVEArts</a></span>
# <span class="hash-tag"><span class="hash-tag-label">#</span><a href="/Search/VR">VR</a></span>
# <span class="hash-tag"><span class="hash-tag-label">#</span><a href="/Search/體驗">體驗</a></span>
# <span class="hash-tag"><span class="hash-tag-label">#</span><a href="/Search/藝廊">藝廊</a></span>
# <span class="hash-tag"><span class="hash-tag-label">#</span><a href="/Search/妮克">妮克</a></span>
# </div>
#
#
# <div class="ad rwd with-placeholder" data-id="mobile-end-banner-1st">
# <div class="banner-300x250 placeholder">
# <div id="div-gpt-ad-1551201747632-4"></div>
# </div>
# </div>
#
# </div>
#
# </div>
# </div>
#
# <div class="prev-next-content">
# <div class="row no-gutters">
# <div class="col-md">
# </div>
# <div class="col-md">
# </div>
# </div>
# </div>
#
#
# <section class="dable-recommend popin-recommend taboola-recommend">
# <header>
# <h4 class="section-title">也許您會感興趣</h4>
# </header>
#
# <div id="_popIn_recommend"></div>
#
#
# <div id="dablewidget_jobx06lW_37JP6eXN" data-widget_id-pc="jobx06lW" data-widget_id-mo="37JP6eXN"></div>
#
#
# <div id="taboola-below-article-thumbnails"></div>
#
# </section>
#
#
# <div class="subscribe-news-letter" data-from="ct_mweb_detail_1"></div>
#
#
# <section class="dable-recommend popin-recommend others-are-watching">
# <header>
# <h4 class="section-title">其他人正在看</h4>
# </header>
#
# <div id="_popIn_recommend_additional"></div>
#
#
# <div id="dablewidget_G7ZaxwoW_6oMJNG7b" data-widget_id-pc="G7ZaxwoW" data-widget_id-mo="6oMJNG7b"></div>
#
# </section>
#
#
# <div class="ad rwd" data-id="mobile-end-banner-2nd">
# <div class="banner-300x250">
# <div id="div-gpt-ad-1551201747632-5"></div>
# </div>
# </div>
#
#
# <section id="recommended-article" class="recommended-article">
# <header>
# <h4 class="section-title">推薦閱讀</h4>
# </header>
# <ul class="vertical-list list-style-none">
# <li class="row" data-id="recommended-article-1">
# <div class="col-3 col-md-2 col-lg-3 col-xl-2 thumb-photo-wrapper">
# <div class="thumb-photo">
# <div class="cropper">
# <a href="https://www.chinatimes.com/realtimenews/20220415004457-260405"><img src="https://images.chinatimes.com/newsphoto/2022-04-15/330/20220415004458.jpg" class="photo" loading="lazy" alt="埔里鎮推「我的菇菇好可愛」食農教育 香菇寮新體驗"></a>
# </div>
# </div>
# </div>
# <div class="col">
# <h4 class="title"><a href="https://www.chinatimes.com/realtimenews/20220415004457-260405">埔里鎮推「我的菇菇好可愛」食農教育 香菇寮新體驗</a></h4>
# <div class="meta-info">
# <time datetime="2022-04-15 18:06"><span class="hour">18:06</span><span class="date">2022/04/15</span></time>
# <div class="category"><a href="/realtimenews/260405">生活</a></div>
# </div>
# </div>
# </li>
# <li class="row" data-id="recommended-article-2">
# <div class="col-3 col-md-2 col-lg-3 col-xl-2 thumb-photo-wrapper">
# <div class="thumb-photo">
# <div class="cropper">
# <a href="https://autos.chinatimes.com/20220420004000-264301"><img src="https://images.chinatimes.com/newsphoto/2022-04-20/330/20220420004027.jpg" class="photo" loading="lazy" alt="LEXUS ELECTRIFIED品牌概念店                      體驗豪華電能移動新篇章 多元豐富活動即日展開"></a>
# </div>
# </div>
# </div>
# <div class="col">
# <h4 class="title"><a href="https://autos.chinatimes.com/20220420004000-264301">LEXUS ELECTRIFIED品牌概念店 體驗豪華電能移動新篇章 多元豐富活動即日展開</a></h4>
# <div class="meta-info">
# <time datetime="2022-04-20 15:59"><span class="hour">15:59</span><span class="date">2022/04/20</span></time>
# <div class="category"><a href="#">汽車情報-汽車新聞</a></div>
# </div>
# </div>
# </li>
# <li class="row" data-id="recommended-article-3">
# <div class="col">
# <h4 class="title"><a href="https://www.chinatimes.com/realtimenews/20220421003399-260410">《電腦設備》利多難撐 微星險守短均</a></h4>
# <div class="meta-info">
# <time datetime="2022-04-21 14:40"><span class="hour">14:40</span><span class="date">2022/04/21</span></time>
# <div class="category"><a href="/realtimenews/260410">財經</a></div>
# </div>
# </div>
# </li>
# <li class="row" data-id="recommended-article-4">
# <div class="col-3 col-md-2 col-lg-3 col-xl-2 thumb-photo-wrapper">
# <div class="thumb-photo">
# <div class="cropper">
# <a href="https://www.chinatimes.com/realtimenews/20220415002661-260405"><img src="https://images.chinatimes.com/newsphoto/2022-04-15/330/20220415002662.jpg" class="photo" loading="lazy" alt="微光馬祖／追尋浪漫藍眼淚"></a>
# </div>
# </div>
# </div>
# <div class="col">
#  <h4 class="title"><a href="https://www.chinatimes.com/realtimenews/20220415002661-260405">微光馬祖／追尋浪漫藍眼淚</a></h4>
# <div class="meta-info">
# <time datetime="2022-04-15 13:31"><span class="hour">13:31</span><span class="date">2022/04/15</span></time>
# <div class="category"><a href="/realtimenews/260405">生活</a></div>
# </div>
# </div>
# </li>
# <li class="row" data-id="recommended-article-5">
# <div class="col-3 col-md-2 col-lg-3 col-xl-2 thumb-photo-wrapper">
# <div class="thumb-photo">
# <div class="cropper">
# <a href="https://autos.chinatimes.com/20220418003231-264301"><img src="https://images.chinatimes.com/newsphoto/2022-04-18/330/20220418003241.jpg" class="photo" loading="lazy" alt="福斯商旅與 KKday 共推 “ Hotel California ” 不思議車宿體驗"></a>
# </div>
# </div>
# </div>
# <div class="col">
# <h4 class="title"><a href="https://autos.chinatimes.com/20220418003231-264301">福斯商旅與 KKday 共推 “ Hotel California ” 不思議車宿體驗</a></h4>
# <div class="meta-info">
# <time datetime="2022-04-18 16:24"><span class="hour">16:24</span><span class="date">2022/04/18</span></time>
# <div class="category"><a href="#">汽車情報-汽車新聞</a></div>
# </div>
# </div>
# </li>
# <li class="row" data-id="recommended-article-6">
# <div class="col-3 col-md-2 col-lg-3 col-xl-2 thumb-photo-wrapper">
# <div class="thumb-photo">
# <div class="cropper">
# <a href="https://www.chinatimes.com/newspapers/20220419000548-260107"><img src="https://images.chinatimes.com/newsphoto/2022-04-19/330/B10A00_P_03_02.jpg" class="photo" loading="lazy" alt="天文旅遊結合手作 花蓮創皂亮點"></a>
# </div>
# </div>
# </div>
# <div class="col">
# <h4 class="title"><a href="https://www.chinatimes.com/newspapers/20220419000548-260107">天文旅遊結合手作 花蓮創皂亮點</a></h4>
# <div class="meta-info">
# <time datetime="2022-04-19 04:10"><span class="hour">04:10</span><span class="date">2022/04/19</span></time>
# <div class="category"><a href="/newspapers/260107">地方新聞</a></div>
# </div>
# </div>
# </li>
# <li class="row" data-id="recommended-article-7">
# <div class="col-3 col-md-2 col-lg-3 col-xl-2 thumb-photo-wrapper">
# <div class="thumb-photo">
# <div class="cropper">
# <a href="https://www.chinatimes.com/newspapers/20220419000201-260205"><img src="https://images.chinatimes.com/newsphoto/2022-04-19/330/A12A00_P_06_02.jpg" class="photo" loading="lazy" alt="微軟Teams認證 Neat打造視訊會議新體驗"></a>
# </div>
# </div>
# </div>
# <div class="col">
# <h4 class="title"><a href="https://www.chinatimes.com/newspapers/20220419000201-260205">微軟Teams認證 Neat打造視訊會議新體驗</a></h4>
# <div class="meta-info">
# <time datetime="2022-04-19 04:10"><span class="hour">04:10</span><span class="date">2022/04/19</span></time>
# <div class="category"><a href="/newspapers/260205">金融．稅務</a></div>
# </div>
# </div>
# </li>
# <li class="row" data-id="recommended-article-8">
# <div class="col-3 col-md-2 col-lg-3 col-xl-2 thumb-photo-wrapper">
# <div class="thumb-photo">
# <div class="cropper">
# <a href="https://www.chinatimes.com/realtimenews/20220418002684-260421"><img src="https://images.chinatimes.com/newsphoto/2022-04-18/330/20220418002685.jpg" class="photo" loading="lazy" alt="八仙山森林系沉浸式體驗 帶您尋找命定香"></a>
# </div>
# </div>
# </div>
# <div class="col">
# <h4 class="title"><a href="https://www.chinatimes.com/realtimenews/20220418002684-260421">八仙山森林系沉浸式體驗 帶您尋找命定香</a></h4>
# <div class="meta-info">
# <time datetime="2022-04-18 15:33"><span class="hour">15:33</span><span class="date">2022/04/18</span></time>
# <div class="category"><a href="/realtimenews/260421">寶島</a></div>
# </div>
# </div>
# </li>
# <li class="row" data-id="recommended-article-9">
# <div class="col-3 col-md-2 col-lg-3 col-xl-2 thumb-photo-wrapper">
# <div class="thumb-photo">
# <div class="cropper">
# <a href="https://www.chinatimes.com/newspapers/20220419000205-260204"><img src="https://images.chinatimes.com/newsphoto/2022-04-19/330/A13A00_P_01_01.jpg" class="photo" loading="lazy" alt="Touch Taiwan 面板雙虎大拚場"></a>
# </div>
# </div>
# </div>
# <div class="col">
# <h4 class="title"><a href="https://www.chinatimes.com/newspapers/20220419000205-260204">Touch Taiwan 面板雙虎大拚場</a></h4>
# <div class="meta-info">
# <time datetime="2022-04-19 04:10"><span class="hour">04:10</span><span class="date">2022/04/19</span></time>
# <div class="category"><a href="/newspapers/260204">產業．科技</a></div>
# </div>
# </div>
# </li>
# <li class="row" data-id="recommended-article-10">
# <div class="col-3 col-md-2 col-lg-3 col-xl-2 thumb-photo-wrapper">
# <div class="thumb-photo">
# <div class="cropper">
# <a href="https://www.chinatimes.com/realtimenews/20220421002381-260405"><img src="https://images.chinatimes.com/newsphoto/2022-04-21/330/20220421002382.jpg" class="photo" loading="lazy" alt="東浪嘉年華5／14起連嗨15天 邀民眾體驗杉原灣魅力"></a>
# </div>
# </div>
# </div>
# <div class="col">
# <h4 class="title"><a href="https://www.chinatimes.com/realtimenews/20220421002381-260405">東浪嘉年華5／14起連嗨15天 邀民眾體驗杉原灣魅力</a></h4>
# <div class="meta-info">
# <time datetime="2022-04-21 11:46"><span class="hour">11:46</span><span class="date">2022/04/21</span></time>
# <div class="category"><a href="/realtimenews/260405">生活</a></div>
# </div>
# </div>
# </li>
# </ul>
# </section>
#
#
#
# <section class="hot-news">
# <header>
# <h4 class="section-title">財經熱門新聞</h4>
# </header>
# <ol class="vertical-list"></ol>
# </section>
#
#
# <section id="comments" class="comments">
# <header>
# <h4 class="section-title">發表意見</h4>
# </header>
# <div class="comment-rules-wrapper">
# <div class="text-right">
# <a class="btn btn-outline-secondary comment-rules-button" href="javascript:;" role="button" data-toggle="collapse" data-target="#comment-rules" aria-expanded="false" aria-controls="comment-rules">留言規則</a>
# </div>
# <div class="collapse comment-rules" id="comment-rules">
# <div class="card card-body">
# <p><strong>中時新聞網對留言系統使用者發布的文字、圖片或檔案保有片面修改或移除的權利。當使用者使用本網站留言服務時，表示已詳細閱讀並完全了解，且同意配合下述規定：</strong></p>
# <ul>
# <li>請勿重覆刊登一樣的文章，或大意內容相同、類似的文章</li>
# <li>請不要刊登與主題無相關之內容</li>
# <li>發言涉及攻擊、侮辱、影射或其他有違社會善良風俗、社會正義、國家安全、政府法令之內容，本網站將會直接移除</li>
# <li>請勿以發文、回文等方式，進行商業廣告、騷擾網友等行為，或是為特定網站、blog宣傳，一經發現，將會限制您的發言權限或者封鎖帳號</li>
# <li>為避免留言系統變成發洩區和口水版，請勿轉貼新聞性文章、報導或相關連結</li>
# <li>請勿提供軟體註冊碼等違反智慧財產權之資訊</li>
# <li>禁止發表涉及他人隱私、含有個人對公眾人物之私評，且未經證實、未註明消息來源的網路八卦、不實謠言等</li>
# <li>請確認發表或回覆的內容（圖片）未侵害到他人的著作權、商標、專利等權利；若因發表或回覆內容而產生的版權法律責任將由使用者自行承擔，不代表中時新聞網的立場，請遵守相關法律規範</li>
# </ul>
# <p><strong>違反上述規定者，中時新聞網有權刪除留言，或者直接封鎖帳號！請使用者在發言前，務必先閱讀留言板規則，謝謝配合。</strong></p>
# </div>
# </div>
# </div>
# <div class="fb-comments" data-href="https://www.chinatimes.com/realtimenews/20220415003322-260410" data-numposts="5" data-order-by="reverse_time" data-width="100%"></div>
# </section>
#
# </article>
# </div>
# </div>
# </div>
# </div>
#
# <footer class="main-footer"></footer>
#
# </div>
#
# <div class="ad rwd">
# <div class="banner-sticky-320x100">
# <div class="size-container">
# <div id="div-gpt-ad-1551201747632-6"></div>
# </div>
# <div class="btn-close"><a href="javascript:;">關閉</a></div>
# </div>
# </div>
#
# <div class="gotop"><a href="#page-top" class="btn-gotop">回到頁首</a><a href="#comments" class="btn-goto-comments">發表意見</a></div>
#
# <script src="https://static.chinatimes.com/libs/jqueryui/1.13.1/jquery-ui.min.js"></script>
# <script src="https://static.chinatimes.com/scripts/jquery.query.min.js?20220324"></script>
# <script src="https://static.chinatimes.com/scripts/vertical-marquee/scripts/jquery.vertical-marquee.min.js?20220616"></script>
# <script src="https://static.chinatimes.com/scripts/adaptive-gallery/scripts/jquery.adaptive-gallery.min.js?20220616"></script>
# <script src="https://static.chinatimes.com/scripts/owl-carousel-v2.34/owl.carousel.min.js"></script>
# <script src="https://static.chinatimes.com/scripts/common-scriptsch.min.js?20220324"></script>
# <script src="https://static.chinatimes.com/scripts/2019/tab-pane2019.min.js?20191220"></script>
# <script src="https://static.chinatimes.com/scripts/likr.js?20210716"></script>
# <script src="https://static.chinatimes.com/scripts/2020/subscribe-news-letter-prompt2020.min.js?20210804"></script>
#
# <script src="https://static.chinatimes.com/scripts/footer2019.min.js?20220331"></script>
#
# <script src="https://static.chinatimes.com/scripts/2019/common-scripts2019.min.js?20210428"></script>
# <script src="https://static.chinatimes.com/scripts/2019/ad2019.min.js?20220304"></script>
#
#
# <script src="https://static.chinatimes.com/scripts/2019/social-share2019.min.js?20200302a"></script>
# <script src="https://static.chinatimes.com/scripts/2019/article-function2019.min.js"></script>
# <script src="https://apis.google.com/js/platform.js"></script>
#
# <script async src="https://static.chinatimes.com/scripts/prebid.min.js?20210802"></script>
# <script>
#             var PREBID_TIMEOUT = 800;
#             var FAILSAFE_TIMEOUT = 1500;
#             var adUnits = [{ //Mobile浮水印
#                 code: "/81206261/20_Chinatimes_Mobile/CP/20C_Mobile_StickyAd",
#                 mediaTypes: {
#                     banner: {
#                         sizes: [
#                             [320, 50],
#                             [320, 100]
#                         ]
#                     }
#                 },
#                 bids: [{
#                     bidder: "aol",
#                     params: {
#                         dcn: "8a96946d0178788462e186e30dc50032",
#                         pos: "mobile_leaderboard_and_large_banner"
#                     }
#                 },
#                 {
#                     bidder: "appier",
#                     params: {
#                         hzid: "mhV6HzOZ"
#                     }
#                 },
#                 {
#                     bidder: "bridgewell",
#                     params: {
#                         cid: 18760
#                     }
#                 },
#                 {
#                     bidder: "criteo",
#                     params: {
#                         networkId: 4132
#                     }
#                 }
#                 ]
#             },
#             { //Mobile 內頁TOP Banner
#                 code: "/81206261/20_Chinatimes_Mobile/CP/20C_Mobile_TopBannerN",
#                 mediaTypes: {
#                     banner: {
#                         sizes: [300, 250]
#                     }
#                 },
#                 bids: [{
#                     bidder: "aol",
#                     params: {
#                         dcn: "8a96946d0178788462e186e30dc50032",
#                         pos: "mobile_inner_top_banner_mrec"
#                     }
#                 },
#                 {
#                     bidder: "appier",
#                     params: {
#                         hzid: "mhV6HIOZ"
#                     }
#                 },
#                 {
#                     bidder: "bridgewell",
#                     params: {
#                         cid: 18761
#                     }
#                 },
#                 {
#                     bidder: "criteo",
#                     params: {
#                         networkId: 4132
#                     }
#                 },
#                 {
#                     bidder: "clickforce",
#                     params: {
#                         zone: 12561
#                     }
#                 }
#                 ]
#             },
#             { //Mobile文中Banner
#                 code: "/81206261/20_Chinatimes_Mobile/CP/20C_Mobile_MiddleBannerN",
#                 mediaTypes: {
#                     banner: {
#                         sizes: [320, 480]
#                     }
#                 },
#                 bids: [{
#                     bidder: "aol",
#                     params: {
#                         dcn: "8a96946d0178788462e186e30dc50032",
#                         pos: "mobile_inarticle_interstitial"
#                     }
#                 },
#                 {
#                     bidder: "appier",
#                     params: {
#                         hzid: "mhV6HFOZ"
#                     }
#                 },
#                 {
#                     bidder: "bridgewell",
#                     params: {
#                         cid: 18762
#                     }
#                 },
#                 {
#                     bidder: "criteo",
#                     params: {
#                         networkId: 4132
#                     }
#                 }
#                 ]
#             },
#             { //Mobile文末Banner
#                 code: "/81206261/20_Chinatimes_Mobile/CP/20C_Mobile_EndBanner_1st",
#                 mediaTypes: {
#                     banner: {
#                         sizes: [300, 250]
#                     }
#                 },
#                 bids: [{
#                     bidder: "aol",
#                     params: {
#                         dcn: "8a96946d0178788462e186e30dc50032",
#                         pos: "mobile_article_bottom_mrec"
#                     }
#                 },
#                 {
#                     bidder: "appier",
#                     params: {
#                         hzid: "mhV6m9OZ"
#                     }
#                 },
#                 {
#                     bidder: "bridgewell",
#                     params: {
#                         cid: 18782
#                     }
#                 },
#                 {
#                     bidder: "criteo",
#                     params: {
#                         networkId: 4132
#                     }
#                 },
#                 {
#                     bidder: "clickforce",
#                     params: {
#                         zone: 12562
#                     }
#                 }
#                 ]
#             }
#             ];
#             var initAdserver = function () {
#                 if (pbjs.initAdserverSet) return;
#                 pbjs.initAdserverSet = true;
#                 googletag.cmd.push(function () {
#                     pbjs.que.push(function () {
#                         pbjs.setTargetingForGPTAsync();
#                         googletag.pubads().refresh();
#                     });
#                 });
#             };
#             var googletag = googletag || {};
#             var pbjs = pbjs || {};
#             googletag.cmd = googletag.cmd || [];
#             googletag.cmd.push(function () {
#                 googletag.pubads().disableInitialLoad();
#             });
#             pbjs.que = pbjs.que || [];
#             pbjs.que.push(function () {
#                 pbjs.addAdUnits(adUnits);
#                 pbjs.setConfig({
#                     appier: {
#                         farm: "tw"
#                     }
#                 });
#                 pbjs.requestBids({
#                     bidsBackHandler: initAdserver,
#                     timeout: PREBID_TIMEOUT
#                 });
#             });
#             // in case PBJS doesn't load
#             setTimeout(function () {
#                 initAdserver();
#             }, FAILSAFE_TIMEOUT);
#         </script>
#
# <script>
#                 //定義DFP非同步廣告版位
#                 var ctFirstTimeToEnterSite = $.cookie("ctFirstTimeToEnterSite"),
#                     isInAppBrowser = (function () {
#                         var ua = navigator.userAgent,
#                             vendors = {
#                                 "facebook": "FBAV",
#                                 "line": "Line"
#                             },
#                             key;
#                         for (key in vendors) {
#                             if (ua.indexOf(vendors[key]) > -1) {
#                                 return true;
#                             }
#                         }
#                         return false;
#                     })();
#                 if (ctFirstTimeToEnterSite === undefined) {
#                     $.cookie("ctFirstTimeToEnterSite", "false", {
#                         "path": "/",
#                         "expires": 5 / (24 * 60)
#                     });
#                 }
#             googletag.cmd.push(function () {
#                 (function () {
#                     var interstitialSlot = googletag.defineOutOfPageSlot("/81206261/20_Chinatimes_Mobile/CP/20C_Mobile_INTERSTITIAL", googletag.enums.OutOfPageFormat.INTERSTITIAL);
#                     if (interstitialSlot) {
#                         interstitialSlot.addService(googletag.pubads());
#                         googletag.pubads().addEventListener("slotOnload", function (event) {
#                             var interstitialCallback,
#                                 interstitialObserver;
#                             if (interstitialSlot === event.slot) {
#                                 interstitialCallback = function (entries) {
#                                     $.each(entries, function (i, entry) {
#                                         if (entry.isIntersecting) {
#                                             $.removeCookie("ctFirstTimeToEnterSite", {
#                                                 "path": "/"
#                                             });
#                                         }
#                                     });
#                                 };
#                                 interstitialObserver = new IntersectionObserver(interstitialCallback);
#                                 interstitialObserver.observe(document.getElementById(interstitialSlot.getSlotElementId()));
#                             }
#                         });
#                     }
#                 })();
#                 if (ctFirstTimeToEnterSite === "false" || isInAppBrowser) {
#                 googletag.defineSlot("/81206261/20_Chinatimes_Mobile/CP/20C_Mobile_InCover", [
#                     [320, 480],
#                     [1, 1]
#                 ], "div-gpt-ad-1551201747632-0").setTargeting("cid", ["260410"]).addService(googletag.pubads());
#             }
#             googletag.defineSlot("/81206261/20_Chinatimes_Mobile/CP/20C_Mobile_TopBannerN", [
#                 [300, 250],
#                 [1, 1],
#                 "fluid"
#             ], "div-gpt-ad-1590732299155-0").setTargeting("cid", ["260410"]).addService(googletag.pubads());
#             googletag.defineSlot("/81206261/20_Chinatimes_Mobile/CP/20C_Mobile_MiddleBannerN", [
#                 [1, 1],
#                 [320, 480],
#                 "fluid"
#             ], "div-gpt-ad-1590732428465-0").setTargeting("cid", ["260410"]).addService(googletag.pubads());
#              googletag.defineSlot("/81206261/20_Chinatimes_Mobile/CP/20C_Mobile_InRead", [
#                 [1, 1], "fluid"
#             ], "div-gpt-ad-1551201747632-3").setTargeting("cid", ["260410"]).addService(googletag.pubads());
#             googletag.defineSlot("/81206261/20_Chinatimes_Mobile/CP/20C_Mobile_EndBanner_1st", [
#                 [1, 1],
#                 [300, 250]
#             ], "div-gpt-ad-1551201747632-4").setTargeting("cid", ["260410"]).addService(googletag.pubads());
#             googletag.defineSlot("/81206261/20_Chinatimes_Mobile/CP/20C_Mobile_EndBanner_2nd", [
#                 [300, 250],
#                 [320, 100]
#             ], "div-gpt-ad-1551201747632-5").setTargeting("cid", ["260410"]).addService(googletag.pubads());
#             googletag.defineSlot("/81206261/20_Chinatimes_Mobile/CP/20C_Mobile_StickyAd", [
#                 [1, 1],
#                 [320, 50],
#                 [320, 100]
#             ], "div-gpt-ad-1551201747632-6").setTargeting("cid", ["260410"]).addService(googletag.pubads());
#             googletag.defineSlot("/81206261/20_Chinatimes_Mobile/CP/20C_Mobile_EndText", [
#                 [330, 65], "fluid"
#             ], "div-gpt-ad-1603262317858-0").setTargeting("cid", ["260410"]).addService(googletag.pubads());
#             googletag.pubads().setTargeting("aid", "20220415003322");
#             var hasKeywords = "&quot;VIVEArts&quot;,&quot;VR&quot;,&quot;體驗&quot;,&quot;藝廊&quot;,&quot;妮克&quot;";
#             if (hasKeywords != "") {
#                 googletag.pubads().setTargeting("c_tag", ["VIVEArts","VR","體驗","藝廊","妮克"]);
#             }
#             googletag.pubads().enableAsyncRendering();
#             googletag.pubads().collapseEmptyDivs(true);
#             googletag.pubads().enableSingleRequest();
#             googletag.enableServices();
#         });
#         </script>
# <script>
#             //顯示DFP非同步廣告
#             googletag.cmd.push(function () {
#                 if (ctFirstTimeToEnterSite === "false" || isInAppBrowser) {
#                     googletag.display("div-gpt-ad-1551201747632-0");
#                 }
#                 googletag.display("div-gpt-ad-1590732299155-0");
#                 googletag.display("div-gpt-ad-1590732428465-0");
#                 googletag.display("div-gpt-ad-1551201747632-3");
#                 googletag.display("div-gpt-ad-1551201747632-4");
#                 googletag.display("div-gpt-ad-1551201747632-5");
#                 googletag.display("div-gpt-ad-1551201747632-6");
#                 googletag.display("div-gpt-ad-1603262317858-0");
#             });
#         </script>
# <script>
#         //®加上<sup>標籤
#         $(document).ready(function () {
#             if (isRwd && !navigator.userAgent.match(/iPhone|iPad/i)) {
#                 return;
#             }
#             $(".article-box .main-figure, .article-box .article-body").contents().filter(function () {
#                 return (this.nodeType === 1 && (this.tagName.toLowerCase() === "p" || this.tagName.toLowerCase() === "figure"));
#             }).each(function () {
#                 var targetElement;
#                 if (this.tagName.toLowerCase() === "p") {
#                     targetElement = this;
#                 } else {
#                     targetElement = this.querySelector("figcaption");
#                 }
#                 targetElement.innerHTML = targetElement.innerHTML.replace(/®/g, "<sup>®</sup>");
#             });
#         });
#     </script>
# <script>
#     //邊欄熱門新聞
#     $(document).ready(function () {
#         var apiUrl = "https://dinfo.chinatimes.com/get/chinatimes/hotpages/money";
#         $.ajax({
#             "method": "GET",
#             "url": apiUrl,
#             "dataType": "json"
#         }).done(function (data) {
#             var stringBuffer = [];
#             $.each(data.Pages, function (i, page) {
#                 if (i > 4) {
#                     return false;
#                 }
#                 stringBuffer.push(i < 5 ? '<li class="top">' : '<li>');
#                 stringBuffer.push('<h4 class="title">');
#                 stringBuffer.push('<a href="https://' + page.PagePath + '">' + page.PageTitle + '</a>');
#                 stringBuffer.push('</h4></li>');
#             });
#             $(".hot-news .vertical-list").append(stringBuffer.join(""));
#         }).fail(function (error) {
#             console.log("熱門新聞api資料有誤");
#             console.log(error);
#         });
#     });
#     </script>
#
# </body>
# </html>

# %%
print(url)
# Out:
# https://www.chinatimes.com/realtimenews/20220415003322-260410

# %%
import bs4

# %%
root=bs4.BeautifulSoup(content,"html.parser")
paragraphs=root.find_all('p')
for paragraph in paragraphs:
    if paragraph.string!=None:
        print(paragraph.string)
# Out:
# 宏達電(2498)宣布，旗下藝術創新團隊VIVE Arts將再度與知名法國藝術家多米妮克.岡薩雷斯-福斯特(Dominique Gonzalez-Foerster)聯手合作，擔任其將於倫敦蛇形藝廊(Serpentine)隆重登場的全新個展「Alienarium 5」的官方虛擬實境夥伴。
# VIVE Arts是一家全球性的藝術與科技企業，主要是在為數位藝術孕育豐富的生態系，讓藝術家得以透過VR、XR和元宇宙技術來展示創意理念。《Alienarium》是岡薩雷斯-福斯特第二件由VIVE Arts委託製作、以及Lucid Realities開發的VR作品；第一件為2019年於威尼斯雙年展亮相的《Endodrome》。《Alienarium》將嘗試以VR為媒介，連結虛擬與真實世界，在僅能存在於虛擬世界般的想像空間、空幻情境中，感受靈魂出竅的體驗。訪客戴上VIVE Pro後，將置身斑斕繽紛的深度空間環境，在此與外星生命相遇，並與外星生命發光的抽象形體合而為一。岡薩雷斯-福斯特所設計的環境每次可供五人同時體驗，營造兼具私密與社交的體驗，訪客能夠以嶄新形式與外星人互動、與他人交流。
# VIVE Arts總監葉心宇表示，VIVE Arts的宗旨是鼓勵視覺藝術家探索數位技術的無限可能，重新定義藝術與文化的體驗方式。我們很榮幸能與蛇形藝廊合作舉辦此次精采的沉浸式展覽，也很榮幸能與多米妮克.岡薩雷斯-福斯特再續合作前緣，將她大膽、奇想的與外星生命相遇連結的抽象概念轉化為虛擬實境。多米妮克著名的特色是以對不同型態的意識、主觀性、以及人體與空間的感官關聯性上進行探索，並不斷創新突破界限。多米妮克運用VR的手法充滿巧思和實驗性質，她活用VR包羅萬象的潛力，開創新境界並建立連結，為每位觀眾帶來獨一無二的強大體驗。」
# 宏達電表示，本次個展「Alienarium 5」展期為4月14日至9月4日，是其自2008年於泰德當代美術館(Tate Modern)渦輪大廳(Turbine Hall)之「TH.2058」展覽以來，首度在英國重要藝術機構蛇形藝廊(Serpentine)舉辦的大型個展。
# 中時新聞網對留言系統使用者發布的文字、圖片或檔案保有片面修改或移除的權利。當使用者使用本網站留言服務時，表示已詳細閱讀並完全了解，且同意配合下述規定：
# 違反上述規定者，中時新聞網有權刪除留言，或者直接封鎖帳號！請使用者在發言前，務必先閱讀留言板規則，謝謝配合。

# %%
# ETtoday財經雲

# %%
my_headers ={'cookie':'over18=1;'}
url=data['link'][2]
response = requests.get(url, headers=my_headers)
content=response.text
print(data['source'][2])
print(content)
# Out:
# ETtoday財經雲
# <!doctype html>
# <html lang="zh-Hant-TW" prefix="og:http://ogp.me/ns#" itemscope itemtype="https://schema.org/NewsArticle" xmlns:wb="http://open.weibo.com/wb">
#
# <head>
#     <!-- ★非共用meta 開始★ -->
#     <!-- ★基本meta 開始★ -->
#     <meta charset="utf-8">
#             <link rel="amphtml" href="https://finance.ettoday.net/amp/amp_news.php7?news_id=2233305">
#         <title>十大超夯股東會紀念品！聯電續推角落小夥伴　敲碗等王品、宏達電 | ETtoday財經雲 | ETtoday新聞雲</title>
#     <link rel="canonical" itemprop="mainEntityOfPage" href="https://finance.ettoday.net/news/2233305" />
#     <meta name="description" content="股東會旺季即將到來，不少股民都相當關注股東紀念品，其中擁有百萬股民的中鋼（2002）今年推出環保餐具；聯電（2303）再以角落小夥伴帆布包作為股東會紀念品；大魯閣（1432）的消費抵用券也成為焦點；不過備受矚目的王品（2727）、宏達電（2498）則尚未公布，以下為《ETtoday新聞雲》記者特選10間一直是市場熱度最高股東會紀念品。(股東會,紀念品,聯電,王品)" />
#     <meta property="og:description" itemprop="description" content="股東會旺季即將到來，不少股民都相當關注股東紀念品，其中擁有百萬股民的中鋼（2002）今年推出環保餐具；聯電（2303）再以角落小夥伴帆布包作為股東會紀念品；大魯閣（1432）的消費抵用券也成為焦點；不過備受矚目的王品（2727）、宏達電（2498）則尚未公布，以下為《ETtoday新聞雲》記者特選10間一直是市場熱度最高股東會紀念品。" />
#     <meta property="og:url" itemprop="url" content="https://finance.ettoday.net/news/2233305" />
#     <meta property="og:title" itemprop="name" content="十大超夯股東會紀念品！聯電續推角落小夥伴　敲碗等王品、宏達電 | ETtoday財經雲 | ETtoday新聞雲" />
#             <meta property="og:image" itemprop="image" content="https://cdn2.ettoday.net/images/6296/e6296515.jpg" />
#             <meta property="og:image:type" content="image/jpeg" />
#     <meta property="og:image:width" content="1200" />
#     <meta property="og:image:height" content="630" />
#     <!-- ★基本meta 結束★ -->
#
#     <!-- 新聞資訊(系統站內頁專用) 開始 -->
#     <meta name="section" content="財經" />
#         <meta name="subsection" itemprop="articleSection" content="財經" />
#     <meta name="pubdate" itemprop="dateCreated" content="2022-04-19T17:15:00+08:00" />
#     <meta name="lastmod" itemprop="dateModified" http-equiv="last-modified" content="2022-04-19T17:26:23+08:00" />
#     <meta name="author" content="ETtoday新聞雲" />
#     <meta property="article:author" content="https://www.facebook.com/ETtodaymoney" />
#     <meta name="source" itemprop="author" content="ETtoday財經雲" />
#     <meta name="dcterms.rightsHolder" content="ETtoday新聞雲">
#     <meta name="news_keywords" itemprop="keywords" content="股東會,紀念品,聯電,王品">
#     <!-- 新聞資訊(系統站內頁專用) 結束 -->
#     <!-- ★非共用meta 結束★ -->
#
#     <!-- 共用 meta 開始 -->
#     <!-- 共用 meta 開始 -->
# <!-- ★基本meta 開始★ -->
# <meta name="robots" content="index,follow,noarchive" />
# <meta name="viewport" content="width=1200" />
# <link rel="alternate" type="application/rss+xml" title="ETtoday《財經新聞》" href="https://feeds.feedburner.com/ettoday/finance" />
# <!-- ★CSS、JS 開始★ -->
# <link href="//cdn2.ettoday.net/style/finance2020/css/style.css" rel="stylesheet">
#
# <script src="//cdn2.ettoday.net/style/finance2020/js/all.js"></script>
# <!-- DFP code -->
# <script type="text/javascript" src="//cdn2.ettoday.net/dfp/dfp-gpt.js"></script>
# <!-- ★CSS、JS 結束★ -->
# <!-- ★基本meta 結束★ -->
#
# <!-- ★dns-prefetch 開始★ -->
# <link rel="dns-prefetch" href="//ad.ettoday.net">
# <link rel="dns-prefetch" href="//ad1.ettoday.net">
# <link rel="dns-prefetch" href="//ad2.ettoday.net">
# <link rel="dns-prefetch" href="//cache.ettoday.net">
# <link rel="dns-prefetch" href="//static.ettoday.net">
# <link rel="dns-prefetch" href="//cdn1.ettoday.net">
# <link rel="dns-prefetch" href="//cdn2.ettoday.net">
# <!-- ★dns-prefetch 結束★ -->
#
# <!-- ★社群分享專用 開始★ -->
# <meta property="og:locale" content="zh_TW" />
# <meta property="fb:app_id" content="146858218737386" />
# <meta property="og:site_name" name="application-name" content="ETtoday財經雲" />
# <meta property="article:publisher" content="https://www.facebook.com/ETtodaymoney" />
# <!-- ★社群分享專用 結束★-->
#
# <!-- touch icon 開始 -->
# <link rel="apple-touch-icon" sizes="180x180" href="//cdn2.ettoday.net/style/finance2020/images/touch-icon.png" />
# <link rel="shortcut icon" sizes="192x192" href="//cdn2.ettoday.net/style/finance2020/images/touch-icon.png" />
# <!-- touch icon 結束 -->
#
# <!-- Google Tag Manager 開始 -->
# <!-- GTM DataLayer 開始 -->
# <script>
#     dataLayer = [{
#         'csscode': 'finance',
#         'page-id': '2233305',
#         'category-id': '17',
#         'category-name1': '財經',
#         'category-name2': '財經',
#         'dept-name': '',
#         'author-id': '2482',
#         'author-name': '廖婕妤',
#         'readtype': 'PC'
#     }];
# </script>
# <!-- GTM DataLayer 結束 -->
# <script>
#     (function(w, d, s, l, i) {
#         w[l] = w[l] || [];
#         w[l].push({
#             'gtm.start': new Date().getTime(),
#             event: 'gtm.js'
#         });
#         var f = d.getElementsByTagName(s)[0],
#             j = d.createElement(s),
#             dl = l != 'dataLayer' ? '&l=' + l : '';
#         j.async = true;
#         j.src =
#             'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
#         f.parentNode.insertBefore(j, f);
#     })(window, document, 'script', 'dataLayer', 'GTM-M6DGLM3');
# </script>
# <!-- Google Tag Manager 結束 -->
# <!-- 共用 meta 結束 -->    <!-- 共用 meta 結束 -->
#
#     <!-- ★非共用meta 開始★ -->
#     <!-- JSON-LD(新聞內頁專用) 開始 -->
#     <script type="application/ld+json">
#         {
#             "@context": "https://schema.org",
#             "@type": "NewsArticle",
#             "mainEntityOfPage": "https://finance.ettoday.net/news/2233305",
#             "headline": "十大超夯股東會紀念品！聯電續推角落小夥伴　敲碗等王品、宏達電",
#             "url": "https://finance.ettoday.net/news/2233305",
#             "thumbnailUrl": "https://cdn2.ettoday.net/images/6296/e6296515.jpg",
#             "articleSection": "財經",
#             "creator": ["2233305-廖婕妤", "2233305"],
#             "image": {
#                 "@type": "ImageObject",
#                 "url": "https://cdn2.ettoday.net/images/6296/e6296515.jpg"
#             },
#             "dateCreated": "2022-04-19T17:15:00+08:00",
#             "datePublished": "2022-04-19T17:15:00+08:00",
#             "dateModified": "2022-04-19T17:26:23+08:00",
#             "publisher": {
#                 "@type": "Organization",
#                 "name": "ETtoday新聞雲",
#                 "logo": {
#                     "@type": "ImageObject",
#                     "url": "https://cdn2.ettoday.net/style/finance2020/images/push.jpg"
#                 }
#             },
#             "author": {
#                 "@type": "Organization",
#                 "name": "ETtoday新聞雲",
#                 "url": "https://www.ettoday.net/"
#             },
#             "speakable": {
#                 "@type": "SpeakableSpecification",
#                 "xpath": [
#                     "/html/head/meta[@property='og:title']/@content",
#                     "/html/head/meta[@name='description']/@content"
#                 ]
#             },
#             "description": "股東會旺季即將到來，不少股民都相當關注股東紀念品，其中擁有百萬股民的中鋼（2002）今年推出環保餐具；聯電（2303）再以角落小夥伴帆布包作為股東會紀念品；大魯閣（1432）的消費抵用券也成為焦點；不過備受矚目的王品（2727）、宏達電（2498）則尚未公布，以下為《ETtoday新聞雲》記者特選10間一直是市場熱度最高股東會紀念品。",
#             "keywords": ["股東會","紀念品","聯電","王品"]
#         }
#     </script>
#     <!-- JSON-LD(新聞內頁專用) 結束 -->
#     <!-- ★非共用meta 結束★ -->
#
#     <!-- dmp.js 開始 -->
#     <script>
#         var dmp_event_property = "finance";
#         var dmp_id = "2233305";
#         var dmp_name = "十大超夯股東會紀念品！聯電續推角落小夥伴　敲碗等王品、宏達電";
#         var dmp_keywords = "股東會,紀念品,聯電,王品";
#         var dmp_publish_date = "2022-04-19 17:15:00";
#         var dmp_modified_date = "2022-04-19 17:26:23";
#         var dmp_category_id_list = "17_15";
#         var dmp_is_editor_rec = "0";
#         var dmp_et_token = "c12f5fcdcfa656efc2e46bfe9bbcdeff";
#         var dmp_event_id = "";
#     </script>
#     <script src="//cdn2.ettoday.net/jquery/dmp/news.js"></script>
#     <!-- dmp.js 結束 -->
# </head>
#
# <body id="finance" class="news-page news-2233305 ">
#     <!-- Fb Go 開始 -->
#     <!-- Google Tag Manager (noscript) -->
# <noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-M6DGLM3" height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <!-- FB plugins 開始-->
# <div id="fb-root"></div>
# <script async defer crossorigin="anonymous" src="https://connect.facebook.net/zh_TW/sdk.js#xfbml=1&version=v9.0&appId=146858218737386&autoLogAppEvents=1" nonce="HMd5J4wR"></script>
# <!-- FB Quote 選取文字分享 開始-->
# <div class="fb-quote"></div>
# <!-- FB Quote 選取文字分享 結束-->
# <!-- FB plugins 結束-->    <!-- Fb Go 結束 -->
#     <!--wrapper_box 開始-->
#     <div class="wrapper_box">
#         <!-- 模組 新聞內頁 分享按鈕 開始 -->
#         <div id="et_sticky_pc">
#             <ul>
#                 <li><a class="btn logo" href="https://finance.ettoday.net" title="回首頁">回首頁</a></li>
#                                     <li><a class="btn fb" href="javascript:;" onclick="window.open('https://www.facebook.com/sharer/sharer.php?u='+encodeURIComponent('https://finance.ettoday.net/news/2233305?from=pc-newsshare-fb-fixed'),'facebook-share-dialog','width=626,height=436');" title="facebook">facebook</a></li>
#
#                     <li><a class="btn line" href="javascript:;" onclick="window.open('https://social-plugins.line.me/lineit/share?url='+encodeURIComponent('https://finance.ettoday.net/news/2233305')+'?from=pc-newsshare-line-fixed','LINE','width=626,height=500');return false;" title="LINE">LINE</a></li>
#
#                     <li><a class="btn twitter" href="javascript:;" onclick="window.open('https://twitter.com/intent/tweet?text='+encodeURIComponent('十大超夯股東會紀念品！聯電續推角落小夥伴　敲碗等王品、宏達電')+'&url=https://finance.ettoday.net/news/2233305?from=pc-newsshare-twitter-fixed','Twittes','width=626,height=436');return false;" title="twitter">twitter</a></li>
#                                 <li><a class="btn link" href="javascript:;" title="複製連結">複製連結</a></li>
#             </ul>
#         </div>
#         <!-- 模組 新聞內頁 分享按鈕 結束 -->
#         <!--wrapper 開始-->
#         <div class="wrapper">
#             <!--ettop 開始-->
#             <!--header.php7-->
#             <!--ettop 結束-->
#             <!--header_box 開始-->
#
# <!-- 財經_轟天雷【硬性】 開始 -->
# <div id="finance_thunder" class="top-sky">
#     <script type="text/javascript">
#         (function() {
#             var ts = Math.random();
#             document.write('<scr' + 'ipt type="text/javascript" src="https://ad1.ettoday.net/ads.php?bid=finance_thunder&rr=' + ts + '"></scr' + 'ipt>');
#         })()
#     </script>
# </div>
# <!-- 財經_轟天雷【硬性】 結束 -->
#
#
# <!-- 雙門簾廣告 start -->
# <div id="finance_curtain" class="twin-curtain">
#     <script type="text/javascript">
#         (function() {
#             //廣告碼 開始
#             var ts = Math.random();
#             document.write('<scr' + 'ipt type="text/javascript" src="https://ad1.ettoday.net/ads.php?bid=finance_curtain&rr=' + ts + '"></scr' + 'ipt>');
#         })();
#     </script>
# </div>
# <!-- 雙門簾廣告  end -->
#
# <!--ettop 開始-->
# <div class="ettop">
#     <div class="inner clearfix">
#         <!--menu_1 開始-->
#         <div class="menu_1">
#             <a href="https://www.ettoday.net/" target="_blank">ETtoday新聞雲</a>
#             <a href="javascript:;" onclick="location.replace('https://www.ettoday.net/changeReadType.php?rtype=0&rurl='+location.href);">手機版</a>
#             <a href="https://www.ettoday.net/events/app/ettoday_app.htm" target="_blank">新聞雲Apps</a>
#         </div>
#         <!--menu_1 結束-->
#
#         <!-- 財經雲_版頭小橫幅_左 開始 -->
#         <div id="finance_header_120x50_1" class="ad_header">
#             <script type="text/javascript">
#                 (function() {
#                     var ts = Math.random();
#                     document.write('<scr' + 'ipt type="text/javascript" src="https://ad1.ettoday.net/ads.php?bid=finance_header_120x50_1&rr=' + ts + '"></scr' + 'ipt>');
#                 })()
#             </script>
#         </div>
#         <!-- 財經雲_版頭小橫幅_左 結束 -->
#
#         <!-- 全網_版頭_小橫幅 開始 -->
#         <div id="all_header_250x50" class="ad_header">
#             <script type="text/javascript">
#                 (function() {
#                     var ts = Math.random();
#                     document.write('<scr' + 'ipt type="text/javascript" src="https://ad1.ettoday.net/ads.php?bid=all_header_250x50&rr=' + ts + '"></scr' + 'ipt>');
#                 })()
#             </script>
#         </div>
#         <!-- 全網_版頭_小橫幅 結束 -->
#
#         <!-- 財經雲_版頭小橫幅_右 開始 -->
#         <div id="finance_header_120x50_2" class="ad_header">
#             <script type="text/javascript">
#                 (function() {
#                     var ts = Math.random();
#                     document.write('<scr' + 'ipt type="text/javascript" src="https://ad1.ettoday.net/ads.php?bid=finance_header_120x50_2&rr=' + ts + '"></scr' + 'ipt>');
#                 })()
#             </script>
#         </div>
#         <!-- 財經雲_版頭小橫幅_右 結束 -->
#
#         <!--搜尋 開始-->
#         <div class="search_box">
#             <form method="get" action="https://finance.ettoday.net/search.php7">
#                 <input class="txt" type="search" name='keyword' placeholder="搜尋" />
#                 <input class="btn" type="submit">
#             </form>
#         </div>
#         <!--搜尋 結束-->
#     </div>
# </div>
# <!--ettop 結束-->
# <!--header_box 開始-->
# <div class="header_box">
#     <!--header 開始-->
#     <div class="header">
#         <h1 class="main_logo"><a href="https://finance.ettoday.net" title="回首頁">財經雲</a></h1>
#         <!--nav_1 主選單 開始-->
#         <div id="float_nav" class="nav_1 clearfix">
#             <ul class="clearfix">
#                 <li><a href="https://finance.ettoday.net/focus/775">投資理財</a></li>
#                 <li><a href="https://finance.ettoday.net/focus/104">財經最新</a></li>
#                 <li><a href="https://finance.ettoday.net/focus/106">頂尖企業</a></li>
#                 <li><a href="https://finance.ettoday.net/focus/131">金融保險</a></li>
#                 <li><a href="https://finance.ettoday.net/focus/175">股匯行情</a></li>
#                 <li><a href="https://finance.ettoday.net/focus/427">科技3C</a></li>
#                 <li><a href="https://boba.ettoday.net/category/267" target="_blank">財經影音</a></li>
#                 <li><a href="https://finance.ettoday.net/focus/776">產業綜合</a></li>
#                 <li><a href="https://house.ettoday.net/" target="_blank">房產新聞</a></li>
#                 <li><a href="https://finance.ettoday.net/focus/779">社會企業</a></li>
#             </ul>
#         </div>
#         <!--nav_1 主選單 結束-->
#     </div>
#     <!--header 結束-->
# </div>
# <!--header_box 結束-->
#
# <!-- 財經_超級大橫幅 開始 -->
# <div id="finance_970x90" class="ad_970">
#     <script type="text/javascript">
#         (function() {
#             var ts = Math.random();
#             document.write('<scr' + 'ipt type="text/javascript" src="https://ad1.ettoday.net/ads.php?bid=finance_970x90&rr=' + ts + '"></scr' + 'ipt>');
#         })()
#     </script>
# </div>
# <!-- 財經_超級大橫幅 結束 -->
#
# <!-- BEGIN 525387 EtToday - TW - Adblocking - 728x90 START -->
# <script type="text/javascript" async src="//static.criteo.net/js/ld/publishertag.js"></script>
# <div id="abp3" style="width:728px;height:90px;margin:10px auto 50px auto"></div>
# <script type="text/javascript">
#     var Criteo = Criteo || {};
#     Criteo.events = Criteo.events || [];
#     Criteo.events.push(function() {
#         Criteo.DisplayAcceptableAdIfAdblocked({
#             "zoneid": 525387,
#             "containerid": "abp3",
#             "overrideZoneFloor": false
#         });
#     });
# </script>
# <!-- BEGIN 525387 EtToday - TW - Adblocking - 728x90 END -->            <!--header_box 結束-->
#             <!--container_box 開始-->
#             <div class="container_box">
#                 <!--container 開始-->
#                 <div class="container">
#                     <!--r1 開始-->
#                     <div class="r1 clearfix">
#
#                         <!--c1 開始-->
#                         <div class="c1">
#                             <!--breadcrumb_box 開始-->
#                             <div class="breadcrumb_box clearfix">
#                                 <!--麵包屑 開始-->
#                                 <div class="menu_bread_crumb" itemscope itemtype="http://schema.org/BreadcrumbList">
#                                     <!-- 第一層 開始 -->
#                                     <div itemscope itemtype="http://schema.org/ListItem" itemprop="itemListElement">
#                                         <a itemscope itemtype="http://schema.org/Thing" itemprop="item" href="https://www.ettoday.net/" id="https://www.ettoday.net/">
#                                             <span itemprop="name">ETtoday新聞雲</span>
#                                         </a>
#                                         <meta itemprop="position" content="1" />
#                                     </div>
#                                     <!-- 第一層 結束 -->
#                                     ›
#                                     <!-- 第二層 開始 -->
#                                     <div itemscope itemtype="http://schema.org/ListItem" itemprop="itemListElement">
#                                         <a itemscope itemtype="http://schema.org/Thing" itemprop="item" href="https://finance.ettoday.net/" id="https://finance.ettoday.net/">
#                                             <span itemprop="name">ETtoday財經雲</span>
#                                         </a>
#                                         <meta itemprop="position" content="2" />
#                                     </div>
#                                     <!-- 第二層 結束 -->
#                                 </div>
#                                 <!--麵包屑 結束-->
#                                 <!--時間 開始-->
#                                 <time class="date" itemprop="datePublished" datetime="30">
#                                     2022-04-19 17:15                                </time>
#                                 <!--時間 結束-->
#                             </div>
#                             <!--breadcrumb_box 結束-->
#                             <!--新聞模組 開始-->
#                             <div class="subject_article">
#                                 <!--網站logo 列印時出現 開始-->
#                                 <div class="site_logo" style="display:none;">
#                                     <img src="https://cdn2.ettoday.net/style/finance2020/images/logo_print.jpg" />
#                                 </div>
#                                 <!--網站logo 列印時出現 結束-->
#                                 <header>
#                                     <h1 class="title" itemprop="headline">十大超夯股東會紀念品！聯電續推角落小夥伴　敲碗等王品、宏達電</h1>
#                                 </header>
#
#                                 <!-- 財經_文字廣告(上) 開始 -->
#                                 <div id="finance_text_1" class="finance_text_1">
#                                     <script type="text/javascript">
#                                         (function() {
#                                             var ts = Math.random();
#                                             document.write('<scr' + 'ipt type="text/javascript" src="https://ad.ettoday.net/ads.php?bid=finance_text_1&rr=' + ts + '"></scr' + 'ipt>');
#                                         })()
#                                     </script>
#                                 </div>
#                                 <!-- 財經_文字廣告(上) 結束 -->
#
#                                 <!--各頻道PC 文首分享 開始-->
#                                 <!--模組 et_social_1 開始-->
# <div class="et_social_1">
# 	<!-------成人警告 開始----------->
# 		<!-------成人警告 結束----------->
#
# 	<!-- menu 開始 -->
# 		<div class="menu">
# 		<div class="fb-like" data-href="https://finance.ettoday.net/news/2233305" data-width=""
# 			data-layout="box_count" data-action="like" data-size="large" data-share="false"></div>
# 	</div>
# 		<!-- menu 結束 -->
# </div>
# <!--模組 et_social_1 結束-->
#                                 <!--各頻道PC 文首分享 結束-->
#
#                                 <!--本文 開始-->
#                                 <!--
#                                     -->
#                                 <div class="story" itemprop="articleBody">
#                                     <p><img src="//cdn2.ettoday.net/images/6296/6296515.jpg" alt="▲聯電2022年股東會紀念品，角落小夥伴帆布包。（圖／聯電提供）" width="563" height="450" /></p>
# <p><strong>▲聯電2022年股東會紀念品為角落小夥伴帆布包。（圖／聯電提供）<br type="_moz" />
# </strong></p>
# <p>記者廖婕妤／綜合報導</p>
# <p>股東會旺季即將到來，不少股民都相當關注股東紀念品，其中擁有百萬股民的中鋼（2002）今年推出環保餐具；聯電（2303）再以角落小夥伴帆布包作為股東會紀念品；大魯閣（1432）的消費抵用券也成為焦點；不過備受矚目的王品（2727）、宏達電（2498）則尚未公布，以下為《ETtoday新聞雲》記者特選一直是市場熱度最高10間股東會紀念品。</p>
# <p><img src="//cdn2.ettoday.net/images/6297/6297456.jpg" alt="▲2022股東會紀念品。（圖／記者廖婕妤製表）" width="600" height="313" /></p>
#     <!-- 新聞中_巨幅 start-->
#     <div class="ad_in_news" style="mragin:10px auto;text-align:center">
#      <div class="ad_readmore">[廣告]請繼續往下閱讀...</div>
#      <script language="JavaScript" type="text/javascript">
#       var ts = Math.random();
#       document.write('<scr' + 'ipt language="JavaScript" type="text/javascript" src="https://ad.ettoday.net/ads.php?bid=finance_in_news_1&rr='+ ts +'"></scr' + 'ipt>');
#      </script>
#     </div>
#     <!-- 新聞中_巨幅 end-->
#
# <p><strong>▲2022股東會紀念品。（圖／記者廖婕妤製表）<br type="_moz" />
# </strong></p>
# <p><strong>大魯閣（1432）</strong></p>
# <p>繼去年推出600元消費抵用券後，大魯閣今年的股東紀念品更狂，發放「700元消費抵用券」及「7張每月玩樂買1送1券」，總價值共2800元，雖然僅限下載大魯閣APP會員登錄使用，但由於股東持股不限股數，均可以拿到紀念品，一度成功推升股價連拉6根漲停。</p>
# <p><strong>正隆（1904）</strong></p>
# <p>造紙大廠正隆幾乎每年都以衛生紙作為股東會紀念品，今年發放「春風抽取式衛生紙一串」，股東持股不限股數，均可以拿到紀念品。</p>
# <p><strong>中鋼（2002）</strong></p>
# <p>百萬股民最期待的中鋼今年推出「精緻鈦ONE戶外型環保餐具」，雖然爆發抄襲設計爭議，但中鋼極力駁斥，方便攜帶又美觀的特點仍吸引股民目光。</p>
# <p>不過要注意的是，持股未滿1000股之股東，除股東親自出席股東會或以電子方式行使表決權者得領取外，將不予發放紀念品。</p>
# <p><strong>聯電（2303）</strong></p>
# <p>聯電2020年以角落小夥伴陶瓷杯作為股東會紀念品，讓股民為之轟動，2021年推出角落小夥伴帆布包為紀念品，今年再度發放角落小夥伴帆布包，但顏色跟圖案不同。不過要留意的是，持股未滿1000股之股東，除股東親自出席股東會或以電子方式行使表決權者得領取外，將不予發放紀念品。</p>
# <p><img src="//cdn2.ettoday.net/images/6297/6297532.jpg" alt="▲聯電2022年、2020年股東會紀念品。（圖／聯電提供、記者廖婕妤攝）。" width="600" height="401" /></p>
# <p><strong>▲聯電2022年、2020年股東會紀念品。（圖／聯電提供、記者廖婕妤攝）</strong></p>
# <p><strong>宏達電（2498）</strong></p>
# <p>宏達電過去曾推出風衣外套、後背包、運動包等實用商品做為股東會紀念品，去年更是發放休閒折疊椅，設計輕巧且方便收納。不過今年的紀念品則待揭曉。</p>
# <p><strong>王品（2727）</strong></p>
# <p>王品集團去年推出價值2516元的大禮包作為股東會紀念品，成功製造討論話題，且由於零股股東也能領，以當時股價來看，花不到200元買一股，就可以換到優惠券，可說是相當划算。不過王品今年尚未公布紀念品，讓股民相當期待。</p>
# <p><strong>華南金（2880）</strong></p>
# <p>華南金今年尚未公布紀念品，但歷年來都走實用路線，去年送出法國樂美雅餐盤2入組，前年則發放捲捲矽水瓶，讓股民相當關注今年的紀念品。</p>
# <p><strong>開發金（2883）</strong></p>
# <p>開發金去年發放智能保溫杯，今年紀念品為「彩繪花鳥碗（6入）組」。需留意持股未滿1000股之股東，除股東親自出席股東會或以電子方式行使表決權者得領取外，將不予發放紀念品。</p>
# <p><strong>永豐金（2890）</strong></p>
# <p>永豐金前年送出德國雙人牌抗菌砧板，成功擄獲家庭主婦的心，去年則是寬庭時尚旅行毯，今年紀念品為「黃金萬兩茶摳（香皂）禮盒」，股東持股不限股數，均予發放紀念品。</p>
# <p><strong>中信金（2891）</strong></p>
# <p>中信金今年尚未公布紀念品，去年推出的臺灣茶摳防疫隨身組，以及前年送出的日式碟筷架組，都被網友大讚超實用，因此今年的紀念品也讓人相當期待。</p>
# <p><img src="//cdn2.ettoday.net/images/6297/6297510.jpg" alt="▲中信金2020年股東會紀念品。（圖／記者廖婕妤攝）" width="600" height="450" /></p>
# <p><strong>▲中信金2020年股東會紀念品。（圖／記者廖婕妤攝）</strong></p>                                </div>
#                                 <!--本文 結束-->
#
#                                 <!-- 財經_文末_In-Read 開始 -->
#                                 <div id="finance_inread" class="ad-position-fix">
#                                     <script type="text/javascript">
#                                         (function() {
#                                             var ts = Math.random();
#                                             document.write('<scr' + 'ipt type="text/javascript" src="https://ad.ettoday.net/ads.php?bid=finance_inread&rr=' + ts + '"></scr' + 'ipt>');
#                                         })()
#                                     </script>
#                                 </div>
#                                 <!-- 財經_文末_In-Read 結束 -->
#
#                                 <!--tag 關鍵字 開始-->
#                                 <p class="tag">
#                                     <span>關鍵字：</span>
#                                                                             <a href="https://finance.ettoday.net/tag/股東會">股東會</a>
#                                         ﹑                                                                            <a href="https://finance.ettoday.net/tag/紀念品">紀念品</a>
#                                         ﹑                                                                            <a href="https://finance.ettoday.net/tag/聯電">聯電</a>
#                                         ﹑                                                                            <a href="https://finance.ettoday.net/tag/王品">王品</a>
#                                                                                                             </p>
#                                 <!--tag 關鍵字 結束-->
#
#                                 <!-- 全網_新聞內頁_推薦閱讀上方文字(3) 開始 -->
#                                 <div id="all_news_text1" class="all_news_text1">
#                                     <script type="text/javascript">
#                                         (function() {
#                                             var ts = Math.random();
#                                             document.write('<scr' + 'ipt type="text/javascript" src="https://ad.ettoday.net/ads.php?bid=all_news_text1&rr=' + ts + '"></scr' + 'ipt>');
#                                         })()
#                                     </script>
#                                 </div>
#                                 <!-- 全網_新聞內頁_推薦閱讀上方文字(3) 結束 -->
#
#
#
#                                 <!--各頻道PC 文末分享 開始-->
#                                 <!--模組 et_social_2 開始-->
# <div class="et_social_2">
# 	<p>分享給朋友：</p>
# 	<!-- menu 開始 -->
# 	<div class="menu">
# 				<div class="fb_box">
# 			<div class="fb-like" data-href="https://finance.ettoday.net/news/2233305" data-width="" data-layout="box_count" data-action="like" data-size="small" data-share="false"></div>
# 		</div>
# 		<a href="javascript:;" onclick="window.open('https://www.facebook.com/sharer/sharer.php?u='+encodeURIComponent('https://finance.ettoday.net/news/2233305')+'?from=pc-newsshare-fb','facebook-share-dialog','width=626,height=436');return false;" class="facebook" title="分享到Facebook"></a>
# 		<a href="javascript:;" onclick="window.open('https://social-plugins.line.me/lineit/share?url='+encodeURIComponent('https://finance.ettoday.net/news/2233305')+'?from=pc-newsshare-line','LINE','width=626,height=500');return false;" class="line" title="分享到LINE"></a>
# 		<a href="javascript:;" onclick="window.open('https://twitter.com/intent/tweet?text='+encodeURIComponent('十大超夯股東會紀念品！聯電續推角落小夥伴　敲碗等王品、宏達電')+'&url=https://finance.ettoday.net/news/2233305?from=pc-newsshare-twitter','Twittes','width=626,height=436');return false;" class="twitter" title="分享到Twitter"></a>
# 				<a class="copy-link" title="複製連結"></a>
# 		<a class="print" onclick="window.print();" title="列印本頁"></a>
# 				<a class="message scrollgo" title="點我留言" rel=".fb-comments"></a>
# 			</div>
# 	<!-- menu 結束 -->
# </div>
# <!--模組 et_social_2 結束-->
#
# <!--模組 et_social_3 開始-->
# <div class="et_social_3">
# 	<p>追蹤我們：</p>
# 	<!-- menu 開始 -->
# 	<div class="menu">
# 		<div class="fb_box">
# 			<div class="fb-page" data-href="https://www.facebook.com/ETtodaymoney" data-tabs="timeline" data-width="230" data-height="70" data-small-header="true" data-adapt-container-width="false" data-hide-cover="false" data-show-facepile="false">
# 				<blockquote cite="https://www.facebook.com/ETtodaymoney" class="fb-xfbml-parse-ignore"><a href="https://www.facebook.com/ETtodaymoney">掌握即時財經、理財新訊　按讚追蹤ETtoday財經雲向錢衝！</a></blockquote>
# 			</div>
# 		</div>
# 		<a href="https://www.youtube.com/user/ettoday" class="youtube" title="訂閱YouTube" target="_blank"></a>
# 		<a href="https://www.instagram.com/ettodaytw" class="instagram" title="追蹤IG" target="_blank"></a>
# 		<a href="https://line.me/R/ti/p/%40ETtoday" class="line" title="加LINE好友" target="_blank"></a>
# 		<a href="https://twitter.com/ettodaytw" class="twitter" title="追蹤Twitter" target="_blank"></a>
# 		<a href="https://t.me/ETtodaynews" class="telegram" title="追蹤Telegram" target="_blank"></a>
# 	</div>
# 	<!-- menu 結束 -->
# </div>
# <!--模組 et_social_3 結束-->
#                                 <!--各頻道PC 文末分享 結束-->
#
#
#                                 <p class="note">※本文版權所有，非經授權，不得轉載。<a href="https://www.ettoday.net/member/clause_copyright.php" target="_blank">[ETtoday著作權聲明]</a>※</p>
#                             </div>
#                             <!--新聞模組 結束-->
#
#                             <!-- 影音開框 開始-->
#                                                         <!-- 影音開框 結束 -->
#
#                             <!--推薦閱讀 block_1 開始-->
#                             <div class="block_1 recomm-news">
#                                 <h2 class="block_title">推薦閱讀</h2>
#                                 <!--part_pictxt_3 開始-->
#                                 <div class="part_pictxt_3">
#
#                                                                             <!--組-->
#                                         <a class="piece clearfix" href="//www.ettoday.net/news/20220708/2289593.htm" title="勞保、勞退可緩繳6個月「免滯納金」　7／11開放申請">
#                                             <div class="pic lazyload">
#                                                 <img src="https://cdn2.ettoday.net/style/misc/loading_300x225.gif" data-original="https://cdn2.ettoday.net/images/6356/f6356006.jpg" data-original="" title="勞保、勞退可緩繳6個月「免滯納金」　7／11開放申請" alt="勞保、勞退可緩繳6個月「免滯納金」　7／11開放申請">
#                                             </div>
#                                             <h3>
#                                                                                                 勞保、勞退可緩繳6個月「免滯納金」　7／11開放申請                                            </h3>
#                                             <p>國內疫情仍尚未趨緩，勞動部宣布，疫情期間受到影響的投保單位及被保險人，自7月11日起至2023年1月3日止，可向勞保局申請今年5月至10月勞、勞職、就保保險費及雇主提繳的勞工退休金緩繳6個月，緩繳期間免徵滯納金，至於雇主已扣收勞工個人自願提繳退休金，雇主仍應正常依限繳納。</p>
#                                             <p class="date">2022-07-08 07:00</p>
#                                         </a>
#                                         <!--組-->
#                                                                             <!--組-->
#                                         <a class="piece clearfix" href="//www.ettoday.net/news/20220708/2289611.htm" title="長榮單月營收飆新高、金融三業前5月獲利減2成　財經HOT 5一次看">
#                                             <div class="pic lazyload">
#                                                 <img src="https://cdn2.ettoday.net/style/misc/loading_300x225.gif" data-original="https://cdn2.ettoday.net/images/6440/f6440585.jpg" data-original="" title="長榮單月營收飆新高、金融三業前5月獲利減2成　財經HOT 5一次看" alt="長榮單月營收飆新高、金融三業前5月獲利減2成　財經HOT 5一次看">
#                                             </div>
#                                             <h3>
#                                                                                                 長榮單月營收飆新高、金融三業前5月獲利減2成　財經HOT 5一次看                                            </h3>
#                                             <p>《ETtoday新聞雲》記者整理五件財經大事，供讀者迅速掌握今日重點。</p>
#                                             <p class="date">2022-07-08 07:11</p>
#                                         </a>
#                                         <!--組-->
#                                                                             <!--組-->
#                                         <a class="piece clearfix" href="//www.ettoday.net/news/20220708/2289609.htm" title="美股回穩！道瓊勁揚346點　台積電ADR漲逾6%">
#                                             <div class="pic lazyload">
#                                                 <img src="https://cdn2.ettoday.net/style/misc/loading_300x225.gif" data-original="https://cdn2.ettoday.net/images/5117/c5117723.jpg" data-original="" title="美股回穩！道瓊勁揚346點　台積電ADR漲逾6%" alt="美股回穩！道瓊勁揚346點　台積電ADR漲逾6%">
#                                             </div>
#                                             <h3>
#                                                                                                 美股回穩！道瓊勁揚346點　台積電ADR漲逾6%                                            </h3>
#                                             <p>美股邁入7月後回穩，今天道瓊指數勁揚346點，標普500指數與那斯達克指數分別彈漲1.5%、2.3%，拉出連4紅漲勢。費半指數漲幅直逼4.5%，台積電ADR大漲6.7%。</p>
#                                             <p class="date">2022-07-08 06:56</p>
#                                         </a>
#                                         <!--組-->
#                                                                             <!--組-->
#                                         <a class="piece clearfix" href="//www.ettoday.net/news/20220708/2289640.htm" title="台積電大漲12.5元至470元！　台股漲逾160點、站上14500關卡">
#                                             <div class="pic lazyload">
#                                                 <img src="https://cdn2.ettoday.net/style/misc/loading_300x225.gif" data-original="https://cdn2.ettoday.net/images/5581/c5581187.jpg" data-original="" title="台積電大漲12.5元至470元！　台股漲逾160點、站上14500關卡" alt="台積電大漲12.5元至470元！　台股漲逾160點、站上14500關卡">
#                                             </div>
#                                             <h3>
#                                                                                                 台積電大漲12.5元至470元！　台股漲逾160點、站上14500關卡                                            </h3>
#                                             <p>美股邁入7月後回穩，今天道瓊指數勁揚346點，標普500指數與那斯達克指數分別彈漲1.5%、2.3%，拉出連4紅漲勢。台股今（8）日以14462.5點開出，大漲126點，稍後漲幅擴大至逾160點，指數站回14500關卡。</p>
#                                             <p class="date">2022-07-08 09:02</p>
#                                         </a>
#                                         <!--組-->
#                                                                             <!--組-->
#                                         <a class="piece clearfix" href="//www.ettoday.net/news/20220708/2289614.htm" title="台股報復性反彈！　百億操盤手點名「買這幾檔」">
#                                             <div class="pic lazyload">
#                                                 <img src="https://cdn2.ettoday.net/style/misc/loading_300x225.gif" data-original="https://cdn2.ettoday.net/images/6440/f6440804.jpg" data-original="" title="台股報復性反彈！　百億操盤手點名「買這幾檔」" alt="台股報復性反彈！　百億操盤手點名「買這幾檔」">
#                                             </div>
#                                             <h3>
#                                                                                                 台股報復性反彈！　百億操盤手點名「買這幾檔」                                            </h3>
#                                             <p>台股波濤洶湧，持續大漲大跌格局；不過，一位手握近百億資金的台股操盤手直言，近期隨著油價、銅價、農糧價格回跌，8月通膨數字將可看到明顯下滑，預計在7月底至8月初，便可期待一波像樣的中級反彈。配合下半年電子旺季，現階段投資人該瞄準哪些標的，參與報復性反彈？</p>
#                                             <p class="date">2022-07-08 07:19</p>
#                                         </a>
#                                         <!--組-->
#                                                                             <!--組-->
#                                         <a class="piece clearfix" href="//www.ettoday.net/news/20220708/2289612.htm" title="台股將反彈！　法人曝「上看17000大關」時間點">
#                                             <div class="pic lazyload">
#                                                 <img src="https://cdn2.ettoday.net/style/misc/loading_300x225.gif" data-original="https://cdn2.ettoday.net/images/6440/f6440802.jpg" data-original="" title="台股將反彈！　法人曝「上看17000大關」時間點" alt="台股將反彈！　法人曝「上看17000大關」時間點">
#                                             </div>
#                                             <h3>
#                                                                                                 台股將反彈！　法人曝「上看17000大關」時間點                                            </h3>
#                                             <p>台股砲聲隆隆，今年來上演大逃殺，指數從高點18619點狠摔逾4000點，指數一度跌破萬四，投資人無不在心中期待，國安基金快快進場護盤。但就法人及投資老手來看，現在根本還不到政府救市時機，因為股市聰明錢已默默集結、醞釀一波中級反彈；時間點就在7月底至8月，且反彈幅度至少是這波跌幅的1/2。</p>
#                                             <p class="date">2022-07-08 07:13</p>
#                                         </a>
#                                         <!--組-->
#                                                                             <!--組-->
#                                         <a class="piece clearfix" href="//www.ettoday.net/news/20220708/2289597.htm" title="黃正聰建議一人一戶改一人一室、住防疫旅館天數減半　以提高出入境恢復率">
#                                             <div class="pic lazyload">
#                                                 <img src="https://cdn2.ettoday.net/style/misc/loading_300x225.gif" data-original="https://cdn2.ettoday.net/images/6439/f6439477.jpg" data-original="" title="黃正聰建議一人一戶改一人一室、住防疫旅館天數減半　以提高出入境恢復率" alt="黃正聰建議一人一戶改一人一室、住防疫旅館天數減半　以提高出入境恢復率">
#                                             </div>
#                                             <h3>
#                                                                                                 黃正聰建議一人一戶改一人一室、住防疫旅館天數減半　以提高出入境恢復率                                            </h3>
#                                             <p>中央流行疫情指揮中心昨(7)日宣布，即日起入境總人數自每周2.5萬人次提高為4萬人次，靜宜大學副教授黃正聰今日凌晨在LINE群組上問，4萬人何時會觸頂，他建議檢疫辦法從一人一戶改為一人一室，放寬住防疫旅館後4天限制，讓防疫旅館資加一倍周轉率，並放寬自主管理期間可以上學、工作。</p>
#                                             <p class="date">2022-07-08 07:00</p>
#                                         </a>
#                                         <!--組-->
#                                                                             <!--組-->
#                                         <a class="piece clearfix" href="//www.ettoday.net/news/20220708/2289607.htm" title="7月純網銀、實體銀搶客大戰！　加油刷卡每公升最高可省2.6元">
#                                             <div class="pic lazyload">
#                                                 <img src="https://cdn2.ettoday.net/style/misc/loading_300x225.gif" data-original="https://cdn2.ettoday.net/images/6440/f6440801.jpg" data-original="" title="7月純網銀、實體銀搶客大戰！　加油刷卡每公升最高可省2.6元" alt="7月純網銀、實體銀搶客大戰！　加油刷卡每公升最高可省2.6元">
#                                             </div>
#                                             <h3>
#                                                                                                 7月純網銀、實體銀搶客大戰！　加油刷卡每公升最高可省2.6元                                            </h3>
#                                             <p>7月純網銀、實體銀行針對不同族群祭出搶客優惠，其中，針對暑假，聯邦銀加油卡體恤開車族，在9月30日以前推出「天天加油日」，指定日每公升最高可省2.6元，新戶還可享首刷禮二選一，幫民眾聰明善用信用卡有感省荷包，玩得安心也盡興。</p>
#                                             <p class="date">2022-07-08 06:55</p>
#                                         </a>
#                                         <!--組-->
#                                                                             <!--組-->
#                                         <a class="piece clearfix" href="//www.ettoday.net/news/20220708/2288426.htm" title="30年後購買力恐下降45%！對抗通膨不是傻傻存錢就好">
#                                             <div class="pic lazyload">
#                                                 <img src="https://cdn2.ettoday.net/style/misc/loading_300x225.gif" data-original="https://cdn2.ettoday.net/images/6010/c6010781.jpg" data-original="" title="30年後購買力恐下降45%！對抗通膨不是傻傻存錢就好" alt="30年後購買力恐下降45%！對抗通膨不是傻傻存錢就好">
#                                             </div>
#                                             <h3>
#                                                                                                 30年後購買力恐下降45%！對抗通膨不是傻傻存錢就好                                            </h3>
#                                             <p>政府針對某個商品規範或服務規範管制得越嚴格（越寬鬆），長期價格就越容易上升（下降）。舉例來說，因為政府大規模資助與規範，導致價格大幅上升的，包含醫院與醫療支出、大學學費與兒童照護；因為政府相對較少資助與規範，導致價格下降的，則包含軟體、電子產品、玩具、汽車與成衣。</p>
#                                             <p class="date">2022-07-08 01:00</p>
#                                         </a>
#                                         <!--組-->
#                                                                             <!--組-->
#                                         <a class="piece clearfix" href="//www.ettoday.net/news/20220707/2289547.htm" title="4大利空襲擊金融三業！　前5月獲利衰退逾2成">
#                                             <div class="pic lazyload">
#                                                 <img src="https://cdn2.ettoday.net/style/misc/loading_300x225.gif" data-original="https://cdn2.ettoday.net/images/5322/c5322980.jpg" data-original="" title="4大利空襲擊金融三業！　前5月獲利衰退逾2成" alt="4大利空襲擊金融三業！　前5月獲利衰退逾2成">
#                                             </div>
#                                             <h3>
#                                                                                                 4大利空襲擊金融三業！　前5月獲利衰退逾2成                                            </h3>
#                                             <p>金管會7日公布最新統計，今（2022）年前5月銀行、證券期貨投信、保險業稅前盈餘僅3,632億元，較去年同期減少21%，其中以券商縮水最多，獲利衰退逾5成，主因與央行升息、俄烏戰爭、通膨升溫、大陸封城等利空衝擊。</p>
#                                             <p class="date">2022-07-07 22:15</p>
#                                         </a>
#                                         <!--組-->
#
#                                 </div>
#                                 <!--part_pictxt_3 結束-->
#                             </div>
#                             <!--推薦閱讀 block_1 結束-->
#
#                             <!-- 文章推薦模組 1 start-->
#                             <div id="all_recirculation_1" class="recirculation">
#                                 <script type="text/javascript">
#                                     var ts = Math.random();
#                                     document.write('<scr' + 'ipt language="JavaScript" type="text/javascript" src="https://ad.ettoday.net/ads.php?bid=all_recirculation_1&rr=' + ts + '"></scr' + 'ipt>');
#                                 </script>
#                             </div>
#                             <!-- 文章推薦模組 1 end-->
#
#                             <!-- 文章推薦模組 2 start-->
#                             <div id="all_recirculation_2" class="recirculation">
#                                 <script type="text/javascript">
#                                     var ts = Math.random();
#                                     document.write('<scr' + 'ipt language="JavaScript" type="text/javascript" src="https://ad.ettoday.net/ads.php?bid=all_recirculation_2&rr=' + ts + '"></scr' + 'ipt>');
#                                 </script>
#                             </div>
#                             <!-- 文章推薦模組 2 end-->
#
#
#                             <!--讀者迴響 block_1 開始-->
#                             <div class="block_1 fb-comments">
#                                 <h2 class="block_title">讀者迴響</h2>
#                                 <!--et 留言版 開始-->
#                                 <div id="et_comments">
#                                                                             <!--menu 開始-->
#                                         <div class="menu">
#                                             <button class="btn_et current gtmclick">ETtoday留言</button>
#                                             <button class="btn_fb gtmclick">FB留言</button>
#                                         </div>
#                                         <!--menu 結束-->
#                                                                         <!--et_board 開始-->
#                                     <div class="et_board">
#                                         <!--留言 iframe 開始-->
#                                         <iframe src="https://finance.ettoday.net/et_comments.php7?news_id=2233305&title=十大超夯股東會紀念品！聯電續推角落小夥伴　敲碗等王品、宏達電&url=https://finance.ettoday.net/news/2233305" scrolling="no" allowtransparency="true"></iframe>
#                                         <!--留言 iframe 結束-->
#                                     </div>
#                                     <!--et_board 開始-->
#                                     <!--fb_board 開始-->
#                                     <div class="fb_board">
#                                         <!--FB 留言板 start-->
#                                         <div class="fb-comments" data-width="100%" data-mobile="" data-href="https://finance.ettoday.net/news/2233305" data-numposts="5" data-colorscheme="light"></div>
#                                         <!--FB 留言板 end-->
#                                     </div>
#                                     <!--fb_board 結束-->
#                                     <!--btn_go 下載App按鈕 開始-->
#                                     <a class="btn_go gtmclick" href="https://www.ettoday.net/events/ad-source/app/redirect-et-comments.php?news_id=2233305" target="_blank">想看更多留言，快前往新聞雲App吧！</a>
#                                     <!--btn_go 下載App按鈕 結束-->
#                                 </div>
#                                 <!--et 留言版 結束-->
#                             </div>
#                             <!--讀者迴響 block_1 結束-->
#
#                         </div>
#                         <!--c1 結束-->
#                         <!-- InstanceEndEditable -->
#                         <!--c2 開始-->
#
# <!-- 全網_超級快閃 開始 -->
# <div id="all_crazygif" class="">
#     <script type="text/javascript">
#         (function() {
#             var ts = Math.random();
#             document.write('<scr' + 'ipt type="text/javascript" src="https://ad2.ettoday.net/ads.php?bid=all_crazygif&rr=' + ts + '"></scr' + 'ipt>');
#         })()
#     </script>
# </div>
# <!-- 全網_超級快閃 結束 -->
#
# <!--c2 開始-->
# <div class="c2">
#     <div class="inner">
#
#         <!-- 財經_巨幅_上方【硬性】 開始 -->
#         <div id="finance_300x250_top" class="ad_300">
#             <script type="text/javascript">
#                 (function() {
#                     var ts = Math.random();
#                     document.write('<scr' + 'ipt type="text/javascript" src="https://ad2.ettoday.net/ads.php?bid=finance_300x250_top&rr=' + ts + '"></scr' + 'ipt>');
#                 })()
#             </script>
#         </div>
#         <!-- 財經_巨幅_上方【硬性】 結束 -->
#
#         <!-- 全網_巨幅(上2)【分】 開始 -->
#         <div id="all_300x250" class="ad_300">
#             <script type="text/javascript">
#                 (function() {
#                     var ts = Math.random();
#                     document.write('<scr' + 'ipt type="text/javascript" src="https://ad2.ettoday.net/ads.php?bid=all_300x250&rr=' + ts + '"></scr' + 'ipt>');
#                 })()
#             </script>
#         </div>
#         <!-- 全網_巨幅(上2)【分】 結束 -->
#
#                     <!--大盤指數 開始-->
#             <div class="block_2" style="margin-bottom:25px;">
#                 <h2 class="block_title_4" style="margin-bottom: 8px;">大盤指數</h2>
#                 <div style="margin:0px; padding: 0px;">
#                     <iframe src="https://pelements.money-link.com.tw/b2b/ettoday/WebPart_chart_3in1.aspx" width="100%" height="300" marginwidth="0" marginheight="0" frameborder="0" scrolling="no" allowtransparency="true"></iframe>
#                 </div>
#             </div>
#             <!--大盤指數 結束-->
#
#         <!--熱門新聞 block_2 開始-->
#         <div class="block_2 sidebar-hot-news">
#             <h2 class="block_title_4">熱門新聞</h2>
#             <div class="part_txt_1">
#                 <!-- 財經_熱門新聞_文字廣告(左)【硬性】 開始 -->
#                 <div id="finance_text_4" class="">
#                     <script type="text/javascript">
#                         (function() {
#                             var ts = Math.random();
#                             document.write('<scr' + 'ipt type="text/javascript" src="https://ad2.ettoday.net/ads.php?bid=finance_text_4&rr=' + ts + '"></scr' + 'ipt>');
#                         })()
#                     </script>
#                 </div>
#                 <!-- 財經_熱門新聞_文字廣告(左)【硬性】 結束 -->
#
#                 <!-- 財經_熱門新聞_文字廣告(右)【硬性】 開始 -->
#                 <div id="finance_text_5" class="">
#                     <script type="text/javascript">
#                         (function() {
#                             var ts = Math.random();
#                             document.write('<scr' + 'ipt type="text/javascript" src="https://ad2.ettoday.net/ads.php?bid=finance_text_5&rr=' + ts + '"></scr' + 'ipt>');
#                         })()
#                     </script>
#                 </div>
#                 <!-- 財經_熱門新聞_文字廣告(右)【硬性】 結束 -->
#
#                 <h3><a href="https://finance.ettoday.net/news/2285988" title="吃Buffet掏2000元被拒收　網風向一面倒">吃Buffet掏2000元被拒收　網風向一面倒</a></h3><h3><a href="https://finance.ettoday.net/news/2289614" title="台股報復性反彈！　百億操盤手點名「買這幾檔」">台股報復性反彈！　百億操盤手點名「買這幾檔」</a></h3><h3><a href="https://finance.ettoday.net/news/2288827" title="4張台積電全賣！他認賠出場：虧損130萬">4張台積電全賣！他認賠出場：虧損130萬</a></h3><h3><a href="https://finance.ettoday.net/news/2289612" title="台股將反彈！　法人曝「上看17000大關」時間點">台股將反彈！　法人曝「上看17000大關」時間點</a></h3><h3><a href="https://finance.ettoday.net/news/2288140" title="最高3.125％！一表看「24家網銀」活存利率">最高3.125％！一表看「24家網銀」活存利率</a></h3><!-- 新聞雲PC_新聞內頁_側欄廣編熱門新聞A 開始 -->
# <div id="all_news_text5" class="all_news_text5">
#     <h3>
#         <script type="text/javascript">
#         (function(){
#             var ts = Math.random();
#             document.write('<scr' + 'ipt type="text/javascript" src="https://ad2.ettoday.net/ads.php?bid=all_news_text5&rr='+ ts +'"></scr' + 'ipt>');
#         })()
#         </script>
#     </h3>
# </div>
# ...
#         </div>
#         <!--熱門新聞 block_2 結束-->
#
#         <!-- BEGIN 525386 EtToday - TW - Adblocking - 300x600 START -->
#         <script type="text/javascript" async src="//static.criteo.net/js/ld/publishertag.js"></script>
#         <div id="abp2" style="width:300px;height:600px;margin:10px auto"></div>
#         <script type="text/javascript">
#             var Criteo = Criteo || {};
#             Criteo.events = Criteo.events || [];
#             Criteo.events.push(function() {
#                 Criteo.DisplayAcceptableAdIfAdblocked({
#                     "zoneid": 525386,
#                     "containerid": "abp2",
#                     "overrideZoneFloor": false
#                 });
#             });
#         </script>
#         <!-- BEGIN 525386 EtToday - TW - Adblocking - 300x600 END -->
#
#         <!-- 全網_大型摩天_2(300x600)@最夯影音上方 開始 -->
#         <div id="all_300x600_2" class="all_300x600_2">
#             <script type="text/javascript">
#                 (function() {
#                     var ts = Math.random();
#                     document.write('<scr' + 'ipt type="text/javascript" src="https://ad2.ettoday.net/ads.php?bid=all_300x600_2&rr=' + ts + '"></scr' + 'ipt>');
#                 })()
#             </script>
#         </div>
#         <!-- 全網_大型摩天_2(300x600)@最夯影音上方 結束 -->
#
#
#
#         <!--facebook block_2 開始-->
#                     <div class="block_2">
#                 <div class="fb-page" data-href="https://www.facebook.com/ETtodaymoney/" data-tabs="timeline" data-width="" data-height="" data-small-header="false" data-adapt-container-width="true" data-hide-cover="false" data-show-facepile="true">
#                     <blockquote cite="https://www.facebook.com/ETtodaymoney/" class="fb-xfbml-parse-ignore"><a href="https://www.facebook.com/ETtodaymoney/">ETtoday財經雲</a></blockquote>
#                 </div>
#             </div>
#                 <!--facebook block_2 結束-->
#
#         <!-- 財經_巨幅_中 開始 -->
#         <div id="finance_banner_middle" class="finance_banner_middle">
#             <script type="text/javascript">
#                 (function() {
#                     var ts = Math.random();
#                     document.write('<scr' + 'ipt type="text/javascript" src="https://ad2.ettoday.net/ads.php?bid=finance_banner_middle&rr=' + ts + '"></scr' + 'ipt>');
#                 })()
#             </script>
#         </div>
#         <!-- 財經_巨幅_中 結束 -->
#
#         <!--block_1 區塊 boba 熱門影音 開始-->
#               <div class="block block_1 hot_video">
#               <!--block_title 開始-->
#               <div class="block_title">
#                 <h3><em class="icon"></em>最夯影音</h3>
#                 <a href="//boba.ettoday.net/" class="btn_more">更多<i class="icon_arrow"></i></a>
#               </div>
#               <!--block_title 結束-->
#               <!--block_content 開始-->
#               <div class="block_content">
#                       <!--part_pictxt_4 圖文列表 開始-->
#                       <div class="part_pictxt_4">
#                               <!-- 首則有圖 -->
#
#                               <div class="cover_pic">
#                                   <a class="pic icon_type_video" href="//boba.ettoday.net/videonews/333904?from=et_pc_sidebar" target="_blank" title='店家接單才過8分就來催　外送員爆氣：王八蛋爛店'>
#                                           <img src="https://cdn2.ettoday.net/style/misc/loading_800x450.gif" data-original="//cdn2.ettoday.net/film/images/333/c333904.jpg" alt='店家接單才過8分就來催　外送員爆氣：王八蛋爛店'>
#                                               <h3>店家接單才過8分就來催　外送員爆氣：王八蛋爛店</h3>
#                                       </a>
#                               </div>
#
#                               <!-- 首則有圖 -->
#                               <!-- 廣告 最夯影音(2) 開始 -->
#                               <script language="JavaScript" type="text/javascript">
#                                     <!-- <![CDATA[
#                                             var ts = Math.random();
#                                             document.write('<scr' + 'ipt language="JavaScript" type="text/javascript" src="//ad2.ettoday.net/ads.php?bid=mobileweb_video_1&rr='+ ts +'"></scr' + 'ipt>');
#                               // ]]> -->
#                               </script>
#                               <!-- 廣告 最夯影音(2) 結束 -->
#                               <!-- 廣告 最夯影音(3) 開始 -->
#                               <script language="JavaScript" type="text/javascript">
#                                     <!-- <![CDATA[
#                                             var ts = Math.random();
#                                             document.write('<scr' + 'ipt language="JavaScript" type="text/javascript" src="//ad2.ettoday.net/ads.php?bid=mobileweb_video_2&rr='+ ts +'"></scr' + 'ipt>');
#                               // ]]> -->
#                               </script>
#                               <!-- 廣告 最夯影音(3) 結束 -->
#                               <!-- 廣告 最夯影音(4) 開始 -->
#                               <script language="JavaScript" type="text/javascript">
#                                     <!-- <![CDATA[
#                                             var ts = Math.random();
#                                             document.write('<scr' + 'ipt language="JavaScript" type="text/javascript" src="//ad2.ettoday.net/ads.php?bid=mobileweb_video_3&rr='+ ts +'"></scr' + 'ipt>');
#                               // ]]> -->
#                               </script>
#                             <!-- 廣告 最夯影音(4) 結束 -->
#
#       <!--組-->
#       <div class="piece clearfix">
#               <a class="pic icon_type_video" href="//boba.ettoday.net/videonews/333851?from=et_pc_sidebar" target="_blank" title='Jessi正式宣布離開PSY公司！　「3年內數次送醫吊點滴」'>
#                   <img src="https://cdn2.ettoday.net/style/misc/loading_300x169.gif" data-original="//cdn2.ettoday.net/film/images/333/c333851.jpg" alt='Jessi正式宣布離開PSY公司！　「3年內數次送醫吊點滴」'>
#               </a>
#               <h3><a href="//boba.ettoday.net/videonews/333851?from=et_pc_sidebar" target="_blank" title='Jessi正式宣布離開PSY公司！　「3年內數次送醫吊點滴」'>Jessi正式宣布離開PSY公司！　「3年內數次送醫吊點滴」</a></h3>
#       </div>
#       <!--組-->
#
#       <!--組-->
#       <div class="piece clearfix">
#               <a class="pic icon_type_video" href="//boba.ettoday.net/videonews/333873?from=et_pc_sidebar" target="_blank" title='進派出所高喊「我有炸彈」　新竹男引爆炸爛右手掌'>
#                   <img src="https://cdn2.ettoday.net/style/misc/loading_300x169.gif" data-original="//cdn2.ettoday.net/film/images/333/c333873.jpg" alt='進派出所高喊「我有炸彈」　新竹男引爆炸爛右手掌'>
#               </a>
#               <h3><a href="//boba.ettoday.net/videonews/333873?from=et_pc_sidebar" target="_blank" title='進派出所高喊「我有炸彈」　新竹男引爆炸爛右手掌'>進派出所高喊「我有炸彈」　新竹男引爆炸爛右手掌</a></h3>
#       </div>
#       <!--組-->
#
#       <!--組-->
#       <div class="piece clearfix">
#               <a class="pic icon_type_video" href="//boba.ettoday.net/videonews/333957?from=et_pc_sidebar" target="_blank" title='疑左轉車未禮讓擦撞重機　騎士「噴飛撞石柱」身亡'>
#                   <img src="https://cdn2.ettoday.net/style/misc/loading_300x169.gif" data-original="//cdn2.ettoday.net/film/images/333/c333957.jpg" alt='疑左轉車未禮讓擦撞重機　騎士「噴飛撞石柱」身亡'>
#               </a>
#               <h3><a href="//boba.ettoday.net/videonews/333957?from=et_pc_sidebar" target="_blank" title='疑左轉車未禮讓擦撞重機　騎士「噴飛撞石柱」身亡'>疑左轉車未禮讓擦撞重機　騎士「噴飛撞石柱」身亡</a></h3>
#       </div>
#       <!--組-->
#
#       <!--組-->
#       <div class="piece clearfix">
#               <a class="pic icon_type_video" href="//boba.ettoday.net/videonews/333859?from=et_pc_sidebar" target="_blank" title='警抓包抽菸+10年7度酒駕　醉男跳針：有抽我被車撞'>
#                   <img src="https://cdn2.ettoday.net/style/misc/loading_300x169.gif" data-original="//cdn2.ettoday.net/film/images/333/c333859.jpg" alt='警抓包抽菸+10年7度酒駕　醉男跳針：有抽我被車撞'>
#               </a>
#               <h3><a href="//boba.ettoday.net/videonews/333859?from=et_pc_sidebar" target="_blank" title='警抓包抽菸+10年7度酒駕　醉男跳針：有抽我被車撞'>警抓包抽菸+10年7度酒駕　醉男跳針：有抽我被車撞</a></h3>
#       </div>
#       <!--組-->
#
#
#                       </div>
#                       <!--part_pictxt_4 圖文列表 結束-->
#               </div>
#               <!--block_content 結束-->
#       </div>
#         <!--block_1 區塊 boba 熱門影音 結束-->
#
#         <!-- BEGIN 505672 EtToday - TW - Adblocking - 300x250 START -->
#         <script type="text/javascript" async src="//static.criteo.net/js/ld/publishertag.js"></script>
#         <div id="abp1" style="width:300px;height:250px;margin:10px auto"></div>
#         <script type="text/javascript">
#             var Criteo = Criteo || {};
#             Criteo.events = Criteo.events || [];
#             Criteo.events.push(function() {
#                 Criteo.DisplayAcceptableAdIfAdblocked({
#                     "zoneid": 505672,
#                     "containerid": "abp1",
#                     "overrideZoneFloor": false
#                 });
#             });
#         </script>
#         <!-- BEGIN 505672 EtToday - TW - Adblocking - 300x250 END -->
#
#         <!--block_2 熱門快報 開始-->
#         <div class="block block_2 sidebar-hot-express">
#             <h2 class="block_title_4">熱門快報</h2>
#             <!--block_content 開始-->
#             <div class="block_content">
#                 <!--part_pictxt_5 圖文列表 開始-->
#                 <div class="part_pictxt_5">
#                                             <!--組-->
#                         <div class="piece clearfix">
#                             <a target="_blank" class="pic lazyload" href="https://events.ettoday.net/cooking/s3/introduction.php7">
#                                 <img src="https://cdn2.ettoday.net/style/misc/loading_100x100.gif" data-original="https://cdn1.ettoday.net/img/paste/103/103610.gif">
#                             </a>
#                             <h3 class="title"><a target="_blank" href="https://events.ettoday.net/cooking/s3/introduction.php7">《料理之王3》火熱上映中！</a></h3>
#                             <p class="summary">6/3起每周五、六晚間九點，《料理之王3》料戰再起、美味升級！</p>
#                         </div>
#                         <!--組-->
#                                             <!--組-->
#                         <div class="piece clearfix">
#                             <a target="_blank" class="pic lazyload" href="https://www.ettoday.net/events/app/ettoday_app.htm">
#                                 <img src="https://cdn2.ettoday.net/style/misc/loading_100x100.gif" data-original="https://cdn1.ettoday.net/img/paste/100/100112.jpg">
#                             </a>
#                             <h3 class="title"><a target="_blank" href="https://www.ettoday.net/events/app/ettoday_app.htm">新聞雲APP週週躺著抽</a></h3>
#                             <p class="summary">看新聞參加全民搶寶，蘋果3C爽爽抽，周周更新好禮！東森幣好用不藏私！</p>
#                         </div>
#                         <!--組-->
#                                             <!--組-->
#                         <div class="piece clearfix">
#                             <a target="_blank" class="pic lazyload" href="https://www.ettoday.net/feature/2021house">
#                                 <img src="https://cdn2.ettoday.net/style/misc/loading_100x100.gif" data-original="https://cdn1.ettoday.net/img/paste/102/102124.jpg">
#                             </a>
#                             <h3 class="title"><a target="_blank" href="https://www.ettoday.net/feature/2021house">全台房巿供不應求?!何處可買房</a></h3>
#                             <p class="summary">北中南房巿獵房行動，專家帶看環境交通、生活機能、精彩公設，開箱新建案</p>
#                         </div>
#                         <!--組-->
#                                             <!--組-->
#                         <div class="piece clearfix">
#                             <a target="_blank" class="pic lazyload" href="https://shopping.etipets.com/?utm_source=ettoday&utm_medium=banner&utm_campaign=202207_petfair&utm_content=sidebar_hot_express">
#                                 <img src="https://cdn2.ettoday.net/style/misc/loading_100x100.gif" data-original="https://cdn1.ettoday.net/img/paste/103/103976.gif">
#                             </a>
#                             <h3 class="title"><a target="_blank" href="https://shopping.etipets.com/?utm_source=ettoday&utm_medium=banner&utm_campaign=202207_petfair&utm_content=sidebar_hot_express">【寵物展】全館滿1599折百</a></h3>
#                             <p class="summary">7/8-7/11毛毛商城全館滿1599現折100元。活動期間新會員註冊送100元折價券，馬上去!</p>
#                         </div>
#                         <!--組-->
#                                             <!--組-->
#                         <div class="piece clearfix">
#                             <a target="_blank" class="pic lazyload" href="https://bit.ly/3BNAHIt">
#                                 <img src="https://cdn2.ettoday.net/style/misc/loading_100x100.gif" data-original="https://cdn1.ettoday.net/img/paste/100/100033.gif">
#                             </a>
#                             <h3 class="title"><a target="_blank" href="https://bit.ly/3BNAHIt">ETtoday Podcast聽起來</a></h3>
#                             <p class="summary">專屬年輕人的網路電台，用聲音陪你通勤上班</p>
#                         </div>
#                         <!--組-->
#                                     </div>
#                 <!--part_pictxt_5 圖文列表 結束-->
#             </div>
#             <!--block_content 結束-->
#         </div>
#         <!--block_2 熱門快報 結束-->
#
#         <!-- 全網_大型摩天_1(多支素材) [側欄置底] 開始 -->
#         <div id="all_300x600_1" class="">
#             <script type="text/javascript">
#                 (function() {
#                     var ts = Math.random();
#                     document.write('<scr' + 'ipt type="text/javascript" src="https://ad2.ettoday.net/ads.php?bid=all_300x600_1&rr=' + ts + '"></scr' + 'ipt>');
#                 })()
#             </script>
#         </div>
#         <!-- 全網_大型摩天_1(多支素材) [側欄置底] 結束 -->
#     </div>
# </div>
# <!--c2 結束-->                        <!--c2 結束-->
#                     </div>
#                     <!--r1 結束-->
#                 </div>
#                 <!--container 結束-->
#             </div>
#             <!--container_box 結束-->
#             <!--footer_box 開始-->
#             <!--footer_box 開始-->
# <div class="footer_box">
#     <!--footer 開始-->
#     <div class="footer clearfix" itemscope itemprop="publisher" itemtype="http://schema.org/Organization">
#         <!--footer_menu 開始-->
#         <div class="footer_menu">
#             <a href="mailto:editor@ettoday.net">我要投稿</a> |
#             <a href="https://www.104.com.tw/company/b6ctt6w?jobsource=checkc" target="_blank">人才招募</a> |
#             <a href="https://events.ettoday.net/about-ettoday/index.htm" target="_blank">關於我們</a> |
#             <a href="mailto:service@ettoday.net">廣告刊登/合作提案</a> |
#             <a href="mailto:service@ettoday.net">客服信箱</a> |
#             <a href="https://www.ettoday.net/member/clause_member.php" target="_blank">服務條款</a> |
#             <a href="https://www.ettoday.net/member/clause_privacy.php" target="_blank">隱私權政策</a> |
#             <a href="https://www.ettoday.net/member/clause_copyright.php" target="_blank">著作權聲明</a> |
#             <a href="https://www.ettoday.net/member/clause_duty.php" target="_blank">免責聲明</a>
#         </div>
#         <!--footer_menu 結束-->
#         <address>
#             <span itemprop="name" class="company_name">ETtoday新聞雲</span>
#             版權所有，非經授權，不許轉載本網站內容 &copy;
#             <a href="https://www.ettoday.net/" target="_top">ETtoday.net</a>
#             All Rights Reserved. 電話：
#             <span itemprop="telephone">+886-2-5555-6366</span>
#         </address>
#         <!--本區隱藏 開始-->
#         <span itemprop="logo" itemscope itemtype="//schema.org/ImageObject">
#             <link itemprop="url" href="https://cdn2.ettoday.net/style/finance2020/images/push.jpg">
#         </span>
#         <!--本區隱藏 結束-->
#     </div>
#     <!--footer 結束-->
# </div>
# <!--footer_box 結束-->            <!--footer_box 結束-->
#         </div>
#         <!--wrapper 結束-->
#     </div>
#     <!--wrapper_box 結束-->
# </body>
#
# </html>

# %%
print(url)
# Out:
# https://finance.ettoday.net/news/2233305

# %%
root=bs4.BeautifulSoup(content,"html.parser")
article=root.find_all('div',class_='subject_article')
print(article)
# Out:
# [<div class="subject_article">
# <!--網站logo 列印時出現 開始-->
# <div class="site_logo" style="display:none;">
# <img src="https://cdn2.ettoday.net/style/finance2020/images/logo_print.jpg"/>
# </div>
# <!--網站logo 列印時出現 結束-->
# <header>
# <h1 class="title" itemprop="headline">十大超夯股東會紀念品！聯電續推角落小夥伴　敲碗等王品、宏達電</h1>
# </header>
# <!-- 財經_文字廣告(上) 開始 -->
# <div class="finance_text_1" id="finance_text_1">
# <script type="text/javascript">
#                                         (function() {
#                                             var ts = Math.random();
#                                             document.write('<scr' + 'ipt type="text/javascript" src="https://ad.ettoday.net/ads.php?bid=finance_text_1&rr=' + ts + '"></scr' + 'ipt>');
#                                         })()
#                                     </script>
# </div>
# <!-- 財經_文字廣告(上) 結束 -->
# <!--各頻道PC 文首分享 開始-->
# <!--模組 et_social_1 開始-->
# <div class="et_social_1">
# <!-------成人警告 開始----------->
# <!-------成人警告 結束----------->
# <!-- menu 開始 -->
# <div class="menu">
# <div class="fb-like" data-action="like" data-href="https://finance.ettoday.net/news/2233305" data-layout="box_count" data-share="false" data-size="large" data-width=""></div>
# </div>
# <!-- menu 結束 -->
# </div>
# <!--模組 et_social_1 結束-->
# <!--各頻道PC 文首分享 結束-->
# <!--本文 開始-->
# <!--
# -->
# <div class="story" itemprop="articleBody">
# <p><img alt="▲聯電2022年股東會紀念品，角落小夥伴帆布包。（圖／聯電提供）" height="450" src="//cdn2.ettoday.net/images/6296/6296515.jpg" width="563"/></p>
# <p><strong>▲聯電2022年股東會紀念品為角落小夥伴帆布包。（圖／聯電提供）<br type="_moz"/>
# </strong></p>
# <p>記者廖婕妤／綜合報導</p>
# <p>股東會旺季即將到來，不少股民都相當關注股東紀念品，其中擁有百萬股民的中鋼（2002）今年推出環保餐具；聯電（2303）再以角落小夥伴帆布包作為股東會紀念品；大魯閣（1432）的消費抵用券也成為焦點；不過備受矚目的王品（2727）、宏達電（2498）則尚未公布，以下為《ETtoday新聞雲》記者特選一直是市場熱度最高10間股東會紀念品。</p>
# <p><img alt="▲2022股東會紀念品。（圖／記者廖婕妤製表）" height="313" src="//cdn2.ettoday.net/images/6297/6297456.jpg" width="600"/></p>
# <!-- 新聞中_巨幅 start-->
# <div class="ad_in_news" style="mragin:10px auto;text-align:center">
# <div class="ad_readmore">[廣告]請繼續往下閱讀...</div>
# <script language="JavaScript" type="text/javascript">
#       var ts = Math.random();
#       document.write('<scr' + 'ipt language="JavaScript" type="text/javascript" src="https://ad.ettoday.net/ads.php?bid=finance_in_news_1&rr='+ ts +'"></scr' + 'ipt>');
#      </script>
# </div>
# <!-- 新聞中_巨幅 end-->
# <p><strong>▲2022股東會紀念品。（圖／記者廖婕妤製表）<br type="_moz"/>
# </strong></p>
# <p><strong>大魯閣（1432）</strong></p>
# <p>繼去年推出600元消費抵用券後，大魯閣今年的股東紀念品更狂，發放「700元消費抵用券」及「7張每月玩樂買1送1券」，總價值共2800元，雖然僅限下載大魯閣APP會員登錄使用，但由於股東持股不限股數，均可以拿到紀念品，一度成功推升股價連拉6根漲停。</p>
# <p><strong>正隆（1904）</strong></p>
# <p>造紙大廠正隆幾乎每年都以衛生紙作為股東會紀念品，今年發放「春風抽取式衛生紙一串」，股東持股不限股數，均可以拿到紀念品。</p>
# <p><strong>中鋼（2002）</strong></p>
# <p>百萬股民最期待的中鋼今年推出「精緻鈦ONE戶外型環保餐具」，雖然爆發抄襲設計爭議，但中鋼極力駁斥，方便攜帶又美觀的特點仍吸引股民目光。</p>
# <p>不過要注意的是，持股未滿1000股之股東，除股東親自出席股東會或以電子方式行使表決權者得領取外，將不予發放紀念品。</p>
# <p><strong>聯電（2303）</strong></p>
# <p>聯電2020年以角落小夥伴陶瓷杯作為股東會紀念品，讓股民為之轟動，2021年推出角落小夥伴帆布包為紀念品，今年再度發放角落小夥伴帆布包，但顏色跟圖案不同。不過要留意的是，持股未滿1000股之股東，除股東親自出席股東會或以電子方式行使表決權者得領取外，將不予發放紀念品。</p>
# <p><img alt="▲聯電2022年、2020年股東會紀念品。（圖／聯電提供、記者廖婕妤攝）。" height="401" src="//cdn2.ettoday.net/images/6297/6297532.jpg" width="600"/></p>
# <p><strong>▲聯電2022年、2020年股東會紀念品。（圖／聯電提供、記者廖婕妤攝）</strong></p>
# <p><strong>宏達電（2498）</strong></p>
# <p>宏達電過去曾推出風衣外套、後背包、運動包等實用商品做為股東會紀念品，去年更是發放休閒折疊椅，設計輕巧且方便收納。不過今年的紀念品則待揭曉。</p>
# <p><strong>王品（2727）</strong></p>
# <p>王品集團去年推出價值2516元的大禮包作為股東會紀念品，成功製造討論話題，且由於零股股東也能領，以當時股價來看，花不到200元買一股，就可以換到優惠券，可說是相當划算。不過王品今年尚未公布紀念品，讓股民相當期待。</p>
# <p><strong>華南金（2880）</strong></p>
# <p>華南金今年尚未公布紀念品，但歷年來都走實用路線，去年送出法國樂美雅餐盤2入組，前年則發放捲捲矽水瓶，讓股民相當關注今年的紀念品。</p>
# <p><strong>開發金（2883）</strong></p>
# <p>開發金去年發放智能保溫杯，今年紀念品為「彩繪花鳥碗（6入）組」。需留意持股未滿1000股之股東，除股東親自出席股東會或以電子方式行使表決權者得領取外，將不予發放紀念品。</p>
# <p><strong>永豐金（2890）</strong></p>
# <p>永豐金前年送出德國雙人牌抗菌砧板，成功擄獲家庭主婦的心，去年則是寬庭時尚旅行毯，今年紀念品為「黃金萬兩茶摳（香皂）禮盒」，股東持股不限股數，均予發放紀念品。</p>
# <p><strong>中信金（2891）</strong></p>
# <p>中信金今年尚未公布紀念品，去年推出的臺灣茶摳防疫隨身組，以及前年送出的日式碟筷架組，都被網友大讚超實用，因此今年的紀念品也讓人相當期待。</p>
# <p><img alt="▲中信金2020年股東會紀念品。（圖／記者廖婕妤攝）" height="450" src="//cdn2.ettoday.net/images/6297/6297510.jpg" width="600"/></p>
# <p><strong>▲中信金2020年股東會紀念品。（圖／記者廖婕妤攝）</strong></p> </div>
# <!--本文 結束-->
# <!-- 財經_文末_In-Read 開始 -->
# <div class="ad-position-fix" id="finance_inread">
# <script type="text/javascript">
#                                         (function() {
#                                             var ts = Math.random();
#                                             document.write('<scr' + 'ipt type="text/javascript" src="https://ad.ettoday.net/ads.php?bid=finance_inread&rr=' + ts + '"></scr' + 'ipt>');
#                                         })()
#                                     </script>
# </div>
# <!-- 財經_文末_In-Read 結束 -->
# <!--tag 關鍵字 開始-->
# <p class="tag">
# <span>關鍵字：</span>
# <a href="https://finance.ettoday.net/tag/股東會">股東會</a>
#                                         ﹑                                                                            <a href="https://finance.ettoday.net/tag/紀念品">紀念品</a>
#                                         ﹑                                                                            <a href="https://finance.ettoday.net/tag/聯電">聯電</a>
#                                         ﹑                                                                            <a href="https://finance.ettoday.net/tag/王品">王品</a>
# </p>
# <!--tag 關鍵字 結束-->
# <!-- 全網_新聞內頁_推薦閱讀上方文字(3) 開始 -->
# <div class="all_news_text1" id="all_news_text1">
# <script type="text/javascript">
#                                         (function() {
#                                             var ts = Math.random();
#                                             document.write('<scr' + 'ipt type="text/javascript" src="https://ad.ettoday.net/ads.php?bid=all_news_text1&rr=' + ts + '"></scr' + 'ipt>');
#                                         })()
#                                     </script>
# </div>
# <!-- 全網_新聞內頁_推薦閱讀上方文字(3) 結束 -->
# <!--各頻道PC 文末分享 開始-->
# <!--模組 et_social_2 開始-->
# <div class="et_social_2">
# <p>分享給朋友：</p>
# <!-- menu 開始 -->
# <div class="menu">
# <div class="fb_box">
# <div class="fb-like" data-action="like" data-href="https://finance.ettoday.net/news/2233305" data-layout="box_count" data-share="false" data-size="small" data-width=""></div>
# </div>
# <a class="facebook" href="javascript:;" onclick="window.open('https://www.facebook.com/sharer/sharer.php?u='+encodeURIComponent('https://finance.ettoday.net/news/2233305')+'?from=pc-newsshare-fb','facebook-share-dialog','width=626,height=436');return false;" title="分享到Facebook"></a>
# <a class="line" href="javascript:;" onclick="window.open('https://social-plugins.line.me/lineit/share?url='+encodeURIComponent('https://finance.ettoday.net/news/2233305')+'?from=pc-newsshare-line','LINE','width=626,height=500');return false;" title="分享到LINE"></a>
# <a class="twitter" href="javascript:;" onclick="window.open('https://twitter.com/intent/tweet?text='+encodeURIComponent('十大超夯股東會紀念品！聯電續推角落小夥伴　敲碗等王品、宏達電')+'&amp;url=https://finance.ettoday.net/news/2233305?from=pc-newsshare-twitter','Twittes','width=626,height=436');return false;" title="分享到Twitter"></a>
# <a class="copy-link" title="複製連結"></a>
# <a class="print" onclick="window.print();" title="列印本頁"></a>
# <a class="message scrollgo" rel=".fb-comments" title="點我留言"></a>
# </div>
# <!-- menu 結束 -->
# </div>
# <!--模組 et_social_2 結束-->
# <!--模組 et_social_3 開始-->
# <div class="et_social_3">
# <p>追蹤我們：</p>
# <!-- menu 開始 -->
# <div class="menu">
# <div class="fb_box">
# <div class="fb-page" data-adapt-container-width="false" data-height="70" data-hide-cover="false" data-href="https://www.facebook.com/ETtodaymoney" data-show-facepile="false" data-small-header="true" data-tabs="timeline" data-width="230">
# <blockquote cite="https://www.facebook.com/ETtodaymoney" class="fb-xfbml-parse-ignore"><a href="https://www.facebook.com/ETtodaymoney">掌握即時財經、理財新訊　按讚追蹤ETtoday財經雲向錢衝！</a></blockquote>
# </div>
# </div>
# <a class="youtube" href="https://www.youtube.com/user/ettoday" target="_blank" title="訂閱YouTube"></a>
# <a class="instagram" href="https://www.instagram.com/ettodaytw" target="_blank" title="追蹤IG"></a>
# <a class="line" href="https://line.me/R/ti/p/%40ETtoday" target="_blank" title="加LINE好友"></a>
# <a class="twitter" href="https://twitter.com/ettodaytw" target="_blank" title="追蹤Twitter"></a>
# <a class="telegram" href="https://t.me/ETtodaynews" target="_blank" title="追蹤Telegram"></a>
# </div>
# <!-- menu 結束 -->
# </div>
# <!--模組 et_social_3 結束-->
# <!--各頻道PC 文末分享 結束-->
# <p class="note">※本文版權所有，非經授權，不得轉載。<a href="https://www.ettoday.net/member/clause_copyright.php" target="_blank">[ETtoday著作權聲明]</a>※</p>
# </div>]

# %%
#=bs4.BeautifulSoup(content,"html.parser")
paragraphs=article[0].find_all('p') 
for paragraph in paragraphs:
    if paragraph.string!=None:
        print(paragraph.string)
# Out:
# 記者廖婕妤／綜合報導
# 股東會旺季即將到來，不少股民都相當關注股東紀念品，其中擁有百萬股民的中鋼（2002）今年推出環保餐具；聯電（2303）再以角落小夥伴帆布包作為股東會紀念品；大魯閣（1432）的消費抵用券也成為焦點；不過備受矚目的王品（2727）、宏達電（2498）則尚未公布，以下為《ETtoday新聞雲》記者特選一直是市場熱度最高10間股東會紀念品。
# 大魯閣（1432）
# 繼去年推出600元消費抵用券後，大魯閣今年的股東紀念品更狂，發放「700元消費抵用券」及「7張每月玩樂買1送1券」，總價值共2800元，雖然僅限下載大魯閣APP會員登錄使用，但由於股東持股不限股數，均可以拿到紀念品，一度成功推升股價連拉6根漲停。
# 正隆（1904）
# 造紙大廠正隆幾乎每年都以衛生紙作為股東會紀念品，今年發放「春風抽取式衛生紙一串」，股東持股不限股數，均可以拿到紀念品。
# 中鋼（2002）
# 百萬股民最期待的中鋼今年推出「精緻鈦ONE戶外型環保餐具」，雖然爆發抄襲設計爭議，但中鋼極力駁斥，方便攜帶又美觀的特點仍吸引股民目光。
# 不過要注意的是，持股未滿1000股之股東，除股東親自出席股東會或以電子方式行使表決權者得領取外，將不予發放紀念品。
# 聯電（2303）
# 聯電2020年以角落小夥伴陶瓷杯作為股東會紀念品，讓股民為之轟動，2021年推出角落小夥伴帆布包為紀念品，今年再度發放角落小夥伴帆布包，但顏色跟圖案不同。不過要留意的是，持股未滿1000股之股東，除股東親自出席股東會或以電子方式行使表決權者得領取外，將不予發放紀念品。
# ▲聯電2022年、2020年股東會紀念品。（圖／聯電提供、記者廖婕妤攝）
# 宏達電（2498）
# 宏達電過去曾推出風衣外套、後背包、運動包等實用商品做為股東會紀念品，去年更是發放休閒折疊椅，設計輕巧且方便收納。不過今年的紀念品則待揭曉。
# 王品（2727）
# 王品集團去年推出價值2516元的大禮包作為股東會紀念品，成功製造討論話題，且由於零股股東也能領，以當時股價來看，花不到200元買一股，就可以換到優惠券，可說是相當划算。不過王品今年尚未公布紀念品，讓股民相當期待。
# 華南金（2880）
# 華南金今年尚未公布紀念品，但歷年來都走實用路線，去年送出法國樂美雅餐盤2入組，前年則發放捲捲矽水瓶，讓股民相當關注今年的紀念品。
# 開發金（2883）
# 開發金去年發放智能保溫杯，今年紀念品為「彩繪花鳥碗（6入）組」。需留意持股未滿1000股之股東，除股東親自出席股東會或以電子方式行使表決權者得領取外，將不予發放紀念品。
# 永豐金（2890）
# 永豐金前年送出德國雙人牌抗菌砧板，成功擄獲家庭主婦的心，去年則是寬庭時尚旅行毯，今年紀念品為「黃金萬兩茶摳（香皂）禮盒」，股東持股不限股數，均予發放紀念品。
# 中信金（2891）
# 中信金今年尚未公布紀念品，去年推出的臺灣茶摳防疫隨身組，以及前年送出的日式碟筷架組，都被網友大讚超實用，因此今年的紀念品也讓人相當期待。
# ▲中信金2020年股東會紀念品。（圖／記者廖婕妤攝）
# 分享給朋友：
# 追蹤我們：

# %%
#Apple Daily TW

# %%
my_headers ={'cookie':'over18=1;'}
url=data['link'][5]
response = requests.get(url, headers=my_headers)
content=response.text
print(data['source'][5])
print(content)
# Out:
# Apple Daily TW
# <!DOCTYPE html>
# <html lang="zh-Hant-TW">
#     <head>
#                 <!-- Google Tag Manager For Appledaily_PRD-->
#         <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#         new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#         j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#         '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#         })(window,document,'script','dataLayer','GTM-PF4JMPC');</script>
#         <!-- End Google Tag Manager -->
#         <title>宏達電VIVE Arts與藝術家曾吳合作威尼斯雙年展｜蘋果新聞網｜蘋果日報</title>
#         <meta content="text/html; charset=UTF-8" http-equiv="content-type"/>
#         <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no">
#         <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
#         <meta property="description" content="宏達電（2498）旗下致力於藝術與科技結合的團隊VIVE Arts 宣布與藝術家、電影製作人與表演者曾吳合作2022年第59屆威尼斯國際雙年藝術展的特別藝術項目－大型影像和聲音裝置《Of Whales》。"/>
#         <meta name="keywords" content="宏達電|HTC|VIVE Arts|曾吳|威尼斯雙年展" />
#         <meta property="og:site_name" content="AppleDaily" />
#         <meta property="og:type" content="article">
#         <meta property="og:locale" content="zh_TW"/>
#         <meta property="og:locale:alternate" content="zh_TW"/>
#         <meta property="og:title" content="宏達電VIVE Arts與藝術家曾吳合作威尼斯雙年展｜蘋果新聞網｜蘋果日報">
#         <meta property="og:url" content="https://www.appledaily.com.tw/property/20220421/O3VTMUDBVVEFXK4H2LEFGSPPMA" />
#         <meta property="og:image" content="https://static-arc.appledaily.com.tw/20220421/O3VTMUDBVVEFXK4H2LEFGSPPMA/img/BCXWET36SNGDPFDXX4OVXOOCUU.jpg" />
#         <meta property="og:description" content="宏達電（2498）旗下致力於藝術與科技結合的團隊VIVE Arts 宣布與藝術家、電影製作人與表演者曾吳合作2022年第59屆威尼斯國際雙年藝術展的特別藝術項目－大型影像和聲音裝置《Of Whales》。"/>
#         <meta property="fb:app_id" content="244889285591923" />
#         <meta property="twitter:title" content="宏達電VIVE Arts與藝術家曾吳合作威尼斯雙年展｜蘋果新聞網｜蘋果日報" />
#         <meta property="twitter:description" content="宏達電（2498）旗下致力於藝術與科技結合的團隊VIVE Arts 宣布與藝術家、電影製作人與表演者曾吳合作2022年第59屆威尼斯國際雙年藝術展的特別藝術項目－大型影像和聲音裝置《Of Whales》。" />
#         <meta property="twitter:card" content="summary_large_image" />
#         <meta name="twitter:url" content="https://www.appledaily.com.tw/property/20220421/O3VTMUDBVVEFXK4H2LEFGSPPMA" />
#         <meta property="twitter:site" content="@TW_nextmedia" />
#         <link rel="shortcut icon" href="//img.appledaily.com.tw/aws/global/images/favicon.ico">
#         <link rel="shortcut icon" type="image/x-icon" href="//img.appledaily.com.tw/aws/global/images/favicon.ico">
#         <link rel="icon" type="image/ico" href="//img.appledaily.com.tw/aws/global/images/favicon.ico">
#         <link rel="canonical" href="https://www.appledaily.com.tw/property/20220421/O3VTMUDBVVEFXK4H2LEFGSPPMA"/>
#         <link rel="stylesheet" type="text/css" href="//img.appledaily.com.tw/aws/global/css/default.css?d=20220512.2" />
#         <link rel="stylesheet" href="//img.appledaily.com.tw/aws/global/css/style.css?d=20220630" />
#         <link rel="stylesheet" href="//img.appledaily.com.tw/aws/global/css/bootstrap.css?d=20220525.2" crossorigin="anonymous">
#         <link rel="stylesheet" href="//img.appledaily.com.tw/aws/global/css/customized.css?d=20220629" />
#         <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.6.0/jquery.min.js"></script>
#         <script async="async" src="https://www.googletagservices.com/tag/js/gpt.js"></script>
#         <link href="https://fonts.googleapis.com/css2?family=IBM+Plex+Serif:wght@400;700&amp;display=swap" rel="stylesheet" />
#         <script src="//img.appledaily.com.tw/aws/global/js/prebid6.4.0.js?d=206"></script>
#         <script src="//img.appledaily.com.tw/aws/global/js/index.js?d=206"></script>
#         <script src="//img.appledaily.com.tw/aws/global/js/comscore.js?d=206"></script>
#         <script src="//img.appledaily.com.tw/aws/global/js/browser.js?d=206"></script>
#         <script src="//img.appledaily.com.tw/aws/global/js/lazyload.min.js"></script>
#         <!-- <script id="gdpr-message" src="//img.appledaily.com.tw/aws/global/js/gdpr.js?cpreg=TW&platform=WEB&v=1"></script> -->        <script>
#   const mobile = [
#     {
#       name: 'interscroller',
#       dimensions: [[1, 1], [300, 250], [320, 360], [320, 480]],
#     },
#     {
#       name: 'adheadertop',
#       dimensions: [[320, 100], [1, 1]],
#     },
#     {
#       name: 'flyingcarpet1',
#       dimensions: [[1, 1], 'fluid', [300, 250], [336, 280], [320, 480]],
#     },
#     {
#       name: 'flyingcarpet2',
#       dimensions: [[1, 1], 'fluid', [300, 250], [336, 280], [320, 480]],
#     },
#     {
#       name: 'fadeinout',
#       dimensions: [[1, 1], 'fluid', [320, 50], [320, 100], [320, 180]],
#     },
#     {
#       name: 'fixedbanner1',
#       dimensions: [[1, 1], [300, 100], [300, 250], [336, 280], [370, 308]],
#     },
#     {
#       name: 'fixedbanner2',
#       dimensions: [[1, 1], [300, 100], [300, 250], [336, 280], [370, 308]],
#     },
#     {
#       name: 'fixedbanner3',
#       dimensions: [[1, 1], [300, 100], [300, 250], [336, 280], [370, 308]],
#     },
#     {
#       name: 'fixedbanner4',
#       dimensions: [[1, 1], [300, 100], [300, 250], [336, 280], [370, 308]],
#     },
#     {
#       name: 'fixedbanner5',
#       dimensions: [[1, 1], [300, 100], [300, 250], [336, 280], [370, 308]],
#     },
#     {
#       name: 'fixedbanner6',
#       dimensions: [[1, 1], [300, 100], [300, 250], [336, 280], [370, 308]],
#     },
#     {
#       name: 'fixedbanner7',
#       dimensions: [[1, 1], [300, 100], [300, 250], [336, 280], [370, 308]],
#     },
#     {
#       name: 'fixedbanner8',
#       dimensions: [[1, 1], [300, 100], [300, 250], [336, 280], [370, 308]],
#     },
#     {
#       name: 'fixedbanner9',
#       dimensions: [[1, 1], [300, 100], [300, 250], [336, 280], [370, 308]],
#     },
#     {
#       name: 'inarticlebanner1',
#       dimensions: [[1, 1], 'fluid', [300, 250], [336, 280], [320, 480]],
#     },
#     {
#       name: 'inarticlebanner2',
#       dimensions: [[1, 1], 'fluid', [300, 250], [336, 280], [320, 480]],
#     },
#     {
#       name: 'leaderboard',
#       dimensions: [[1, 1], [320, 50]],
#     },
#     {
#       name: 'lrec1',
#       dimensions: [[1, 1], [300, 250], [336, 280]],
#     },
#     {
#       name: 'lrec2',
#       dimensions: [[1, 1], [300, 250], [336, 280]],
#     },
#     {
#       name: 'lrec3',
#       dimensions: [[1, 1], [300, 250], [336, 280]],
#     },
#     {
#       name: 'lrec4',
#       dimensions: [[1, 1], [300, 250], [336, 280]],
#     },
#     {
#       name: 'middlebanner',
#       dimensions: [[1, 1], [300, 250], [336, 280], 'fluid'],
#     },
#     {
#       name: 'mpm01',
#       dimensions: [[1, 1], [760, 428], [380, 214]],
#     },
#     {
#       name: 'mpm02',
#       dimensions: [[1, 1], [760, 428], [380, 214]],
#     },
#     {
#       name: 'mpm03',
#       dimensions: [[1, 1], [760, 428], [380, 214]],
#     },
#     {
#       name: 'mpm04',
#       dimensions: [[1, 1], [760, 428], [380, 214]],
#     },
#     {
#       name: 'mpm05',
#       dimensions: [[1, 1], [760, 428], [380, 214]],
#     },
#     {
#       name: 'mpm06',
#       dimensions: [[1, 1], [760, 428], [380, 214]],
#     },
#     {
#       name: 'native1',
#       dimensions: [[1, 1], [336, 280], 'fluid'],
#     },
#     {
#       name: 'native2',
#       dimensions: [[1, 1], [336, 280], 'fluid'],
#     },
#     {
#       name: 'preroll',
#       dimensions: [[640, 360]],
#     },
#     {
#       name: 'instream',
#       dimensions: [[640, 360]],
#     },
#     {
#       name: 'endtag',
#       dimensions: [[640, 360]],
#     },
#     {
#       name: 'sponsored',
#       dimensions: [[1, 1], [320, 200]],
#     },
#     {
#       name: 'advertorial01',
#       dimensions: [[1, 1], [300, 250], [336, 280], [370, 308], [350, 295], [640, 360], 'fluid'],
#     },
#     {
#       name: 'advertorial02',
#       dimensions: [[1, 1], [300, 250], [336, 280], [370, 308], [350, 295], [640, 360], 'fluid'],
#     },
#     {
#       name: 'advertorial03',
#       dimensions: [[1, 1], [300, 250], [336, 280], [370, 308], [350, 295], [640, 360], 'fluid'],
#     },
#     {
#       name: 'advertorial04',
#       dimensions: [[1, 1], [300, 250], [336, 280], [370, 308], [350, 295], [640, 360], 'fluid'],
#     },
#     {
#       name: 'advertorial05',
#       dimensions: [[1, 1], [300, 250], [336, 280], [370, 308], [350, 295], [640, 360], 'fluid'],
#     },
#     {
#       name: 'advertorial06',
#       dimensions: [[1, 1], [300, 250], [336, 280], [370, 308], [350, 295], [640, 360], 'fluid'],
#     },
#     {
#       name: 'advertorial06',
#       dimensions: [[1, 1], [300, 250], [336, 280], [370, 308], [350, 295], [640, 360], 'fluid'],
#     },
#     {
#       name: 'leadinbox_rightrail',
#       dimensions: [[1, 1], [300, 168], [300, 250], 'fluid'],
#     },
#     {
#       name: 'netboard',
#       dimensions: [[1, 1], [560, 90], [580, 400], 'fluid'],
#     },
#     {
#       name: 'promosite',
#       dimensions: [[1, 1], [560, 90], [580, 400], [650, 100], [760, 150], 'fluid'],
#     },
#     {
#       name: 'splash',
#       dimensions: [[1, 1], [320, 480], 'fluid'],
#     },
#   ];
#
#   const desktop = [
#     {
#       name: 'adheadertop',
#       dimensions: [[970, 90], [1, 1]],
#     },
#     {
#       name: 'bottombanner',
#       dimensions: [[970, 250], [970, 160], [970, 90], [728, 90], [1, 1]],
#     },
#     {
#       name: 'endtag',
#       dimensions: [640, 360],
#     },
#     {
#       name: 'halfpage',
#       dimensions: [[300, 600], [300, 250], [1, 1]],
#     },
#     {
#       name: 'headbanner',
#       dimensions: [[1, 1], [728, 90], [970, 160], [970, 250], [970, 90]],
#     },
#     {
#       name: 'flyingcarpet',
#       dimensions: [[1, 1], [300, 250], [336, 280], [320, 480], [728, 90], [750, 200], 'fluid', [640, 360]],
#     },
#     {
#       name: 'flyingcarpet1',
#       dimensions: [[1, 1], [300, 250], [336, 280], [320, 480], [728, 90], [750, 200], 'fluid', [640, 360]],
#     },
#     {
#       name: 'flyingcarpet2',
#       dimensions: [[1, 1], [300, 250], [336, 280], [320, 480], [728, 90], [750, 200], 'fluid', [640, 360]],
#     },
#     {
#       name: 'inread',
#       dimensions: [[1, 1], [300, 250], [336, 280], [640, 360]],
#     },
#     {
#       name: 'inarticlebanner1',
#       dimensions: [[1, 1], [300, 250], [336, 280], [640, 360], [728, 90]],
#     },
#     {
#       name: 'inarticlebanner2',
#       dimensions: [[1, 1], [300, 250], [336, 280], [640, 360], [728, 90]],
#     },
#     {
#       name: 'inarticlebanner3',
#       dimensions: [[1, 1], [300, 250], [336, 280], [640, 360], [728, 90]],
#     },
#     {
#       name: 'lrec1',
#       dimensions: [[1, 1], [300, 250], [300, 600]],
#     },
#     {
#       name: 'lrec2',
#       dimensions: [[1, 1], [300, 250]],
#     },
#     {
#       name: 'lrec3',
#       dimensions: [[1, 1], [300, 250]],
#     },
#     {
#       name: 'lrec4',
#       dimensions: [[1, 1], [300, 250]],
#     },
#     {
#       name: 'lrec5',
#       dimensions: [[1, 1], [300, 250]],
#     },
#     {
#       name: 'lrec6',
#       dimensions: [[1, 1], [300, 250]],
#     },
#     {
#       name: 'middlebanner',
#       dimensions: [[970, 250], [970, 160], [970, 90], [728, 90], [1, 1]],
#     },
#     {
#       name: 'mpm01',
#       dimensions: [[1, 1], [760, 428]],
#     },
#     {
#       name: 'mpm02',
#       dimensions: [[1, 1], [760, 428]],
#     },
#     {
#       name: 'mpm03',
#       dimensions: [[1, 1], [760, 428]],
#     },
#     {
#       name: 'mpm04',
#       dimensions: [[1, 1], [760, 428]],
#     },
#     {
#       name: 'mpm05',
#       dimensions: [[1, 1], [760, 428]],
#     },
#     {
#       name: 'mpm06', // TODO logic for diffent sections differet different dimensions
#       dimensions: [[1, 1], [760, 428]],
#     },
#     {
#       name: 'native5',
#       dimensions: [[1, 1], [704, 130], 'fluid'],
#     },
#     {
#       name: 'native6',
#       dimensions: [[1, 1], [704, 130], 'fluid'],
#     },
#     {
#       name: 'preroll',
#       dimensions: [[640, 360]],
#     },
#     {
#       name: 'instream',
#       dimensions: [[640, 360]],
#     },
#     {
#       name: 'sponsored',
#       dimensions: [[1, 1], [400, 50]],
#     },
#     {
#       name: 'advertorial01',
#       dimensions: [[1, 1], [240, 264], [640, 360], [650, 100], [760, 150], 'fluid'],
#     },
#     {
#       name: 'advertorial02',
#       dimensions: [[1, 1], [240, 264], [640, 360], [650, 100], [760, 150], 'fluid'],
#     },
#     {
#       name: 'advertorial03',
#       dimensions: [[1, 1], [240, 264], [640, 360], [650, 100], [760, 150], 'fluid'],
#     },
#     {
#       name: 'advertorial04',
#       dimensions: [[1, 1], [240, 264], [640, 360], [650, 100], [760, 150], 'fluid'],
#     },
#     {
#       name: 'advertorial05',
#       dimensions: [[1, 1], [240, 264], [640, 360], [650, 100], [760, 150], 'fluid'],
#     },
#     {
#       name: 'advertorial06',
#       dimensions: [[1, 1], [240, 264], [640, 360], [650, 100], [760, 150], 'fluid'],
#     },
#     {
#       name: 'advertorial07',
#       dimensions: [[1, 1], [240, 264], [640, 360], [650, 100], [760, 150], 'fluid'],
#     },
#     {
#       name: 'advertorial08',
#       dimensions: [[1, 1], [240, 264], [640, 360], [650, 100], [760, 150], 'fluid'],
#     },
#     {
#       name: 'advertorial09',
#       dimensions: [[1, 1], [240, 264], [640, 360], [650, 100], [760, 150], 'fluid'],
#     },
#     {
#       name: 'skyscraper1',
#       dimensions: [[120, 600], [150, 660], [160, 600]],
#     },
#     {
#       name: 'skyscraper2',
#       dimensions: [[120, 600], [150, 660], [160, 600]],
#     },
#     {
#       name: 'leadinbox_rightrail',
#       dimensions: [[1, 1], [300, 168], [300, 250], 'fluid'],
#     },
#     {
#       name: 'netboard',
#       dimensions: [[1, 1], [560, 90], [580, 400], 'fluid'],
#     },
#     {
#       name: 'promosite',
#       dimensions: [[1, 1], [650, 100], [760, 150], 'fluid'],
#     },
#     {
#       name: 'articlelistad',
#       dimensions: [[1, 1], [650, 100], [760, 150], 'fluid'],
#     },
#   ];
#
#   window.googletag = window.googletag || {};
#   googletag.cmd = googletag.cmd || [];
#
#   googletag.cmd.push(function() {
#     window.adTypes = {
#       mobile,
#       desktop
#     };
#   });
#
# </script>
#
#     <script>
#         window.googletag = window.googletag || {};
#         googletag.cmd = googletag.cmd || [];
#
#         let device = (/Android|webOS|iPhone|iPad|iPod|BlackBerry|IEMobile|Opera Mini/i.test(navigator.userAgent) ? "MOBWEB" : "WEB");
#         googletag.cmd.push(function () {
#             googletag.pubads().disableInitialLoad();
#             googletag.pubads().collapseEmptyDivs();
#
#         });
#     </script>
#
# <script>
#     /* --- ads targeting --- */
#     window.googletag = window.googletag || {};
#     googletag.cmd = googletag.cmd || [];
#
#     const getParameterByName = function (prop) {
#         const params = {};
#         const search = ((typeof window !== 'undefined') && window.location)
#             ? decodeURIComponent(window.location.href.slice(window.location.href.indexOf('?') + 1)) : '';
#         const definitions = search.split('&');
#
#         definitions.forEach(function (val) {
#             const parts = val.split('=', 2);
#             params[parts[0]] = parts[1]; /* eslint-disable-line prefer-destructuring */
#         });
#
#         return (prop && prop in params) ? params[prop] : params;
#     };
#     const dpfParam = getParameterByName('dfppreview');
#
#
#     const articleId = `O3VTMUDBVVEFXK4H2LEFGSPPMA`;
#     const path = window.location.pathname.replace(/\/$/, "");
#     const targeting = {
#         CN: 'TAIPEI',
#         CC: 'TW',
#         S: '',
#         OMO_MEMBER: '0',
#         L: 'TC',
#         apple_daily_article_id: 'NIL',
#         arc_article_id: articleId ? articleId : path,
#         CAT: 'property',
#         dfppreview: typeof dpfParam === 'string' ? dpfParam : 'NIL',
#         KY: '宏達電,HTC,VIVE Arts,曾吳,威尼斯雙年展',
#     };
#
#     googletag.cmd.push(function () {
#         for (const key in targeting) {
#             googletag.pubads().setTargeting(key, targeting[key]);
#         }
#     });
#
# </script>
#
# <script>
#
# const APPNEXUS_BIDDER_NAME = 'appnexus';
# // Bridgewell
# const BRIDGEWELL_BIDDER_NAME = 'bridgewell';
# // rubicon
# const RUBICON_BIDDER_NAME = 'rubicon';
#
# const TW_APPNEXUS_PLACEMENT_ID_CATALOG = {
#     // TW Apple Daily_Desktop
#     web: {
#         lrec6: 13801051,
#         lrec5: 13801050,
#         lrec4: 13801049,
#         lrec3: 13801048,
#         lrec2: 13801047,
#         inarticlebanner1: 22264615,
#         inarticlebanner2: 13801052,
#         inarticlebanner3: 22264622,
#         headbanner: 13801045,
#         lrec1: 13801046,
#         preroll: 14877333,
#         leadinbox_rightrail: 19727296,
#         halfpage: 19727298,
#         bottombanner: 19727299,
#     },
#     // TW Apple Daily_Mobile Web
#     mweb: {
#         lrec3: 13801069,
#         lrec2: 13801068,
#         lrec1: 13801067,
#         middlebanner: 13801071,
#         flyingcarpet1: 13801066,
#         fixedbanner1: 13801056,
#         fixedbanner2: 13801057,
#         fixedbanner3: 13801058,
#         fixedbanner4: 13801059,
#         fixedbanner5: 13801060,
#         fixedbanner6: 13801061,
#         fixedbanner7: 13801062,
#         fixedbanner8: 13801063,
#         fixedbanner9: 13801064,
#         fadeinout: 13801070,
#         leaderboard: 13801065,
#         preroll: 14877368,
#         interscroller: 19727300,
#     },
#   };
#
#   const TW_BRIDGEWELL_CHANNEL_ID_CATALOG = {
#     // TW Apple Daily_Desktop
#     web: {
#       groupList: 'Apple Daily_Desktop',
#       lrec6: 15961,
#       lrec5: 16247,
#       lrec4: 16246,
#       lrec3: 16245,
#       lrec2: 16244,
#       lrec1: 15963,
#       bottombanner: 18241,
#       inarticlebanner2: 16248,
#       inarticlebanner3: 19041,
#       headbanner: 15962,
#       halfpage: 18240,
#     },
#     // TW Apple Daily_Mobile Web
#     mweb: {
#       interscroller: 16251,
#       lrec3: 15965,
#       lrec2: 16250,
#       lrec1: 16249,
#       flyingcarpet1: 16252,
#       flyingcarpet2: 19015,
#       articletopbanner: 16252,
#       fixedbanner1: 16253,
#       fixedbanner2: 16254,
#       fixedbanner3: 16255,
#       fixedbanner4: 16256,
#       fixedbanner5: 16257,
#       fixedbanner6: 16258,
#       fixedbanner7: 16258,
#       fixedbanner8: 16260,
#       fixedbanner9: 16261,
#       fadeinout: 16061,
#     },
#   };
#
#   const TW_RUBICON_CONFIG_DESKTOP = {
#     // Apple Daily TW
#     accountId: 18530,
#     site: 'Apple Daily TW - Prebid',
#     siteId: 203154,
#     zone: 'Prebid ROS',
#     zoneId: 1001604,
#   };
#
#   const TW_RUBICON_CONFIG_MOBILE = {
#     // Apple Daily TW Mobile
#     accountId: 18530,
#     site: 'Apple Daily TW - Prebid',
#     siteId: 203154,
#     zone: 'Prebid ROS',
#     zoneId: 1001604,
#   };
#
#   const TW_RUBICON_SIZE_MAP = {
#     '320x50': 43,
#     '300x250': 15,
#     '970x250': 57,
#     '970x90': 55,
#     '300x600': 10,
#   };
#
#   const getPreBidVendors = function () {
#     const vendors = {
#       appnexus: TW_APPNEXUS_PLACEMENT_ID_CATALOG,
#       bridgewell: TW_BRIDGEWELL_CHANNEL_ID_CATALOG,
#       rubicon: {
#         config: device === 'WEB' ? TW_RUBICON_CONFIG_DESKTOP : TW_RUBICON_CONFIG_MOBILE,
#         sizeMap: TW_RUBICON_SIZE_MAP,
#       },
#     };
#
#     return vendors;
#   };
#
#   const getPreBidConfig = function (adTypeName, dimensions) {
#     const breakpoint = device === 'WEB' ? 'web' : 'mweb';
#     const vendor = getPreBidVendors();
#
#     let rubiconSizes = [];
#     const bids = [];
#
#     // get Rubicon Size Id Array
#     if (dimensions) {
#       // eslint-disable-next-line arrow-parens
#       const adsizes = dimensions.filter(adsize => Array.isArray(adsize));
#       const dimensionList = adsizes.map((dim) => `${dim[0]}x${dim[1]}`);
#       rubiconSizes = dimensionList.filter((size) => (vendor.rubicon.sizeMap[size]))
#         .map((size) => vendor.rubicon.sizeMap[size]);
#     }
#
#     // APPNEXUS
#     if (vendor.appnexus && vendor.appnexus[breakpoint][adTypeName]) {
#       bids.push(
#         {
#           bidder: APPNEXUS_BIDDER_NAME,
#           params: {
#             placementId: vendor.appnexus[breakpoint][adTypeName],
#           },
#         },
#       );
#     }
#
#     // BRIDGEWELL
#     if (vendor.bridgewell && vendor.bridgewell[breakpoint][adTypeName]) {
#       bids.push(
#         {
#           bidder: BRIDGEWELL_BIDDER_NAME,
#           params: {
#             cid: vendor.bridgewell[breakpoint][adTypeName],
#           },
#         },
#       );
#     }
#
#     // RUBICON
#     if ((rubiconSizes).length > 0) {
#       bids.push(
#         {
#           bidder: RUBICON_BIDDER_NAME,
#           params: {
#             ...vendor.rubicon.config,
#             sizes: rubiconSizes,
#           },
#         },
#       );
#     }
#
#     const prebidConfig = {
#       prebid: {
#         enabled: bids.length > 0,
#         timeout: 4000,
#         useSlotForAdUnit: true,
#         bids,
#         config: {
#           userSync: {
#             syncsPerBidder: 0,
#             filterSettings: {
#               iframe: {
#                 bidders: '*', // '*' means all bidders
#                 filter: 'include',
#               },
#             },
#           },
#         },
#       },
#     };
#
#     return prebidConfig;
#   };
#
#   const addPbUnit = function (code, sizes, bids, wrapper = {}) {
#     // Formats the add unit for prebid..
#     const slot = { code, bids };
#     const bannerSizes = [];
#     let videoSize;
#     // size examples:
#     // [300, 250]
#     // '[640, 360v]'
#     // 'fluid'
#     sizes.forEach((s) => {
#       const dimensions = typeof s === 'string' && s.match(/\d+/g);
#       if (typeof dimensions === 'object' && dimensions !== null && dimensions.length === 2) {
#         videoSize = dimensions.map((dimension) => Number(dimension));
#       } else if (s !== 'fluid') {
#         bannerSizes.push(s);
#       }
#     });
#
#     slot.mediaTypes = {};
#     if (bannerSizes.length > 0) slot.mediaTypes.banner = { sizes: bannerSizes };
#     if (typeof videoSize === 'object' && videoSize.length === 2) {
#       slot.mediaTypes.video = { context: 'outstream', playerSize: videoSize };
#     }
#
#     const { sizeConfig, config } = wrapper;
#     window.pbjs.addAdUnits(slot);
#
#     if (config) {
#       window.pbjs.setConfig(config);
#       return;
#     }
#
#     if (sizeConfig) {
#       window.pbjs.setConfig({ sizeConfig });
#     }
#   }
#
#   window.pbjs = window.pbjs || {};
#   pbjs.que = pbjs.que || [];
#
#   window.googletag = window.googletag || {};
#   googletag.cmd = googletag.cmd || [];
#
#   // pbjs.que.push(function() {
#   //   pbjs.setConfig({
#   //     debugging: {
#   //       enabled: true,
#   //       bids: [{
#   //         cpm: 1.5
#   //       }]
#   //     }
#   //   });
#   // });
#
#   const addPbUnitWithType = function(code, type) {
#     const adTypes = device === 'WEB' ? window.adTypes.desktop : window.adTypes.mobile;
#     const adType = adTypes.filter((ad) => ad.name === type)[0];
#     const bidding = getPreBidConfig(type, adType && adType.dimensions);
#     addPbUnit(code, adType && adType.dimensions, bidding.prebid.bids, bidding.prebid);
#   }
#
#
#   window.getSlotName = function(type) {
#     const isArticle = 1;
#
#     const isMobile = device === 'MOBWEB';
#     const siteSuffix = isMobile ? '_MobileSite' : '';
#     const unitSuffix = '';
#
#     var slot = `/7476/TWAppleDaily${siteSuffix}/realtimenews_property_detail${unitSuffix}/${type}`;
#
#     /* Re-map section if necessary */
#     slot = slot.replace('_supplement_', '_lifestyle_');
#     slot = slot.replace('_property_', '_finance_');
#
#     return slot;
#   }
#
#   window.addDFPSlot = function(type, divId) {
#     const targetDivId = divId || type;
#     const enableAD = 1;
#     const slot = getSlotName(type);
#
#     const adTypes = device === 'WEB' ? window.adTypes.desktop : window.adTypes.mobile;
#     const adType = adTypes.filter((ad) => ad.name === type)[0];
#     if (!adType) {
#       console.log('adType not found', adType, type);
#     }
#
#     var slotObj = googletag.defineSlot(slot, adType.dimensions, targetDivId).addService(googletag.pubads());
#     googletag.pubads().enableSingleRequest();
#
#     if (enableAD) {
#       googletag.enableServices();
#     } else {
#       console.log('ads is disabled');
#     }
#
#     pbjs.que.push(function() {
#       addPbUnitWithType(slot, type);
#     });
#
#     return slotObj;
#   };
#
#   function initAdserver(bids) {
#     if (pbjs.initAdserverSet) return;
#     console.log('received bids', bids);
#     pbjs.initAdserverSet = true;
#     googletag.cmd.push(function() {
#       pbjs.que.push(function() {
#         pbjs.setTargetingForGPTAsync();
#         googletag.pubads().refresh();
#       });
#     });
#   }
#
#   window.onload = function() {
#     pbjs.que.push(function() {
#       pbjs.requestBids({
#         bidsBackHandler: initAdserver,
#         timeout: 4000
#       });
#     });
#
#     if (window.dable){
#       if (device === 'WEB') {
#         window.dable('renderWidget', 'dablewidget_Ql9p5R74');
#       } else {
#         window.dable('renderWidget', 'dablewidget_2XLYyVoO');
#       }
#     }
#   }
#
# </script>
#
#         <script>
#     const intialData = {
#         event: "gtm.init",
#                 c1:"O3VTMUDBVVEFXK4H2LEFGSPPMA",
#                 c10:"宏達電VIVE Arts與藝術家曾吳合作威尼斯雙年展",
#                 c13:"O3VTMUDBVVEFXK4H2LEFGSPPMA",
#                 c16:"即時",
#                 c17:"財經地產",
#                 c18:"NIL",
#                 c19:"財經地產",
#                 c20:"property",
#                 c21:"ARTICLE",
#                 c22:"REALTIME",
#                 c23:"TWAD",
#                 c24:"NIL",
#                 c25:"宏達電|HTC|VIVE Arts|曾吳|威尼斯雙年展",
#                 c26:"20220421",
#                 c27:"ARTICLE",
#                 c28:"俐妏 陳",
#                 c40: "TC"
#     };
#     const geoDimensions = getGeoDimensions();
#     const nxtu = getCookie("nxtu");
#     const registeredSession = getCookie("omoaccid") ? "YES" : "NO";
#     const platform = isMobileDevice() ? "MOBWEB" : "WEB";
#     dataLayer = [
#         Object.assign(intialData, geoDimensions, {
#             c29: platform,
#             c101: nxtu
#         })
#     ];
# </script>
#
#         <!-- outbrain -->
#         <script>
#             const hasOutbrainScript = document.querySelectorAll(
#                     'script[src="//widgets.outbrain.com/outbrain.js"]',
#                     ).length === 0;
#
#             if (!hasOutbrainScript) {
#                 if (window.OBR) {
#                     OBR.extern.researchWidget();
#                 }
#             } else {
#                 const thirdPartyScript = document.createElement('script');
#                 thirdPartyScript.src = '//widgets.outbrain.com/outbrain.js';
#                 thirdPartyScript.async = 'async';
#                 document.getElementsByTagName('head')[0].appendChild(thirdPartyScript);
#             }
#         </script>
#
#         <!-- Dable -->
#         <script>
#             (function (d, a, b, l, e, _) {
#                 d[b] = d[b] || function () {
#                     (d[b].q = d[b].q || []).push(arguments)
#                 };
#                 e = a.createElement(l);
#                 e.async = 1;
#                 e.charset = 'utf-8';
#                 e.src = '//static.dable.io/dist/plugin.min.js';
#                 _ = a.getElementsByTagName(l)[0];
#                 _.parentNode.insertBefore(e, _);
#             })(window, document, 'dable', 'script');
#             dable('setService', 'tw.appledaily.com');
#             dable('sendLogOnce');
#         </script>
#     </head>
#     <body>
#         <noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-PF4JMPC" height="0" width="0" style="display: none; visibility: hidden;"></iframe></noscript>
#         <div id="fusion-app" class="fusion-app">
#             <div id="apd_omo" class="box--hidden"></div>
#             <div class="desktop">
#                 <div class="apd-grid global-masthead">
#     <header id="global-header" class="apd-grid__col--lg-12 apd-grid__col--md-8 apd-grid__col--sm-4">
#         <div class="TW-MOBILE-AD interscroller_outer_wrapper" id="5555interscroller">
#             <div class="interscroller_wrapper">
#                 <div class="dfpAd text--center interscroller_inner dfpAd text--center box--hidden-md" id="interscroller" style="height:250px;background-color: #9e9e9e0a;">
#                     <script>
#                         googletag.cmd.push(function () {
#                             if (device === 'MOBWEB') {
#                                 addDFPSlot("interscroller");
#                                 googletag.display("interscroller");
#                             }
#                         });
#                     </script>
#                 </div>
#             </div>
#         </div>
#         <script>
#             $(function () {
#                 $('.hamburger-menu-icon').on('click', function () {
#                     $('.hamburgerSubMenu').toggleClass(['box--hidden', 'box--position-absolute', 'box--display-block']);
#                 });
#                 $('.sectionTop').on('click', function () {
#                     $(this).find('div.arrow-hamburger').toggleClass(['arrow-down', 'arrow-up', 'box--margin-bottom-sm', 'box--margin-top-sm']);
#                     $(this).parent().find('div.box--hidden:eq(0)').toggle();
#                 });
#             });
#         </script>
#         <header class="background_cerulean">
#             <div class="header-bar flex flex--align-items-center flex--justify-space-between" style="height: 50px;">
#                 <div class="flex flex--align-items-center">
#                     <div class="hamburger-menu">
#                         <div id="hamburger-icon" class="hamburger-menu-icon outline-none pointer" role="menu" tabindex="0">
#                             <div class="bar background_white"></div>
#                             <div class="bar background_white"></div>
#                             <div class="bar background_white"></div>
#                         </div>
#                         <div class="hamburgerSubMenu box--hidden" data-burger="true">
#                             <div class="hamburger-primary-menu">
#                                 <div class="sites-bar sites-bar-highlight box--display-flex flex--align-items-center flex--justify-start">
#                                     <a href="https://www.appledaily.com.tw/">台灣</a>
#                                 </div>
#                                 <div class="primary-sections overflow-y-scroll">
#                                     <div>
#                                         <div class="sectionTop ">
#                                             <a href="/" class="sectionItemTop box--display-flex flex--justify-space-between  undefined">首頁</a>
#                                         </div>
#                                     </div>
#                                     <div>
#                                         <div class="sectionTop undefined">
#                                             <div class="box--display-flex flex--justify-space-between outline-none" role="menuitem" tabindex="0">
#                                                 即時
#                                                 <div class="arrow arrow-hamburger arrow-down box--margin-bottom-sm"></div>
#                                             </div>
#                                         </div>
#                                         <div class="box--hidden">
#                                             <div class="hamburgerDivider"></div>
#                                             <div class="sections-list ">
#                                                 <div class="item"><div class="sectionTop  undefined"><a id="/realtime/recommend" href="/realtime/recommend/" class="sectionItemTop box--display-flex flex--justify-space-between  undefined"> 焦點 </a></div></div>
#                                                 <div class="item"><div class="sectionTop  undefined"><a id="/realtime/new" href="/realtime/new/" class="sectionItemTop box--display-flex flex--justify-space-between  undefined"> 最新 </a></div></div>
#                                                 <div class="item"><div class="sectionTop  undefined"><a id="/realtime/hot" href="/realtime/hot/" class="sectionItemTop box--display-flex flex--justify-space-between  undefined"> 熱門 </a></div></div>
#                                                 <div class="item"><div class="sectionTop  undefined"><a id="/realtime/entertainment" href="/realtime/entertainment/" class="sectionItemTop box--display-flex flex--justify-space-between  undefined"> 娛樂時尚 </a></div></div>
#                                                 <div class="item"><div class="sectionTop  undefined"><a id="/realtime/life" href="/realtime/life/" class="sectionItemTop box--display-flex flex--justify-space-between  undefined"> 生活 </a></div></div>
#                                                 <div class="item"><div class="sectionTop  undefined"><a id="/realtime/local" href="/realtime/local/" class="sectionItemTop box--display-flex flex--justify-space-between  undefined"> 社會 </a></div></div>
#                                                 <div class="item"><div class="sectionTop  undefined"><a id="/realtime/property" href="/realtime/property/" class="sectionItemTop box--display-flex flex--justify-space-between  undefined"> 財經地產 </a></div></div>
#                                                 <div class="item"><div class="sectionTop  undefined"><a id="/realtime/international" href="/realtime/international/" class="sectionItemTop box--display-flex flex--justify-space-between  undefined"> 國際 </a></div></div>
#                                                 <div class="item"><div class="sectionTop  undefined"><a id="/realtime/politics" href="/realtime/politics/" class="sectionItemTop box--display-flex flex--justify-space-between  undefined"> 政治 </a></div></div>
#                                                 <div class="item"><div class="sectionTop  undefined"><a id="/realtime/sports" href="/realtime/sports/" class="sectionItemTop box--display-flex flex--justify-space-between  undefined"> 體育 </a></div></div>
#                                                 <div class="item"><div class="sectionTop  undefined"><a id="/realtime/supplement" href="/realtime/supplement/" class="sectionItemTop box--display-flex flex--justify-space-between  undefined"> 吃喝玩樂 </a></div></div>
#                                                 <div class="item"><div class="sectionTop  undefined"><a id="/realtime/gadget" href="/realtime/gadget/" class="sectionItemTop box--display-flex flex--justify-space-between  undefined"> 3C車市 </a></div></div>
#                                                 <div class="item"><div class="sectionTop  undefined"><a id="/realtime/forum" href="/realtime/forum/" class="sectionItemTop box--display-flex flex--justify-space-between  undefined"> 蘋評理 </a></div></div>
#                                                 <div class="item"><div class="sectionTop  undefined"><a id="/realtime/column" href="/realtime/column/" class="sectionItemTop box--display-flex flex--justify-space-between  undefined"> 火線 </a></div></div></div>
#                                             <div class="hamburgerDivider"></div>
#                                         </div>
#                                     </div>
#                                     <div>
#                                         <div class="sectionTop  undefined">
#                                             <div class="box--display-flex flex--justify-space-between outline-none " role="menuitem" tabindex="0">專區<div class="arrow arrow-hamburger arrow-down box--margin-bottom-sm"></div></div>
#                                         </div>
#                                         <div class=" box--hidden ">
#                                             <div class="hamburgerDivider"></div>
#                                             <div class="sections-list ">
#                                                 <div class="item"><div class="sectionTop  undefined"><a id="/members/health" href="https://tw.feature.appledaily.com/health/" class="sectionItemTop box--display-flex flex--justify-space-between  undefined"> 健康蘋道 </a></div></div>
#                                                 <div class="item"><div class="sectionTop  undefined"><a id="/members/home" href="https://tw.feature.appledaily.com/house/" class="sectionItemTop box--display-flex flex--justify-space-between  undefined"> 蘋果地產 </a></div></div>
#                                                 <div class="item"><div class="sectionTop  undefined"><a id="/members/foodtravel" href="https://tw.feature.appledaily.com/foodtravel/" class="sectionItemTop box--display-flex flex--justify-space-between  undefined"> 飲食男女 </a></div></div>
#                                                 <div class="item"><div class="sectionTop  undefined"><a id="/members/twebook" href="https://tw.feature.appledaily.com/ebook/home" class="sectionItemTop box--display-flex flex--justify-space-between  undefined"> 讀果 </a></div></div>
#                                                 <div class="item"><div class="sectionTop  undefined"><a id="/members/fashion" href="https://fashion.appledaily.com.tw/" class="sectionItemTop box--display-flex flex--justify-space-between  undefined"> Apple Fashion </a></div></div>
#                                                 <div class="item"><div class="sectionTop  undefined"><a id="/members/travelseed" href="https://tw.feature.appledaily.com/travelseed/" class="sectionItemTop box--display-flex flex--justify-space-between  undefined"> 只想旅行 </a></div></div>
#                                                 <div class="item"><div class="sectionTop  undefined"><a id="/realtime/pr" href="/realtime/pr/" class="sectionItemTop box--display-flex flex--justify-space-between  undefined"> 消費熱區 </a></div></div>
#                                                 <div class="item"><div class="sectionTop  undefined"><a id="/realtime/family" href="/realtime/family/" class="sectionItemTop box--display-flex flex--justify-space-between  undefined"> 一家人 </a></div></div>
#                                                 <div class="item"><div class="sectionTop  undefined"><a id="/realtime/pet" href="/realtime/pet/" class="sectionItemTop box--display-flex flex--justify-space-between  undefined"> 動物蘋台 </a></div></div>
#                                                 <div class="item"><div class="sectionTop  undefined"><a id="/freezone/tomonews" href="http://www.tomonews.com/" class="sectionItemTop box--display-flex flex--justify-space-between  undefined"> Tomonews </a></div></div>
#                                             </div>
#                                             <div class="hamburgerDivider"></div>
#                                         </div>
#                                     </div>
#                                     <div>
#                                         <div class="sectionTop undefined">
#                                             <a id="/feature" href="/realtime/entertainment/" class="sectionItemTop box--display-flex flex--justify-space-between undefined">娛樂蘋道</a>
#                                         </div>
#                                     </div>
#                                     <div>
#                                         <div class="sectionTop undefined">
#                                             <div class="box--display-flex flex--justify-space-between outline-none" role="menuitem" tabindex="0">
#                                                 動新聞
#                                                 <div class="arrow arrow-hamburger arrow-down box--margin-bottom-sm"></div>
#                                             </div>
#                                         </div>
#                                         <div class="box--hidden">
#                                             <div class="hamburgerDivider"></div>
#                                             <div class="sections-list ">
#                                                 <div class="item"><div class="sectionTop  undefined"><a id="/video/new" href="/video/new/" class="sectionItemTop box--display-flex flex--justify-space-between  undefined"> 最新 </a></div></div>
#                                                 <div class="item"><div class="sectionTop  undefined"><a id="/video/hot" href="/video/hot/" class="sectionItemTop box--display-flex flex--justify-space-between  undefined"> 熱門 </a></div></div>
#                                                 <div class="item"><div class="sectionTop  undefined"><a id="/video/politics" href="/video/politics/" class="sectionItemTop box--display-flex flex--justify-space-between  undefined"> 政治 </a></div></div>
#                                                 <div class="item"><div class="sectionTop  undefined"><a id="/video/entertainment" href="/video/entertainment/" class="sectionItemTop box--display-flex flex--justify-space-between  undefined"> 娛樂時尚 </a></div></div>
#                                                 <div class="item"><div class="sectionTop  undefined"><a id="/video/life" href="/video/life/" class="sectionItemTop box--display-flex flex--justify-space-between  undefined"> 生活 </a></div></div>
#                                                 <div class="item"><div class="sectionTop  undefined"><a id="/video/local" href="/video/local/" class="sectionItemTop box--display-flex flex--justify-space-between  undefined"> 社會 </a></div></div>
#                                                 <div class="item"><div class="sectionTop  undefined"><a id="/video/international" href="/video/international/" class="sectionItemTop box--display-flex flex--justify-space-between  undefined"> 國際 </a></div></div>
#                                                 <div class="item"><div class="sectionTop  undefined"><a id="/video/micromovie" href="/video/micromovie/" class="sectionItemTop box--display-flex flex--justify-space-between  undefined"> 微視蘋 </a></div></div>
#                                                 <div class="item"><div class="sectionTop  undefined"><a id="/video/property" href="/video/property/" class="sectionItemTop box--display-flex flex--justify-space-between  undefined"> 財經地產 </a></div></div>
#                                                 <div class="item"><div class="sectionTop  undefined"><a id="/video/gadget" href="/video/gadget/" class="sectionItemTop box--display-flex flex--justify-space-between  undefined"> 3C車市 </a></div></div>
#                                                 <div class="item"><div class="sectionTop  undefined"><a id="/video/supplement" href="/video/supplement/" class="sectionItemTop box--display-flex flex--justify-space-between  undefined"> 吃喝玩樂 </a></div></div>
#                                                 <div class="item"><div class="sectionTop  undefined"><a id="/video/sports" href="/video/sports/" class="sectionItemTop box--display-flex flex--justify-space-between  undefined"> 體育 </a></div></div></div>
#                                             <div class="hamburgerDivider"></div>
#                                         </div>
#                                     </div>
#                                     <div>
#                                         <div class="sectionTop  undefined"><a id="/complain" href="https://tw-survey.appledaily.com/s/bLGaK" target="_blank" class="sectionItemTop box--display-flex flex--justify-space-between  undefined"> 爆料投訴 </a></div>
#                                     </div>
#                                     <div>
#                                         <div class="sectionTop  undefined"><a id="/charity" href="https://tw.feature.appledaily.com/charity/" target="_blank" class="sectionItemTop box--display-flex flex--justify-space-between  undefined"> 蘋果慈善基金會 </a></div>
#                                     </div>
#                                     <div>
#                                         <!--<div class="sectionTop  undefined"><a id="/archive" href="" class="sectionItemTop box--display-flex flex--justify-space-between  undefined"> 蘋果日報昔日新聞 </a></div>-->
#                                     </div>
#                                 </div>
#                             </div>
#                         </div>
#                     </div>
#                     <div>
#                         <a href="https://www.appledaily.com.tw/">
#                             <img title="蘋果新聞網" src="//img.appledaily.com.tw/aws/global/images/logo_appleonline_w.png" height="41" width="110" id="mastheadLogo" class="visual__image" alt="蘋果新聞網" />
#                         </a>
#                     </div>
#                 </div>
#                 <div class="flex flex--align-items-center">
#                     <div class="member-campaign">
#                         <a class="flex" href="https://tw.adai.ly/downloadapp">
#                             <img alt="membership campaign button" class="member-campaign-button" src="//img.appledaily.com.tw/aws/global/images/twad_app_download_2022_red.png" style="height: 35px;">
#                         </a>
#                     </div>
#                     <form class="search-bar flex flex--align-self-center">
#                         <input class="box--pad-left-md box--hidden-sm" placeholder="搜尋" type="text" value="" style="border-top-left-radius: 5px; border-bottom-left-radius: 5px; border: none;">
#                         <button type="submit" value="submit" class="search-icon-container background_white flex flex--align-self-center box--hidden-sm" style="margin: 0px; border-top-right-radius: 5px; border-bottom-right-radius: 5px; cursor: pointer;">
#                             <img src="//img.appledaily.com.tw/aws/global/images/search_icon.svg?d=287" width="17px" height="17px" alt="搜尋" class="flex flex--align-self-center box--margin-horizontal">
#                         </button>
#                     </form>
#                     <script>
#                         $('form.search-bar').on('submit',function(){
#                             location.href='/search/'+$(this).find('input').val();
#                             return false;
#                         });
#                     </script>
#                 </div>
#             </div>
#             <button class="back-to-top-button" style="display:none;"><img src="//img.appledaily.com.tw/aws/global/images/backToTop.png?d=213" class="back-to-top-img" alt="backToTop"></button>
#             <script>
#                 $(window).scroll(function () {
#                     var scrollTop = window.pageYOffset || document.documentElement.scrollTop || document.body.scrollTop;
#                     $('.back-to-top-button').toggle(scrollTop > 0).click(function () {
#                         $(window).scrollTop(0);
#                     });
#                 });
#             </script>
#         </header>
#         <!-- category start-->
#         <!--primary-->
#                             <!--secondary-->
#             <div class="section-nav box--display-flex section-nav-secondary link_greyish-brown-two background_white  section-nav-desktop-device section-nav-mobile-device">
#                 <div class="section-name-container "><div class="section-name flex "><a href="/realtime/recommend/">焦點</a></div></div>
#                 <div class="section-name-container "><div class="section-name flex "><a href="/realtime/new/">最新</a></div></div>
#                 <div class="section-name-container "><div class="section-name flex "><a href="/realtime/hot/">熱門</a></div></div>
#                 <div class="section-name-container "><div class="section-name flex "><a href="/realtime/entertainment/">娛樂時尚</a></div></div>
#                 <div class="section-name-container "><div class="section-name flex "><a href="/realtime/life/">生活</a></div></div>
#                 <div class="section-name-container "><div class="section-name flex "><a href="/realtime/local/">社會</a></div></div>
#                 <div class="section-name-container section-name-container-underscore"><div class="section-name flex "><a href="/realtime/property/">財經地產</a></div></div>
#                 <div class="section-name-container "><div class="section-name flex "><a href="/realtime/international/">國際</a></div></div>
#                 <div class="section-name-container "><div class="section-name flex "><a href="/realtime/politics/">政治</a></div></div>
#                 <div class="section-name-container "><div class="section-name flex "><a href="/realtime/sports/">體育</a></div></div>
#                 <div class="section-name-container "><div class="section-name flex "><a href="/realtime/supplement/">吃喝玩樂</a></div></div>
#                 <div class="section-name-container "><div class="section-name flex "><a href="/realtime/gadget/">3C車市</a></div></div>
#                 <div class="section-name-container "><div class="section-name flex "><a href="/realtime/forum/">蘋評理</a></div></div>
#                 <div class="section-name-container "><div class="section-name flex "><a href="/realtime/column/">火線</a></div></div>
#             </div>
# ...
#                     <a href="/life/20220707/7C1C6EA28CB06E90A88F184A3C" class="story-card">
#                         <div class="image-container">
#                                                         <figure>
#                                 <img data-src="https://static.appledaily.com.tw/prod/2022-07/7C1C6EA28CB06E90A88F184A3C/8d3826b789c22e279df74db4d791a4b7_small.jpg" src="..." alt="自備環保杯折5元　專家：買飲料「帶這款」裝最滿又保冰" class="aspect-tall img-loaded lazyload" style="object-fit: cover;" />
#                             </figure>
#                                                     </div>
#                         <div class="text-container box--margin-left-md box--margin-right-md">
#                             <div class="storycard-headline text_greyish-brown-two"><span class="headline truncate truncate--3">自備環保杯折5元　專家：買飲料「帶這款」裝最滿又保冰</span></div>
#                         </div>
#                     </a>
#                 </div>
#                                     <div class="HK-DESKTOP-AD">
#                         <div class="dfpAd text--center dfpAd text--center box--hidden-sm ad-container" id="leadinbox_rightrail">
#                             <script>
#                                 googletag.cmd.push(function() {
#                                     if(device === 'WEB'){
#                                         addDFPSlot("leadinbox_rightrail");
#                                         googletag.display("leadinbox_rightrail");
#                                     }
#                                 });
#                             </script>
#                         </div>
#                     </div>
#                                                                 <div class="flex-feature">
#                     <a href="/entertainment/20220708/1CD980874AEF61E4CEBE7C8C2B" class="story-card">
#                         <div class="image-container">
#                                                         <figure>
#                                 <img data-src="https://static.appledaily.com.tw/prod/2022-07/1CD980874AEF61E4CEBE7C8C2B/d4e2c646a33c48096024cce80992612f_small.jpg" src="..." alt="中國歌迷愛瘋了！周杰倫新專輯預售一夜進帳1.4億" class="aspect-tall img-loaded lazyload" style="object-fit: cover;" />
#                             </figure>
#                                                     </div>
#                         <div class="text-container box--margin-left-md box--margin-right-md">
#                             <div class="storycard-headline text_greyish-brown-two"><span class="headline truncate truncate--3">中國歌迷愛瘋了！周杰倫新專輯預售一夜進帳1.4億</span></div>
#                         </div>
#                     </a>
#                 </div>
#                                                                 <div class="flex-feature">
#                     <a href="/life/20220708/B98786A9FF3D9C2D29ED28808B" class="story-card">
#                         <div class="image-container">
#                                                         <figure>
#                                 <img data-src="https://static.appledaily.com.tw/prod/2022-07/B98786A9FF3D9C2D29ED28808B/2dffcd35ba6ceec62c0d72f611d48c5a_small.jpg" src="..." alt="長髮正妹確診1個半月驚見「恐怖症狀」超崩潰　醫分析：長新冠所致" class="aspect-tall img-loaded lazyload" style="object-fit: cover;" />
#                             </figure>
#                                                     </div>
#                         <div class="text-container box--margin-left-md box--margin-right-md">
#                             <div class="storycard-headline text_greyish-brown-two"><span class="headline truncate truncate--3">長髮正妹確診1個半月驚見「恐怖症狀」超崩潰　醫分析：長新冠所致</span></div>
#                         </div>
#                     </a>
#                 </div>
#                                                                 <div class="flex-feature">
#                     <a href="/entertainment/20220708/3630D7255421B7E34BF89D8021" class="story-card">
#                         <div class="image-container">
#                                                         <figure>
#                                 <img data-src="https://static.appledaily.com.tw/prod/2022-07/3630D7255421B7E34BF89D8021/1b1b2b6d24359dc25254399aaa391ff3_small.jpg" src="..." alt="《灌籃高手》電影12月上映　首波19秒預告片曝光！百萬人暴動" class="aspect-tall img-loaded lazyload" style="object-fit: cover;" />
#                             </figure>
#                                                     </div>
#                         <div class="text-container box--margin-left-md box--margin-right-md">
#                             <div class="storycard-headline text_greyish-brown-two"><span class="headline truncate truncate--3">《灌籃高手》電影12月上映　首波19秒預告片曝光！百萬人暴動</span></div>
#                         </div>
#                     </a>
#                 </div>
#                                                                 <div class="flex-feature">
#                     <a href="/life/20220708/F19E378E378572E224B69AED51" class="story-card">
#                         <div class="image-container">
#                                                         <figure>
#                                 <img data-src="https://static.appledaily.com.tw/prod/2022-07/F19E378E378572E224B69AED51/e6128eb92155f714fe1e2d27f1dac385_small.jpg" src="..." alt="學校查論文「董座卻幫林智堅打氣」　游淑慧揭兩人「超緊密關係」：看不懂的是傻子" class="aspect-tall img-loaded lazyload" style="object-fit: cover;" />
#                             </figure>
#                                                     </div>
#                         <div class="text-container box--margin-left-md box--margin-right-md">
#                             <div class="storycard-headline text_greyish-brown-two"><span class="headline truncate truncate--3">學校查論文「董座卻幫林智堅打氣」　游淑慧揭兩人「超緊密關係」：看不懂的是傻子</span></div>
#                         </div>
#                     </a>
#                 </div>
#                                                                 <div class="flex-feature">
#                     <a href="/politics/20220707/390FB0F78EB874FC87712BE34D" class="story-card">
#                         <div class="image-container">
#                                                         <figure>
#                                 <img data-src="https://static.appledaily.com.tw/prod/2022-07/390FB0F78EB874FC87712BE34D/466d0a334951b46362e2ebc6397b801f_small.jpg" src="..." alt="林智堅論文檢索系統判定文章重覆42%　深綠醫痛斥「你懶到人神共憤」" class="aspect-tall img-loaded lazyload" style="object-fit: cover;" />
#                             </figure>
#                                                             <div class="video-icon">
#                                     <div class="video-triangle-container"><div class="video-triangle"></div></div>
#                                 </div>
#                                                     </div>
#                         <div class="text-container box--margin-left-md box--margin-right-md">
#                             <div class="storycard-headline text_greyish-brown-two"><span class="headline truncate truncate--3">林智堅論文檢索系統判定文章重覆42%　深綠醫痛斥「你懶到人神共憤」</span></div>
#                         </div>
#                     </a>
#                 </div>
#                                                                 <div class="flex-feature">
#                     <a href="/entertainment/20220708/9B37D696AD06709DD54E531260" class="story-card">
#                         <div class="image-container">
#                                                         <figure>
#                                 <img data-src="https://static.appledaily.com.tw/prod/2022-07/9B37D696AD06709DD54E531260/4c3427a1f5ff93d770466530451b7eab_small.jpg" src="..." alt="謝忻綠島曬大露背辣照！目標「換4套比基尼」　粉絲敲碗正面" class="aspect-tall img-loaded lazyload" style="object-fit: cover;" />
#                             </figure>
#                                                     </div>
#                         <div class="text-container box--margin-left-md box--margin-right-md">
#                             <div class="storycard-headline text_greyish-brown-two"><span class="headline truncate truncate--3">謝忻綠島曬大露背辣照！目標「換4套比基尼」　粉絲敲碗正面</span></div>
#                         </div>
#                     </a>
#                 </div>
#                                             </div>
#             <div id="lazy-load-divider-2154"></div>
#         </div>
#         <div class="HK-DESKTOP-AD">
#         <div class="dfpAd text--center dfpAd text--center box--hidden-sm undefined" id="halfpage">
#             <script>
#                 googletag.cmd.push(function() {
#                     if(device === 'WEB'){
#                         addDFPSlot("halfpage");
#                         googletag.display("halfpage");
#                     }
#                 });
#             </script>
#         </div>
#     </div>
# </aside>
#                             <div class="grid__col--lg-1"></div>
#                         </div>
#                     </section>
#                 </div>
#                 <div class="TW-DESKTOP-AD">
#     <div class="dfpAd text--center dfpAd text--center box--hidden-sm inlineArticleAds" id="bottombanner">
#         <script>
#             googletag.cmd.push(function () {
#                 if (device === 'WEB') {
#                     addDFPSlot("bottombanner");
#                     googletag.display("bottombanner");
#                 }
#             });
#         </script>
#     </div>
# </div>
# <footer>
#     <div class="tw-footer box--pad-vertical-lg background_pale-lavender">
#         <div>
#             <div class="box--hidden-lg box--hidden-md tw-footer--mobile-links text--mobile font-size--14 link_greyish-brown-two ">
#                 <div class="flex flex--justify-center flex--wrap">
#                     <div class="box--margin footer--tw-mobile-item">
#                         <a href="https://www.appledaily.com.tw/" class="text__link  footer--tw-separator" target="_blank" rel="noreferrer noopener">台灣</a>
#                     </div>
#                     <div class="box--margin footer--tw-mobile-item">
#                         <a href="https://tw.feature.appledaily.com/info/termofuse" class="text__link  footer--tw-separator" target="_blank" rel="noreferrer noopener">使用條款</a>
#                     </div>
#                     <div class="box--margin footer--tw-mobile-item">
#                         <a href="https://tw.feature.appledaily.com/info/contactus" class="text__link " target="_blank" rel="noreferrer noopener">聯絡我們</a>
#                     </div>
#                 </div>
#             </div>
#             <div class="box--hidden-sm tw-footer--desktop-links text--desktop font-size--12 link_greyish-brown-two ">
#                 <div class="flex flex--justify-center flex--wrap">
#                     <div class="box--margin footer--tw-desktop-item text_greyish-brown-two">壹傳媒：</div>
#                     <div class="box--margin footer--tw-desktop-item">
#                         <a href="https://www.appledaily.com.tw/" class="text__link  footer--tw-separator" target="_blank" rel="noreferrer noopener">
#                             <span class="text_cerulean">台灣</span>
#                         </a>
#                     </div>
#                     <div class="box--margin footer--tw-desktop-item"><a href="https://tw.feature.appledaily.com/info/aboutus" class="text__link  footer--tw-separator" target="_blank" rel="noreferrer noopener"><span class="">了解蘋果日報</span></a></div>
#                     <div class="box--margin footer--tw-desktop-item"><a href="https://tw.feature.appledaily.com/info/contactus" class="text__link  footer--tw-separator" target="_blank" rel="noreferrer noopener"><span class="">聯絡我們</span></a></div>
#                     <div class="box--margin footer--tw-desktop-item"><a href="https://tw.feature.appledaily.com/collection/adguide" class="text__link  footer--tw-separator" target="_blank" rel="noreferrer noopener"><span class="">廣告刊登</span></a></div>
#                     <div class="box--margin footer--tw-desktop-item"><a href="https://tw.feature.appledaily.com/info/faq" class="text__link  footer--tw-separator" target="_blank" rel="noreferrer noopener"><span class="">常見問題</span></a></div>
#                     <div class="box--margin footer--tw-desktop-item"><a href="https://tw.feature.appledaily.com/info/termofuse" class="text__link  footer--tw-separator" target="_blank" rel="noreferrer noopener"><span class="">使用條款</span></a></div>
#                     <div class="box--margin footer--tw-desktop-item"><a href="https://tw.feature.appledaily.com/info/authorization" class="text__link  footer--tw-separator" target="_blank" rel="noreferrer noopener"><span class="">授權申請程序</span></a></div>
#                     <div class="box--margin footer--tw-desktop-item"><a href="https://tw.feature.appledaily.com/info/privacy" class="text__link  footer--tw-separator" target="_blank" rel="noreferrer noopener"><span class="">隱私權說明</span></a></div>
#                     <div class="box--margin footer--tw-desktop-item"><a href="https://tw.feature.appledaily.com/info/disclaimer" class="text__link  footer--tw-separator" target="_blank" rel="noreferrer noopener"><span class="">免責與分級</span></a></div>
#                     <div class="box--margin footer--tw-desktop-item"><a href="https://tw.feature.appledaily.com/info/community" class="text__link  footer--tw-separator" target="_blank" rel="noreferrer noopener"><span class="">蘋果社群</span></a></div>
#                     <div class="box--margin footer--tw-desktop-item"><a href="https://www.facebook.com/nextdigitalstudent/" class="text__link  footer--tw-separator" target="_blank" rel="noreferrer noopener"><span class="">校園培果計畫</span></a></div>
#                     <div class="box--margin footer--tw-desktop-item"><a href="http://www.104.com.tw/jobbank/custjob/index.php?r=cust&amp;j=5e3a4326486c3e6a30323c1d1d1d1d5f2443a363189j01&amp;jobsource=checkc" class="text__link  footer--tw-separator" target="_blank" rel="noreferrer noopener"><span class="">蘋果徵才</span></a></div>
#                     <div class="box--margin footer--tw-desktop-item"><a href="https://tw.feature.appledaily.com/collection/subscribe" class="text__link  footer--tw-separator" target="_blank" rel="noreferrer noopener"><span class="">訂閱蘋果</span></a></div>
#                     <div class="box--margin footer--tw-desktop-item"><a href="https://tw.feature.appledaily.com/ethics/" class="text__link " target="_blank" rel="noreferrer noopener"><span class="">蘋果自律委員會</span></a></div>
#                 </div>
#             </div>
#         </div>
#         <div class="tw-footer-copyright font-size--12 text_brown-grey text--center flex flex--justify-center flex--wrap box--pad-vertical">
#             <div class="text--word_break-keep_all"><span>© 2022 APPLE ONLINE All rights reserved. </span><span class="text--white_space-nowrap">蘋果新聞網 版權所有 不得轉載</span></div>
#         </div>
#     </div>
# </footer>
# <script>$("img.lazyload").lazyload();</script>            </div>
#         </div>
#         <script type="application/ld+json">
#             {
#             "@context": "https://schema.org",
#             "@type": "NewsArticle",
#             "mainEntityOfPage": {
#             "@type": "WebPage",
#             "@id": "https://www.appledaily.com.tw/property/20220421/O3VTMUDBVVEFXK4H2LEFGSPPMA"
#             },
#             "headline": "宏達電VIVE Arts與藝術家曾吳合作威尼斯雙年展｜蘋果新聞網｜蘋果日報",
#             "image": [
#             "https://static-arc.appledaily.com.tw/20220421/O3VTMUDBVVEFXK4H2LEFGSPPMA/img/BCXWET36SNGDPFDXX4OVXOOCUU.jpg"
#             ],
#             "datePublished": "2022-04-21T16:43:00+08:00",
#             "dateModified": "2022-04-21T16:30:00+08:00",
#             "author": {
#             "@type": "Organization",
#             "name": "蘋果新聞網",
#             "url":"https://www.appledaily.com.tw/"
#             },
#             "publisher": {
#             "@type": "Organization",
#             "name": "蘋果新聞網",
#             "logo": {
#             "@type": "ImageObject",
#             "url": "//img.appledaily.com.tw/aws/global/images/logo_appleonline_w.png"
#             }
#             },
#             "description": "宏達電（2498）旗下致力於藝術與科技結合的團隊VIVE Arts 宣布與藝術家、電影製作人與表演者曾吳合作2022年第59屆威尼斯國際雙年藝術展的特別藝術項目－大型影像和聲音裝置《Of Whales》。"
#             }
#         </script>
#     </body>
# </html>

# %%
print(url)
# Out:
# https://www.appledaily.com.tw/property/20220421/O3VTMUDBVVEFXK4H2LEFGSPPMA/

# %%
root=bs4.BeautifulSoup(content,"html.parser")
article=root.find_all('div',class_="article_body article-text-size_md")
print(article)
# Out:
# [<div class="article_body article-text-size_md" id="articleBody">
# <section>
# <div class="tw-social">
# <div class="tw-desktop-social_container vertical box--hidden-sm social-container-NHESKYXTPFDDXJ2OURDAXNZWYY hidden">
# <div class="flex social-icon social-icon_facebook flex--align-self-center" data-social="Facebook" onclick="FB.ui({method: 'share', href: 'https://www.appledaily.com.tw/property/20220421/O3VTMUDBVVEFXK4H2LEFGSPPMA?utm_campaign=twad_article_share&amp;utm_medium=social&amp;utm_source=facebook&amp;utm_content=share_link'}, function (response) {})" role="link" tabindex="0"></div>
# <div class="flex social-icon social-icon_twitter flex--align-self-center" data-social="Twitter" onclick="javascript:void(window.open('http://twitter.com/intent/tweet?text='.concat(encodeURIComponent('宏達電VIVE Arts與藝術家曾吳合作威尼斯雙年展')).concat(' ').concat(encodeURIComponent('https://www.appledaily.com.tw/property/20220421/O3VTMUDBVVEFXK4H2LEFGSPPMA?utm_campaign=twad_article_share&amp;utm_medium=social&amp;utm_source=twitter&amp;utm_content=share_link'))));" role="link" tabindex="0"></div>
# <div class="flex social-icon social-icon_system flex--align-self-center" data-social="URL_copy" onclick="$temp = $('&lt;input value=https://www.appledaily.com.tw/property/20220421/O3VTMUDBVVEFXK4H2LEFGSPPMA?utm_campaign=twad_article_share&amp;utm_medium=social&amp;utm_source=url_copy&amp;utm_content=share_link&gt;');
#                                                             $('body').append($temp);
#                                                             $temp.select();
#                                                             ;
#                                                             document.execCommand('Copy');
#                                                             $temp.remove();
#                                                             alert('連結已複製')" role="link" tabindex="0"></div>
# </div>
# </div>
# </section>
# <section>
# <p class="text--desktop text--mobile article-text-size_md tw-max_width">宏達電（2498）旗下致力於藝術與科技結合的團隊VIVE Arts 宣布與藝術家、電影製作人與表演者曾吳合作2022年第59屆威尼斯國際雙年藝術展的特別藝術項目－大型影像和聲音裝置《Of Whales》。</p>
# <div class="THISISANADHERE">
# <div class="TW-MOBILE-AD-WRAP">
# <div class="flyingCarpet_outer_wrapper" id="da60b9dc">
# <div class="TW-MOBILE-AD flyingCarpet_wrapper">
# <div class="flyingCarpet_reveal">
# <div class="dfpAd text--center flyingCarpet_inner dfpAd text--center box--hidden-md inlineArticleAds flyingCarpet_inner" id="flyingcarpet1">
# <script>
#                         googletag.cmd.push(function () {
#                             if (device === 'MOBWEB') {
#                                 addDFPSlot("flyingcarpet1");
#                                 googletag.display('flyingcarpet1');
#
#                                 googletag.pubads().addEventListener('slotRenderEnded', function(event) {
#                                     const divId = event.slot.getSlotElementId();
#                                     if (divId === 'flyingcarpet1' && event.isEmpty) {
#                                         /* hide empty flying carpet */
#                                         $(`#da60b9dc`).hide();
#                                     }
#                                 });
#                             }
#                         });
#                     </script>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="TW-DESKTOP-AD">
# <div class="dfpAd text--center dfpAd text--center box--hidden-sm inlineArticleAds" id="inarticlebanner1">
# <script>
#             googletag.cmd.push(function () {
#                 if (device === 'WEB') {
#                     addDFPSlot("inarticlebanner1");
#                     googletag.display("inarticlebanner1");
#                 }
#             });
#         </script>
# </div>
# </div>
# </div>
# <p class="text--desktop text--mobile article-text-size_md tw-max_width">作品將於2022 年 4 月 23 日至 11 月 27 日期間展出作為塞西莉雅．阿萊馬尼（Cecilia Alemani）所策劃的「夢之牛奶」（The Milk of Dreams）主題展覽中一部份。雙方所合作的《Of Whales》全新沉浸式VR藝術作品，為曾吳首件展出的VR創作，預計將於巴塞爾藝術展（Art Basel, Switzerland）中展出。</p>
# <p class="text--desktop text--mobile article-text-size_md tw-max_width">曾吳的作品享譽全球，跨越了不同流派和學科，類型包含敘事和紀錄影片，以及現場表演和影像裝置。在2022年威尼斯雙年展上，她將展示自己橫跨多學科的新一代藝術家作品風格。這件作品的靈感來自赫曼‧梅爾維爾（Herman Melville）的《白鯨記》（Moby Dick）。</p>
# <p class="text--desktop text--mobile article-text-size_md tw-max_width">VIVE Arts讓藝術家能夠使用各種數位工具和媒材來突破表現界限，從而解放藝術家的創意力。在這件新作品中，曾吳利用虛擬實境創空間的建構能力，與法國阿爾比恩（Albyon）工作室攜手創作了一部動態的即時電影。 《Of Whales》採用了Unity 遊戲引擎創作，能夠連續播放，呼應了抹香鯨晝夜循環的遨遊和深海潛伏，讓觀眾每次與之相遇都能擁有全新的體驗。</p>
# <div class="THISISANADHERE">
# <!-- use random id to prevent collision with desktop adunit with same name -->
# <div class="TW-MOBILE-AD">
# <div class="dfpAd text--center dfpAd text--center box--hidden-md" id="51bbc6b3">
# <script>
#             googletag.cmd.push(function () {
#                 if (device === 'MOBWEB') {
#                     addDFPSlot("inarticlebanner2", '51bbc6b3');
#                     googletag.display("51bbc6b3");
#                 }
#             });
#         </script>
# </div>
# </div>
# <div class="TW-DESKTOP-AD">
# <div class="dfpAd text--center dfpAd text--center box--hidden-sm inlineArticleAds" id="inarticlebanner2">
# <script>
#             googletag.cmd.push(function () {
#                 if (device === 'WEB') {
#                     addDFPSlot("inarticlebanner2");
#                     googletag.display("inarticlebanner2");
#                 }
#             });
#         </script>
# </div>
# </div>
# </div>
# <p class="text--desktop text--mobile article-text-size_md tw-max_width">曾吳表示，很榮幸能與VIVE Arts合作，身為一名電影製作人，最期待非線性敘事的可能性，這種可能性對於《白鯨記》這類建構世界的小說來說似乎相當完美。</p>
# <p class="text--desktop text--mobile article-text-size_md tw-max_width">VIVE Arts總監葉心宇則表示，《Of Whales》則展示了創新數位科技如何開闢新的藝術表現形式，賦予人們以不同的方式看待世界並與世界互動。宏達電希望能為提供一種帶有連結感知、想像的中介特性及引人入勝的情感體驗。（陳俐妏／台北報導）</p>
# <div class="related-links"></div>
# </section>
# <!-- insert ads at the bottom of article -->
# <div class="TW-DESKTOP-AD">
# <div class="dfpAd text--center dfpAd text--center box--hidden-sm inlineArticleAds" id="inarticlebanner3">
# <script>
#             googletag.cmd.push(function () {
#                 if (device === 'WEB') {
#                     addDFPSlot("inarticlebanner3");
#                     googletag.display("inarticlebanner3");
#                 }
#             });
#         </script>
# </div>
# </div>
# <div class="TW-MOBILE-AD-WRAP">
# <div class="flyingCarpet_outer_wrapper" id="4445219c">
# <div class="TW-MOBILE-AD flyingCarpet_wrapper">
# <div class="flyingCarpet_reveal">
# <div class="dfpAd text--center flyingCarpet_inner dfpAd text--center box--hidden-md inlineArticleAds flyingCarpet_inner" id="flyingcarpet2">
# <script>
#                         googletag.cmd.push(function () {
#                             if (device === 'MOBWEB') {
#                                 addDFPSlot("flyingcarpet2");
#                                 googletag.display('flyingcarpet2');
#
#                                 googletag.pubads().addEventListener('slotRenderEnded', function(event) {
#                                     const divId = event.slot.getSlotElementId();
#                                     if (divId === 'flyingcarpet2' && event.isEmpty) {
#                                         /* hide empty flying carpet */
#                                         $(`#4445219c`).hide();
#                                     }
#                                 });
#                             }
#                         });
#                     </script>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- use random id to prevent collision with desktop adunit with same name -->
# <div class="TW-MOBILE-AD">
# <div class="dfpAd text--center dfpAd text--center box--hidden-md" id="8e6a65e9">
# <script>
#             googletag.cmd.push(function () {
#                 if (device === 'MOBWEB') {
#                     addDFPSlot("middlebanner", '8e6a65e9');
#                     googletag.display("8e6a65e9");
#                 }
#             });
#         </script>
# </div>
# </div>
# <div class="tags grid grid__col apd-grid__col--sm-4 apd-grid4__col--md-8 apd-grid__col--lg-12">
# <div class="box--position-absolute-center ont-size--16 box--display-flex flex--wrap tags-container">
# <a href="/search/宏達電" target="_blank">宏達電</a>
# <a href="/search/HTC" target="_blank">HTC</a>
# <a href="/search/VIVE Arts" target="_blank">VIVE Arts</a>
# <a href="/search/曾吳" target="_blank">曾吳</a>
# <a href="/search/威尼斯雙年展" target="_blank">威尼斯雙年展</a>
# </div>
# </div>
# <!-- sponsored ads -->
# <div class="TW-DESKTOP-AD">
# <div class="dfpAd text--center dfpAd text--center box--hidden-sm inlineArticleAds" id="sponsored">
# <script>
#             googletag.cmd.push(function () {
#                 if (device === 'WEB') {
#                     addDFPSlot("sponsored");
#                     googletag.display("sponsored");
#                 }
#             });
#         </script>
# </div>
# </div>
# <!-- use random id to prevent collision with desktop adunit with same name -->
# <div class="TW-MOBILE-AD">
# <div class="dfpAd text--center dfpAd text--center box--hidden-md" id="17d0ce33">
# <script>
#             googletag.cmd.push(function () {
#                 if (device === 'MOBWEB') {
#                     addDFPSlot("sponsored", '17d0ce33');
#                     googletag.display("17d0ce33");
#                 }
#             });
#         </script>
# </div>
# </div>
# <!-- mobile Dable -->
# <div data-widget_id="2XLYyVoO" id="dablewidget_2XLYyVoO">
# </div>
# <!-- desktop Dable -->
# <div data-widget_id="Ql9p5R74" id="dablewidget_Ql9p5R74">
# </div>
# <div class="rcb-wrapper box--margin-top-xl"></div>
# </div>]

# %%
#=bs4.BeautifulSoup(content,"html.parser")
paragraphs=article[0].find_all('p') 
for paragraph in paragraphs:
    if paragraph.string!=None:
        print(paragraph.string)
# Out:
# 宏達電（2498）旗下致力於藝術與科技結合的團隊VIVE Arts 宣布與藝術家、電影製作人與表演者曾吳合作2022年第59屆威尼斯國際雙年藝術展的特別藝術項目－大型影像和聲音裝置《Of Whales》。
# 作品將於2022 年 4 月 23 日至 11 月 27 日期間展出作為塞西莉雅．阿萊馬尼（Cecilia Alemani）所策劃的「夢之牛奶」（The Milk of Dreams）主題展覽中一部份。雙方所合作的《Of Whales》全新沉浸式VR藝術作品，為曾吳首件展出的VR創作，預計將於巴塞爾藝術展（Art Basel, Switzerland）中展出。
# 曾吳的作品享譽全球，跨越了不同流派和學科，類型包含敘事和紀錄影片，以及現場表演和影像裝置。在2022年威尼斯雙年展上，她將展示自己橫跨多學科的新一代藝術家作品風格。這件作品的靈感來自赫曼‧梅爾維爾（Herman Melville）的《白鯨記》（Moby Dick）。
# VIVE Arts讓藝術家能夠使用各種數位工具和媒材來突破表現界限，從而解放藝術家的創意力。在這件新作品中，曾吳利用虛擬實境創空間的建構能力，與法國阿爾比恩（Albyon）工作室攜手創作了一部動態的即時電影。 《Of Whales》採用了Unity 遊戲引擎創作，能夠連續播放，呼應了抹香鯨晝夜循環的遨遊和深海潛伏，讓觀眾每次與之相遇都能擁有全新的體驗。
# 曾吳表示，很榮幸能與VIVE Arts合作，身為一名電影製作人，最期待非線性敘事的可能性，這種可能性對於《白鯨記》這類建構世界的小說來說似乎相當完美。
# VIVE Arts總監葉心宇則表示，《Of Whales》則展示了創新數位科技如何開闢新的藝術表現形式，賦予人們以不同的方式看待世界並與世界互動。宏達電希望能為提供一種帶有連結感知、想像的中介特性及引人入勝的情感體驗。（陳俐妏／台北報導）
