# %%
# https://finmind.github.io/quickstart/

# %%
import requests
import pandas as pd
url = "https://api.finmindtrade.com/api/v4/data"
parameter = {
    "dataset": "TaiwanStockNews",
    "data_id":"2498", #宏達電
    "start_date": "2022-04-15",
    "end_date": "2022-07-05",
    "token": "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJkYXRlIjoiMjAyMi0wNy0wOCAwOTozMzo0NyIsInVzZXJfaWQiOiJwZWktY2kiLCJpcCI6IjIyMC4xMzYuNDIuMTM5In0.PK15IPBoLxx7wZMB8MH9cc-daEYj3KKghKJ_DHxlSKs", # 參考登入，獲取金鑰
}
data = requests.get(url, params=parameter)
data = data.json()
data = pd.DataFrame(data['data'])
#print(data.head())
print(data)
# Out:
#                     date stock_id  \
# 0    2022-04-15 06:48:57     2498
# 1    2022-04-15 07:00:00     2498
# 2    2022-04-19 09:15:00     2498
# 3    2022-04-19 09:15:00     2498
# 4    2022-04-19 09:15:00     2498
# ..                   ...      ...
# 364  2022-07-04 05:09:00     2498
# 365  2022-07-04 05:12:36     2498
# 366  2022-07-04 06:48:11     2498
# 367  2022-07-04 16:14:02     2498
# 368  2022-07-04 16:15:53     2498
#
#                                                   link                source  \
# 0    https://www.chinatimes.com/realtimenews/202204...  中時新聞網 Chinatimes.com
# 1    https://www.chinatimes.com/realtimenews/202204...  中時新聞網 Chinatimes.com
# 2             https://finance.ettoday.net/news/2233305            ETtoday財經雲
# 3             https://finance.ettoday.net/news/2233305            ETtoday財經雲
# 4             https://finance.ettoday.net/news/2233305            ETtoday財經雲
# ..                                                 ...                   ...
# ...

# %%
for source in data["source"]:
    print(source)
# Out:
# 中時新聞網 Chinatimes.com
# 中時新聞網 Chinatimes.com
# ETtoday財經雲
# ETtoday財經雲
# ETtoday財經雲
# Apple Daily TW
# udn.com
# 經濟日報
# 經濟日報
# udn.com
# 蘋果新聞網
# 經濟日報
# udn.com
# 經濟日報
# Yahoo奇摩股市
# ETtoday財經雲
# Yahoo奇摩股市
# udn.com
# 經濟日報
# 經濟日報
# ETtoday財經雲
# ETtoday財經雲
# Yahoo奇摩股市
# 中時新聞網 Chinatimes.com
# 中時新聞網 Chinatimes.com
# 中時新聞網 Chinatimes.com
# 旺得富 WantRich
# 旺得富 WantRich
# udn.com
# 中時新聞網 Chinatimes.com
# Yahoo奇摩股市
# 旺得富 WantRich
# 旺得富 WantRich
# udn.com
# 經濟日報
# Yahoo奇摩股市
# Yahoo奇摩股市
# 民視新聞網FTVn
# udn.com
# 經濟日報
# Anue鉅亨
# udn.com
# 經濟日報
# 鉅亨網
# 民視新聞網FTVn
# 鉅亨新聞
# cnyes.com
# Anue鉅亨
# 經濟日報
# 經濟日報
# Yahoo奇摩股市
# 旺得富 WantRich
# 中時新聞網 Chinatimes.com
# 旺得富 WantRich
# 中時新聞網 Chinatimes.com
# 旺得富 WantRich
# Apple Daily TW
# Apple Daily TW
# 蘋果新聞網
# 蘋果新聞網
# 經濟日報
# 蘋果新聞網
# Apple Daily TW
# 蘋果新聞網
# Apple Daily TW
# Yahoo奇摩股市
# Yahoo奇摩股市
# udn.com
# Yahoo奇摩股市
# Yahoo奇摩股市
# Yahoo奇摩股市
# Yahoo奇摩股市
# Yahoo奇摩股市
# Yahoo奇摩股市
# Yahoo奇摩股市
# Yahoo奇摩股市
# ETtoday財經雲
# udn.com
# Yahoo奇摩股市
# udn.com
# 經濟日報
# ...

# %%
list=[]
for source in data['source']:
    if source in list:
        continue
    list.append(source)

# %%
for source in list:
    print(source)
# Out:
# 中時新聞網 Chinatimes.com
# ETtoday財經雲
# Apple Daily TW
# udn.com
# 經濟日報
# 蘋果新聞網
# Yahoo奇摩股市
# 旺得富 WantRich
# 民視新聞網FTVn
# Anue鉅亨
# 鉅亨網
# 鉅亨新聞
# cnyes.com
# MoneyDJ理財網
# EBC東森財經新聞
# 工商時報
# 新浪台灣
# TechNews 科技新報
# 科技新報
# finance.technews.tw
# ETtoday新聞雲
# Yahoo奇摩新聞
# Yahoo奇摩
# HiNet 新聞社群
# Investing.com
# 今周刊-在今天看見明天
# 自由財經
# 信傳媒
# MSN
# 台視
# 自由時報

# %%
import requests

# %%
# Out:
# <!DOCTYPE html>
# <html lang="zh-Hant-TW">
# <head id="Head1" prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#">
# <meta charset="utf-8">
# <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
# <title>《通信網路》宏達電VIVE Arts再當藝術咖 前進倫敦蛇形藝廊 - 財經 - 時報資訊</title>
# <meta name="viewport" content="width=device-width, initial-scale=1.0">
#
# <meta property="og:url" itemprop="url" content="https://www.chinatimes.com/realtimenews/20220415003322-260410">
# <meta property="og:title" itemprop="name" content="《通信網路》宏達電VIVE Arts再當藝術咖 前進倫敦蛇形藝廊 - 財經">
# <meta property="og:image" itemprop="image" content="https://static.chinatimes.com/images/2020/logo-chinatimes-250x250.png">
# <meta property="og:image:width" content="250">
# <meta property="og:image:height" content="250">
# <meta name="twitter:card" content="summary_large_image">
# <meta property="og:type" content="article">
# ...

# %%
print(url)
# Out:
# https://www.chinatimes.com/realtimenews/20220415003322-260410

# %%
print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
#compression_opts = dict(method='zip',archive_name='FinMind_News_Source.xml')
data.to_excel('FinMind_News_Source.xlsx')
    #"csv_data=data.to_csv()\n",
    #"print(csv_data)"
