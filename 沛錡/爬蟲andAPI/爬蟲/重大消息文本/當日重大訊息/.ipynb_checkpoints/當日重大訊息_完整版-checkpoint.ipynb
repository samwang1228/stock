# %%
import requests
import pandas as pd
import bs4
import datetime
import time as t

# %%
data = {'date': [], 'time': [], "title": [], 'content': [], 'co_id': [], 'date_of_event': []}

# %%
url='https://mops.twse.com.tw/mops/web/t05st02'

# %%
s_year=2022
s_month=7
s_day=1
date=datetime.datetime(s_year,s_month,s_day)
for i in range(181):
    date=date - datetime.timedelta(days=1)
    year=str(date.year-1911)
    month=str(date.month)
    day=str(date.day)
    
    payload = {
            "encodeURIComponent": "1",
            "step": "1",
            "step00": "0",
            "firstin": "1",
            "off": "1",
            "TYPEK": "all",
            "year": year,
            "month": month,
            "day": day,
       }

    #request url
    try:
        response = requests.post(url, data = payload)
    except:
        print('!')
        t.sleep(20)
        response = requests.post(url, data = payload)
    
    t.sleep(3.1)
    raw_data=response.text
    #print(raw_data)

    #解析response
    soup = bs4.BeautifulSoup(raw_data, 'html.parser')

    #提取訊息
    rowDatasEven = soup.find_all('tr',class_='even')
    rowDatasOdd = soup.find_all('tr',class_='odd')
    rowDatas=rowDatasEven+rowDatasOdd
    if rowDatas==[]:
        continue
    
    for i in range(len(rowDatas)):
        columns=rowDatas[i].find_all('td')
        if len(columns)<5:
            continue
        #print(i,'\n')
        #print(columns,'\n')
        #提取欄位資料
        colDatas=[]
        for col in columns[5].find_all('input'):
              colDatas.append(col.get('value'))
        if len(colDatas)<9:
            continue
        #整理資料
        #date 發布日期
        data['date'].append(colDatas[2])
        #print(data['date'])

        #time 發布時間
        time=colDatas[3]
        if len(time)==5:
              time='0'+time
        data['time'].append(time)
        #print(data['time'])

        #title 標題
        data['title'].append(colDatas[4])
        #print(data['title'])

        #content 內文
        data['content'].append(colDatas[8])
        #print(data['content'])


        #co_id 股票代號
        data['co_id'].append(colDatas[1])
        #print(data['co_id'])

        #date_of_event 事實發布日期
        data['date_of_event'].append(colDatas[7])
        #print(data['date_of_event'])
    print(date)

#轉成DataFrame
result=pd.DataFrame(data)
# Out:
# 2022-06-30 00:00:00
# 2022-06-29 00:00:00
# 2022-06-28 00:00:00
# 2022-06-27 00:00:00
# 2022-06-26 00:00:00
# 2022-06-25 00:00:00
# 2022-06-24 00:00:00
# 2022-06-23 00:00:00
# 2022-06-22 00:00:00
# 2022-06-21 00:00:00
# 2022-06-20 00:00:00
# 2022-06-19 00:00:00
# 2022-06-18 00:00:00
# 2022-06-17 00:00:00
# 2022-06-16 00:00:00
# 2022-06-15 00:00:00
# 2022-06-14 00:00:00
# 2022-06-13 00:00:00
# 2022-06-12 00:00:00
# 2022-06-11 00:00:00
# 2022-06-10 00:00:00
# 2022-06-09 00:00:00
# 2022-06-08 00:00:00
# 2022-06-07 00:00:00
# 2022-06-06 00:00:00
# 2022-06-05 00:00:00
# 2022-06-04 00:00:00
# 2022-06-03 00:00:00
# 2022-06-02 00:00:00
# 2022-06-01 00:00:00
# 2022-05-31 00:00:00
# 2022-05-30 00:00:00
# 2022-05-29 00:00:00
# 2022-05-28 00:00:00
# 2022-05-27 00:00:00
# 2022-05-26 00:00:00
# 54366  1.事實發生日：民國110年11月03日\r\n2.公司名稱：台亞半導體股份有限公司(原名：...  2340      20211103
# 54367  1.事實發生日：民國110年10月14日\r\n2.公司名稱：神基投資控股股份有限公司(原名...  3005      20211014
# 54368  1.標的物之名稱及性質（屬特別股者，並應標明特別股約定發行條件，如股息率等）:\r\n聯強通...  2347      20211231
# 54369  1.事實發生日:110/12/31\n2.發生緣由:依據「財團法人中華民國證券櫃檯買賣中心」...  3625      20211231
# 54370  1.事實發生日：民國110年10月29日\r\n2.公司名稱：美好證券股份有限公司(原名：大...  6021      20211029
#
# [54371 rows x 6 columns]

# %%
print(result['date'][40392])
# Out:
# 20220112

# %%
#res = pd.concat([result,res2],axis=0)
#print(res)
# Out:
#           date    time                                              title  \
# 0     20220629  173129                           公告本公司董事會通過委任第五屆薪資報酬委員會委員
# 1     20220629  173416                         公告本公司111年股東常會董事(含獨立董事)當選名單
# 2     20220629  173715                代子公司中國信託商業銀行股份有限公司公告解除董事競業\r\n禁止之限制
# 3     20220629  173805                          本公司111年股東常會通過解除董事競業禁止之限制案
# 4     20220629  173926  代子公司蘇州艾普來/科德/嘉財/嘉駿/百景/嘉吉\r\n公告一年內累積取得同一有價證券達實收...
# ...        ...     ...                                                ...
# 2759  20220420  173804                                   公告本公司董事會決議股利分派情形
# 2760  20220420  232857                             公告本公司董事會通過110年度合併財務報表案
# 2761  20220420  234329                        公告本公司董事會決議不分派110年度員工酬勞及董事酬勞
# 2762  20220420  234711              公告本公司董事會決議召開111年股東常會事宜\r\n(增列召開股東會事由)
# 2763  20220421  085540                                           本公司董事長請辭
#
#                                                 content   co_id date_of_event
# 0     1.發生變動日期:111/06/29\n2.功能性委員會名稱:薪資報酬委員會\n3.舊任者姓...    1538      20220629
# 1     1.發生變動日期:111/06/29\n2.選任或變動人員別（請輸入法人董事、法人監察人、獨...    3605      20220629
# 2     1.股東會決議日:111/06/29\n2.許可從事競業行為之董事姓名及職稱:\n1.利明(...    2891      20220629
# 3     1.股東會決議日:111/06/29\n2.許可從事競業行為之董事姓名及職稱:\n 董事：袁...    3605      20220629
# 4     1.證券名稱:\r\n上海證券交易所一天期國債逆回購GC001，代碼204001\r\n2....    5215      20220629
# ...                                                 ...     ...           ...
# 2759  1.事實發生日:111/04/20\n2.發生緣由:\n一、董事會決議日期：111/04/2...    6779      20220420
# 2760  1.事實發生日:111/04/20\n2.發生緣由:本公司董事會通過110年度合併財務報表案...    4586      20220420
# 2761  1.事實發生日:111/04/20\n2.發生緣由:依據金融監督管理委員會105年1月30日...    4586      20220420
# 2762  1.事實發生日:111/04/20\n2.發生緣由:本公司董事會決議召開111年股東常會相關...    4586      20220420
# 2763  1.董事會決議日:NA\n2.變動人員職稱(請輸入〝董事長〞或〝總經理〞):董事長\n3.舊...  A00043      20220420
#
# [3568 rows x 6 columns]

# %%
#to csv
compression_opts = dict(method='zip',
                        archive_name='material_information_2021.csv')  
result.to_csv('material_information_2021.zip', index=True,
          compression=compression_opts)
